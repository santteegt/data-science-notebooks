# %% [markdown]
# # Mining the Social Web, 2nd Edition
#
# ## Chapter 5: . Mining Web Pages: Using Natural Language Processing to Understand Human Language, Summarize Blog Posts, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# ## Fixes & improvements
#
# Reviewed by [santteegt](https://santteegt.github.io)
#
# This notebook has been fully reviewed and partially fixed on May 2017 in order to make it work with the current version of libraries and APIs.
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# Note: If you find yourself wanting to copy output files from this notebook back to your host environment, see the bottom of this notebook for one possible way to do it.

# %% [markdown]
# ## Installation Requirements
#
# You can install the following libraries directly from the anaconda navigator:
#
# * boilerpipe
# * feedparser
# * numpy

# %% [markdown]
# ## Example 1. Using boilerpipe to extract the text from a web page

# %%
from boilerpipe.extract import Extractor

URL='http://radar.oreilly.com/2010/07/louvre-industrial-age-henry-ford.html'

extractor = Extractor(extractor='ArticleExtractor', url=URL)

print extractor.getText()
# Out:
# Listen
# The Louvre of the Industrial Age
# The Henry Ford is one of the world's great museums, and the world it chronicles is our own.
# by Tim O'Reilly | @timoreilly | +Tim O'Reilly | July 30, 2010
# This morning I had the chance to get a tour of The Henry Ford Museum in Dearborn, MI, along with Dale Dougherty, creator of Make: and Makerfaire, and Marc Greuther, the chief curator of the museum.  I had expected a museum dedicated to the auto industry, but it’s so much more than that.  As I wrote in my first stunned tweet, “it’s the Louvre of the Industrial Age.”
# When we first entered, Marc took us to what he said may be his favorite artifact in the museum, a block of concrete that contains Luther Burbank’s shovel, and Thomas Edison’s signature and footprints.  Luther Burbank was, of course, the great agricultural inventor who created such treasures as the nectarine and the Santa Rosa plum. Ford was a farm boy who became an industrialist; Thomas Edison was his friend and mentor. The museum, opened in 1929, was Ford’s personal homage to the transformation of the world that he was so much a part of.  This museum chronicles that transformation.
# The machines are astonishing – steam engines and coal-fired electric generators as big as houses, the first lathes capable of making other precision lathes (the makerbot of the 19th century), a ribbon glass machine that is one of five that in the 1970s made virtually all of the incandescent lightbulbs in the world, combine harvesters, railroad locomotives, cars, airplanes, even motels, gas stations, an early McDonalds’ restaurant and other epiphenomena of the automobile era.
# Under Marc’s eye, we also saw the transformation of the machines from purely functional objects to things of beauty.  We saw the advances in engineering — the materials, the workmanship, the design, over a hundred years of innovation.  Visiting The Henry Ford, as they call it, is a truly humbling experience.  I would never in a hundred years have thought of making a visit to Detroit just to visit this museum, but knowing what I know now, I will tell you confidently that it is as worth your while as a visit to Paris just to see the Louvre, to Rome for the Vatican Museum, to Florence for the Uffizi Gallery, to St. Petersburg for the Hermitage, or to Berlin for the Pergamon Museum.  This is truly one of the world’s great museums, and the world that it chronicles is our own.
# I am truly humbled that the Museum has partnered with us to hold Makerfaire Detroit on their grounds.  If you are anywhere in reach of Detroit this weekend, I heartily recommend that you plan to spend both days there.  You can easily spend a day at Makerfaire, and you could easily spend a day at The Henry Ford.
# P.S. Here are some of my photos from my visit .  (More to come soon. Can’t upload many as I’m currently on a plane.)
# Related:

# %% [markdown]
# ## Example 2. Using feedparser to extract the text (and other fields) from an RSS or Atom feed

# %%
import feedparser

FEED_URL='http://feeds.feedburner.com/oreilly/radar/atom'

fp = feedparser.parse(FEED_URL)

for e in fp.entries:
    print e.title
    print e.links[0].href
    print e.content[0].value
# Out:
# Four short links: 30 May 2017
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/GPwtxejeu2I/four-short-links-30-may-2017
# <p><em>World Problems, Story AI, Medical Security Horrors, and OSS Fuzz Winning</em></p><ol>
# <li>
# <a href="https://80000hours.org/career-guide/world-problems/">The World's Biggest Problems</a> -- data for you to consider when you choose to work on Stuff That Matters.</li>
# <li>
# <a href="http://dspace.mit.edu/handle/1721.1/67693">The Strong Story Hypothesis and the Directed Perception Hypothesis</a> -- <i>I ask why humans are smarter than other primates, and I hypothesize that an important part of the answer lies in what I call the Strong Story Hypothesis, which holds that storytelling and understanding have a central role in human intelligence. Next, I introduce another hypothesis, the Driven Perception Hypothesis, which holds that we derive much of our common sense, including the common sense required in story understanding, by deploying our perceptual apparatus on real and imagined events.</i> Paper on <a href="https://groups.csail.mit.edu/genesis/">CSAIL's Genesis story system</a>, which <i>understands, tells, and composes stories using common sense rules and higher level concept patterns.</i>
# </li>
# <li>
# <a href="http://boingboing.net/2017/05/26/disclosure-vs-dmca.html">Medical Implants and Hospital Systems are Still Infosec Dumpster Fires</a> (Cory Doctorow) -- has pointers to two writeups of the horrors in various medical systems. <i>Whitescope's whitepaper on pacemaker security analyzes seven different pacemaker programming devices from four different manufacturers (devices that can reprogram a pacemaker remotely, generally by using radio signals) and finds that they are collectively undefended against 8,000 known vulnerabilities, and do not have even simple authentication between pacemakers and pacemaker programmers, meaning that there's no way your implanted pacemaker can tell whether it is connected to a legit device or an attacker's hacking tool.</i>  Cory points out that the DMCA exemption that allowed this paper to end is (a) expiring and (b) not broad enough to permit the release of sample code and the other stuff that helps to improve software security.</li>
# <li>
# <a href="https://opensource.googleblog.com/2017/05/oss-fuzz-five-months-later-and.html">OSS Fuzz Improving Open Source</a> -- Google's open source fuzzer has <i>found numerous security vulnerabilities in several critical open source projects: 10 in FreeType2, 17 in FFmpeg, 33 in LibreOffice, 8 in SQLite 3, 10 in GnuTLS, 25 in PCRE2, 9 in gRPC, and 7 in Wireshark</i>.  This is an excellent service from Google, which runs the testing on their servers. Their criteria for accepting projects: <i>a large user base and/or be critical to Global IT infrastructure.</i>
# </li>
# </ol>
# <p>Continue reading <a href="https://www.oreilly.com/ideas/four-short-links-30-may-2017">Four short links: 30 May 2017.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/GPwtxejeu2I" width="1" />
# Jupyter Digest: 30 May 2017
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/_yMeCj-qk_4/jupyter-digest-30-may-2017
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/jupyter-digest-1400-0e3d158b1ef12913af3c1fca4137b977.png" /></p><p><em>Script generation from RNNs, Tensorflow book companion notebooks, transportation insights from notebooks, machine learning notebooks.</em></p><ul>
# 	<li>
# <a href="https://github.com/udacity/deep-learning/blob/master/tv-script-generation/dlnd_tv_script_generation.ipynb">Script Generation from RNNs</a>. If you've read the hilarious list of <a href="http://lewisandquark.tumblr.com/post/160776374467/new-paint-colors-invented-by-neural-network">paint names from a neural network</a> and wondering how you might do it yourself, this Notebook provides a walkthrough of the theory and code.</li>
# 	<li>
# <a href="https://github.com/BinRoot/TensorFlow-Book">TensorFlow Book companion notebooks</a>. Manning's "MEAP" program is great, providing early access to manuscripts as they're being developed. This <a href="http://www.tensorflowbook.com/"><em>Machine Learning with TensorFlow</em></a> MEAP looks to be a real winner, just based on the companion notebooks. As always with these "in progress" books, though, be sure to check back frequently for updates.</li>
# 	<li>
# <a href="http://blog.ibmjstart.net/2016/01/14/2314/">Delivering Transportation Insights using Jupyter Notebooks, Interactive Dashboards, and Apache Spark</a>. It's an older case study, but it still checks out. This post from Justin Tyberg at IBM shows how to pull a bunch of open source tools together to analyze data for the swank-sounding "Executive Transportation Group" (via <a href="https://twitter.com/mikeloukides">@mikeloukides</a>).</li>
# 	<li>
# <a href="https://github.com/ageron/handson-ml">Notebooks for "Hands-On Machine Learning."</a> This is a set of notebooks for—you guessed it—doing machine learning in Python with Scikit-Learn and TensorFlow. Another great open Jupyter resource from O'Reilly, and a companion to <a href="https://www.safaribooksonline.com/library/view/hands-on-machine-learning/9781491962282/?utm_source=oreilly&amp;utm_medium=newsite&amp;utm_campaign=jupyter-digest-050317-body-text-cta"><em>Hands-On Machine Learning with Scikit-Learn &amp; TensorFlow</em></a>.<br />
# 	<br />
# 	<a href="https://www.safaribooksonline.com/library/view/hands-on-machine-learning/9781491962282/?utm_source=oreilly&amp;utm_medium=newsite&amp;utm_campaign=jupyter-digest-050317-body-text-cta"><img src="http://akamaicovers.oreilly.com/images/0636920052289/lrg.jpg" /></a>
# </li>
# </ul>
# <p>Continue reading <a href="https://www.oreilly.com/ideas/jupyter-digest-30-may-2017">Jupyter Digest: 30 May 2017.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/_yMeCj-qk_4" width="1" />
# Jupyter Insights: Carol Willing, director of the Python Software Foundation
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/XwFNSwumxB8/jupyter-insights-carol-willing
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/oil-paints-for-art_crop-e000c305a9dd005675109723fcecc650.jpg" /></p><p><em>Jupyter as a learning tool, the JupyterHub Project, and Music21.</em></p><p><em><a href="https://twitter.com/WillingCarol">Carol Willing</a> is a director of the Python Software Foundation, a Jupyter Steering Council member, and a geek in residence at FabLab San Diego, where she teaches wearable electronics and software development.</em></p>
#
# <p><em>Below, Willing shares her thoughts on the current and future state of Jupyter. She will also be <a href="https://conferences.oreilly.com/jupyter/jup-ny/public/schedule/speaker/154796?intcmp=il-data-confreg-lp-jpny17_20170525_new_site_jupyter_insights_carol_willing_text_body_speaking_link">speaking at JupyterCon</a>, August 22-25, 2017, in New York City.</em></p>
#
# <h2>1. How has Jupyter changed the way you work?</h2>
#
# <p>Jupyter Notebooks changed the way I learn new concepts, languages, and libraries. For example, I'm currently learning Julia, and I like the ability to combine prose, code snippets, and YouTube video snippets in the same notebook document as notes while I am learning.</p>
#
# <p>Jupyter has also helped me when teaching a workshop. The notebooks give my students the ability to relax, listen, and interact with the material with confidence since they know the notebooks will be a handy takeaway from the workshop.</p>
#
# <h2>2. How does Jupyter change the way your team works? How does it alter the dynamics of collaboration?</h2>
#
# <p>As one of the Project Jupyter developers, I frequently use Jupyter. I've found that the ability to rapidly prototype and document ideas in the same notebook to be particularly handy. I can work out the basic concepts and easily share with my team.</p>
#
# <h2>3. How do you expect Jupyter to be extended in the coming year?</h2>
#
# <p>One of the projects I am actively working on is <a href="https://jupyterhub.readthedocs.io/en/latest/">JupyterHub</a>. JupyterHub enables a person or organization to host notebook servers for a group of users. We are working very hard to improve the installation, configuration, and management of JupyterHub to make it easier to deploy and begin serving users.</p>
#
# <p>Beyond the many technical enhancements across all the Jupyter projects (which you can learn about from our project <a href="https://github.com/jupyter/roadmap">roadmaps</a>, <a href="http://jupyter.org/community.html">mailing list</a>, and <a href="https://newsletter.jupyter.org/">newsletters</a>), the Jupyter team expects to extend the wonderful work already being done by the Jupyter community. We're providing ways for the community to share their projects, best practices, and talents. Education and research are so important to the team, and we want to actively encourage our community to collaborate and share their ideas.</p>
#
# <h2>4. What will you be talking about at JupyterCon?</h2>
#
# <p>Formally, I'll be talking about JupyterHub, engaging new learners through music using the <a href="http://web.mit.edu/music21/">music21</a> library and TensorFlow, and how Jupyter tools can be used to create rich, interactive documents. Informally, I will be chatting with attendees and newcomers about how they are using Jupyter and what they are trying to accomplish using Jupyter. I love the hallway track and listening to all the wonderful ideas that others have.</p>
#
# <h2>5. What <a href="https://conferences.oreilly.com/jupyter/jup-ny/public/schedule/presentations">sessions</a> are you looking forward to seeing at JupyterCon?</h2>
#
# <p>Can I answer "All of them!"? If I must choose a few, since my xkcd conference attendee replicator will likely not be released by August, I am looking forward to:</p>
#
# <ul>
# 	<li>
# <a href="https://conferences.oreilly.com/jupyter/jup-ny/public/schedule/detail/60043?intcmp=il-data-confreg-lp-jpny17_20170525_new_site_jupyter_insights_carol_willing_sessions_links"><em>A billion stars in the Jupyter Notebook</em>, by Maarten Breddels</a>. Maarten has been doing fantastic work with 3D visualization and interactivity in documentation for projects and research.</li>
# 	<li>
# <a href="https://conferences.oreilly.com/jupyter/jup-ny/public/schedule/detail/59995?intcmp=il-data-confreg-lp-jpny17_20170525_new_site_jupyter_insights_carol_willing_sessions_links"><em>Collaboration and automated operation as literate computing for reproducible infrastructure</em>, by Yoshi Nobu Masatani</a>, who is doing wonderful work with Jupyter and DevOps to create infrastructure that enables reproducible science.</li>
# 	<li>
# <a href="https://conferences.oreilly.com/jupyter/jup-ny/public/schedule/detail/60084?intcmp=il-data-confreg-lp-jpny17_20170525_new_site_jupyter_insights_carol_willing_sessions_links"><em>Using Jupyter at the intersection of robots and industrial biology</em>, by Marc Colangelo, Justin Nand, and Danelle Chou</a>. This looks like a fascinating combination of robots, software, and biology to improve collaboration between software engineers and scientists.</li>
# </ul>
#
# <p>I'm really looking forward to JupyterCon. See you there.</p>
# <p>Continue reading <a href="https://www.oreilly.com/ideas/jupyter-insights-carol-willing">Jupyter Insights: Carol Willing, director of the Python Software Foundation.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/XwFNSwumxB8" width="1" />
# How do I configure a Cisco router for secure remote access using SSH?
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/NKE_mbh6Okw/how-do-i-configure-a-cisco-router-for-secure-remote-access-using-ssh
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/screenshot-(1)-959599616266b97e97835c836cb10f86.png" /></p><p><em>Learn the configuration steps required to enable a Cisco router to accept Secure Shell (SSH) connections over the virtual terminal (VTY) lines.</em></p><p>Continue reading <a href="https://www.oreilly.com/learning/how-do-i-configure-a-cisco-router-for-secure-remote-access-using-ssh">How do I configure a Cisco router for secure remote access using SSH?.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/NKE_mbh6Okw" width="1" />
# How do I recover the password on a Cisco router without losing its configuration?
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/Lbnv2KZbvmc/how-do-i-recover-the-password-on-a-cisco-router-without-losing-its-configuration
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/screenshot-(2)-f13c98222bbe3752c219814ac1f18580.png" /></p><p><em>Learn how to change the configuration register so that a router password can be recovered without losing any configurations.</em></p><p>Continue reading <a href="https://www.oreilly.com/learning/how-do-i-recover-the-password-on-a-cisco-router-without-losing-its-configuration">How do I recover the password on a Cisco router without losing its configuration?.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/Lbnv2KZbvmc" width="1" />
# What is the OSI model?
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/EPtQ2Y9VqYc/what-is-the-osi-model
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/screenshot-84f80034321f0c93c4ef181784702686.png" /></p><p><em>Learn about what may be the single most important networking concept that helps different systems communicate—the OSI model.
# </em></p><p>Continue reading <a href="https://www.oreilly.com/learning/what-is-the-osi-model">What is the OSI model?.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/EPtQ2Y9VqYc" width="1" />
# Four short links: 29 May 2017
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/WfeonJntclE/four-short-links-29-may-2017
# <p><em>Formal Correctness, Conversational Maxims, Learn Datalog, and AlphaGo Retires</em></p><ol>
# <li>
# <a href="https://blog.acolyer.org/2017/05/29/an-empirical-study-on-the-correctness-of-formally-verified-distributed-systems/">An Empirical Study on the Correctness of Formally Verified Distributed Systems</a> (Paper a Day) -- the formal verification ensured the protocol was bug free. <i>By far, the biggest group of bugs relates to assumptions about the behaviour of components that the formally verified system interacts with. These bugs manifest in the interface (or shim layer) between the verified and non-verified components.</i> Buffers, escaping, incomplete reads, unreliable communications, all tripped them up.</li>
# <li>
# <a href="https://www.fastcodesign.com/90126166/googles-3-secrets-to-designing-perfect-conversations">Google's Three Secrets to Designing Perfect Conversations</a> -- <i>One secret to making sure that line one leads to two, and two leads to three, comes from James Giongola, creative lead on conversation design and voice direction at Google. He recommends that chat designers take advantage of the rules baked into the <a href="https://en.wikipedia.org/wiki/Cooperative_principle">Cooperative Principle</a>, a concept created by British philosopher Paul Grice in the 1970s. Grice theorized that people employ all sorts of norms (which are known as <a href="https://www.sas.upenn.edu/~haroldfs/dravling/grice.html">Grice’s Maxims</a>) to make sure that conversations flow normally. These maxims serve as simple hacks for anyone writing robo-conversations—the key is to make sure your bot is always offering enough information to keep a conversation going.</i>
# </li>
# <li>
# <a href="http://www.learndatalogtoday.org/">Learn Datalog Today</a> -- <i>Learn Datalog Today is an interactive tutorial designed to teach you the Datomic dialect of Datalog. Datalog is a declarative database query language with roots in logic programming. Datalog has similar expressive power as SQL.</i> Prolog as a query language, more or less, designed to parallelize, so popular with the Big Data kids. This is gentler info than reading the Datalog papers.</li>
# <li>
# <a href="https://www.theverge.com/2017/5/27/15704088/alphago-ke-jie-game-3-result-retires-future">AlphaGo "Retires"</a> -- <i>DeepMind will release the data from 50 games of the AI playing against itself for the Go community to study. DeepMind is also working on a teaching tool based on AlphaGo to be released sometime in the future. Ke Jie will collaborate with DeepMind on the tool, which Hassabis says should give “all players and fans the opportunity to see the game through the lens of AlphaGo.”</i> I certainly hope this happens. It seems cheap to pop up and win the title, then retire and never play again. IBM's Deep Blue team did this after their software beat Kasparov. If it means the humans never get to learn how to beat the software, then this feels like the engineers using the game rather than loving the game. If you loved the game, you'd leave the game better than you found it rather than unsettled and unresolved.</li>
# </ol>
# <p>Continue reading <a href="https://www.oreilly.com/ideas/four-short-links-29-may-2017">Four short links: 29 May 2017.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/WfeonJntclE" width="1" />
# Intelligent Bits: 26 May 2017
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/OO4F4o3JZbI/intelligent-bits-26-may-2017
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/intelligent_bits_logo_fl_vc-67a77eaa42302374b753b5fd29dd6c36.png" /></p><p><em>Sukiyaki in French style, brick-and-mortar conversion tracking, route-based pricing, and technological productivity.</em></p><ol>
# 	<li>
# <a href="https://motherboard.vice.com/en_us/article/deep-learning-algorithm-rewrites-traditional-recipes-for-new-regions-ingredients">Deep recipe transfer</a> — Many recent results have shown the ability to transfer visual patterns and styles across images. Now researchers demonstrate how neural nets can adapt recipes to the culinary styles of particular geographic regions.</li>
#
#
# 	<li>
# <a href="https://www.washingtonpost.com/news/the-switch/wp/2017/05/23/google-now-knows-when-you-are-at-a-cash-register-and-how-much-you-are-spending/?utm_term=.d8dc82a910a8">Brick, mortar, and bucks</a> — Google can now associate digital ad campaigns with in-store visits and sales by applying machine learning to its wealth of user data, including geolocation, search history, web browsing, app interactions, and now credit card transaction records.</li>
#
#
# 	<li>
# <a href="https://www.bloomberg.com/news/articles/2017-05-19/uber-s-future-may-rely-on-predicting-how-much-you-re-willing-to-pay">How much for that ride?</a> — Uber applies machine learning to route-based pricing in an effort to become more sustainable by predicting how much you’re willing to pay.</li>
#
#
# 	<li>
# <a href="https://itif.org/publications/2017/05/08/false-alarmism-technological-disruption-and-us-labor-market-1850-2015">Phew, false alarm</a> — Contrary to popular outcry about technological dislocation of labor, this think tank argues that more innovation is needed to drive productivity and, therefore, jobs.</li>
# </ol>
# <p>Continue reading <a href="https://www.oreilly.com/ideas/intelligent-bits-26-may-2017">Intelligent Bits: 26 May 2017.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/OO4F4o3JZbI" width="1" />
# Four short links: 26 May 2017
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/XpUdR0M9EMg/four-short-links-26-may-2017
# <p><em>Service Availability, Data Share, Eventual Consistency Explained, and Reproducible Deep Learning</em></p><ol>
# <li>
# <a href="https://tinyurl.com/l5w3ful">The Calculus of Service Availability</a> -- <i>A service cannot be more available than the intersection of all its critical dependencies. If your service aims to offer 99.99% availability, then all of your critical dependencies must be significantly more than 99.99% available. Internally at Google, we use the following rule of thumb: critical dependencies must offer one additional 9 relative to your service—in the example case, 99.999% availability—because any service will have several critical dependencies, as well as its own idiosyncratic problems. This is called the "rule of the extra 9."</i>
# </li>
# <li>
# <a href="https://datproject.org/">datproject</a> -- open source crypto—guaranteed distributed data share, designed for versioned data sets.</li>
# <li>
# <a href="https://medium.com/@yonatanzunger/how-your-data-is-stored-or-the-laws-of-the-imaginary-greeks-54c569c17a49">How Your Data is Stored</a> -- eventual consistency VERY LUCIDLY explained.  It follows <a href="http://lamport.azurewebsites.net/pubs/lamport-paxos.pdf">the original (entertaining) paper by Leslie Lamport</a> but spells everything out clearly for non-computer-scientists.</li>
# <li>
# <a href="https://github.com/openai/baselines">OpenAI Baselines</a> -- open source implementations of the interesting published algorithms in deep learning. The papers often gloss over some of the details, so a full and working implementation truly lets others build on research. It's like the reproducibility project for deep learning.</li>
# </ol>
# <p>Continue reading <a href="https://www.oreilly.com/ideas/four-short-links-26-may-2017">Four short links: 26 May 2017.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/XpUdR0M9EMg" width="1" />
# Running a word count application using Spark
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/361dr_lFFxk/running-a-word-count-application-using-spark
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/number-703136_1920-ada4413fd7564d4f5ed07a757e270ddd.jpg" /></p><p><em>How to use Apache Spark’s Resilient Distributed Dataset (RDD) API.</em></p><p>Continue reading <a href="https://www.oreilly.com/ideas/running-a-word-count-application-using-spark">Running a word count application using Spark.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/361dr_lFFxk" width="1" />
# Peeking into the black box: Lessons from the front lines of machine-learning product launches
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/cL3FWbFYMy4/peeking-into-the-black-box-machine-learning-product-launches
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/box-1197458_crop-8dc71e2956a6d0844b89bf211061ba9b.jpg" /></p><p><em>Grace Huang shares lessons learned from running and interpreting machine-learning experiments.</em></p><p>Continue reading <a href="https://www.oreilly.com/ideas/peeking-into-the-black-box-machine-learning-product-launches">Peeking into the black box: Lessons from the front lines of machine-learning product launches.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/cL3FWbFYMy4" width="1" />
# Using AI to create new jobs
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/ZM5pMhy1SV4/using-ai-to-create-new-jobs
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/wpa-mural-museum-of-mobile-1_crop-aacb8eefe281db7f4fc5cb30127e16c5.jpg" /></p><p><em>Tim O’Reilly delves into past technological transitions, speculates on the possibilities of AI, and looks at what's keeping us from making the right choices to govern our creations.</em></p><p>Continue reading <a href="https://www.oreilly.com/ideas/using-ai-to-create-new-jobs">Using AI to create new jobs.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/ZM5pMhy1SV4" width="1" />
# Lessons from piloting the London Office of Data Analytics
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/AWnDLxWJ0jg/lessons-from-piloting-the-london-office-of-data-analytics
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/whitehead_in_his_glider_1_crop-a22bf927ed8a5aea7f6f586cc632f806.jpg" /></p><p><em>Eddie Copeland explores how the London Office of Data Analytics overcame the barriers to joining, analyzing, and acting upon public sector data at city scale.</em></p><p>Continue reading <a href="https://www.oreilly.com/ideas/lessons-from-piloting-the-london-office-of-data-analytics">Lessons from piloting the London Office of Data Analytics.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/AWnDLxWJ0jg" width="1" />
# Enabling data science in the enterprise
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/mfOlvcc6us4/enabling-data-science-in-the-enterprise
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/singapore-431421_1920_crop-484cc282339ba9f3c89bf9bcf1fb9825.jpg" /></p><p><em>Tom Smith explains how the UK's Office of National Statistics is using data science to create repeatable, accurate, and transferable statistical research.</em></p><p>Continue reading <a href="https://www.oreilly.com/ideas/enabling-data-science-in-the-enterprise">Enabling data science in the enterprise.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/mfOlvcc6us4" width="1" />
# Is finance ready for AI?
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/cCYAgyP6ZIU/is-finance-ready-for-ai
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/ai-finance-computer-screen-crop-4070abafcb268ce65f604379b641b8d7.jpg" /></p><p><em>Aida Mehonic explores the role artificial intelligent might play in the financial world.</em></p><p>Continue reading <a href="https://www.oreilly.com/ideas/is-finance-ready-for-ai">Is finance ready for AI?.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/cCYAgyP6ZIU" width="1" />
# Accelerate analytics and AI innovations with Intel
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/4xdK74B1OXc/accelerate-analytics-and-ai-innovations-with-intel
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/big-bang-466312_1920_crop-16b436da50be33b557a4c1785e6047ac.jpg" /></p><p><em>Ziya Ma outlines the challenges for applying machine learning and deep learning at scale and shares solutions that Intel has enabled for customers and partners.</em></p><p>Continue reading <a href="https://www.oreilly.com/ideas/accelerate-analytics-and-ai-innovations-with-intel">Accelerate analytics and AI innovations with Intel.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/4xdK74B1OXc" width="1" />
# Data science and deep learning in retail
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/S7IY008Uhug/data-science-and-deep-learning-in-retail
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/49545547_973ba1ce46_o_crop-33a13aac4555fcc6ad4cb3e7f35da91a.jpg" /></p><p><em>The O’Reilly Data Show Podcast: Jeremy Stanley on hiring and leading machine learning engineers to build world-class data products.</em></p><p>In this episode of the <a href="https://www.oreilly.com/ideas/topics/oreilly-data-show-podcast">Data Show</a>, I spoke with <a href="https://www.linkedin.com/in/jeremystanley/">Jeremy Stanley</a>, VP of data science at <a href="https://www.instacart.com/">Instacart</a>, a popular grocery delivery service that is expanding rapidly. <a href="https://www.safaribooksonline.com/library/view/strata-hadoop/9781491944660/video282862.html?utm_source=oreilly&amp;utm_medium=newsite&amp;utm_campaign=20170524_data_show_jeremy_stanley_body_text_as_stanley_describes_link">As Stanley describes it</a>, Instacart operates a four-sided marketplace comprised of retail stores, products within the stores, shoppers assigned to the stores, and customers who order from Instacart. The objective is to get fresh groceries from popular retailers delivered to customers in a timely fashion. Instacart’s goals land them in the center of the many opportunities and challenges involved in building high-impact data products. </p><p>Continue reading <a href="https://www.oreilly.com/ideas/data-science-and-deep-learning-in-retail">Data science and deep learning in retail.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/S7IY008Uhug" width="1" />
# Travis Lowdermilk and Jessica Rich on building a customer-driven culture at Microsoft
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/-LMEuK5ErS0/travis-lowdermilk-and-jessica-rich-on-building-a-customer-driven-culture-at-microsoft
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/gears-1258790_1920_crop-ec0c888eccbf3509c3c05ae0dbdbdf96.jpg" /></p><p><em>The O’Reilly Design Podcast: What makes healthy teams healthy, being customer obsessed, and design and research at Microsoft.</em></p><p>This week, I sit down with <a href="https://twitter.com/tlowdermilk?lang=en">Travis Lowdermilk</a> senior UX designer at Microsoft, and <a href="https://twitter.com/jessicarichphd">Jessica Rich</a>, UX researcher at Microsoft; Lowdermilk and Rich are also co-authors of the <a href="https://www.safaribooksonline.com/library/view/the-customer-driven-playbook/9781491981269/?utm_source=oreilly&amp;utm_medium=newsite&amp;utm_campaign=20170524_design_podcast_rich_lowdermilk_book_link_body_text">Customer Driven Playbook</a>. We talk about why failing fast is not always a good approach, sensemaking, and never losing track of the customer’s voice.</p><p>Continue reading <a href="https://www.oreilly.com/ideas/travis-lowdermilk-and-jessica-rich-on-building-a-customer-driven-culture-at-microsoft">Travis Lowdermilk and Jessica Rich on building a customer-driven culture at Microsoft.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/-LMEuK5ErS0" width="1" />
# JupyterLab: The evolution of the Jupyter web interface
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/AW0YMQ37-EA/jupyterlab-the-evolution-of-the-jupyter-web-interface
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/data-shell-fossils-crop-6eb10d5f896b6fcf43b23efc61cb2701.jpg" /></p><p><em>Project Jupyter co-founder Brian Granger on the JupyterLab project, its potential role in scientific and tech communities, and the expanding role of notebooks. </em></p><p>Brian Granger is an associate professor of physics at Cal Poly San Luis Obispo, where he also teaches in the university’s undergraduate data science program. His primary area of research is interactive computing with data and, specifically, Jupyter. He started the original IPython Notebook in 2011 and is one of the co-founders of Project Jupyter. He is also an active contributor to and co-leader of the JupyterLab project, which aims to take the Jupyter Notebook interface to the next level with its flexible building blocks for interactive and collaborative computing. We recently discussed JupyterLab, how feedback from notebook users informed its design, how its features could benefit the scientific and technical computing communities, and the role of notebooks in academia and even data journalism.</p>
#
#
# <h2>What is JupyterLab and how does it represent what you've called the “evolution of the Jupyter web interface?”</h2>
#
#
#
# <p>The classic Jupyter Notebook offers a number of different building blocks for interactive computing: the notebook, file browser, text editor, terminal, outputs, etc. We view JupyterLab as the evolution of the classic notebook, as it allows a more flexible and powerful way for working with those same building blocks. From a user’s perspective, we hope that everything in JupyterLab is familiar, but even more delightful and productive to work with.</p>
#
#
#
# <p>Before going further, I want to acknowledge the incredible team working on Jupyter on many fronts, including software, design and organizational aspects. In particular, individuals on the <a href="http://jupyter.org/about.html">Jupyter Steering Council</a> provide the foundation of the project and are all long-term contributors, without whom the project wouldn’t exist. The team building JupyterLab and PhosphorJS are the driving force behind the work I discuss here. Lastly, we are all grateful to Fernando Perez, creator of IPython and co-founder with us on Jupyter, for setting off into the uncharted wilderness of scientific open source software in 2001.</p>
#
# <h2>What need is JupyterLab fulfilling among Jupyter Notebook users, particularly those who work in data science or scientific/technical computing?</h2>
#
# <p>Since the IPython Notebook came out in 2011, we have spent a lot of time talking to individual and organizational users to understand what delights them about the notebook, and what remains really painful. Some of those pain points are specific to the Jupyter Notebook and others are more general challenges they face working with code and data. Also, in 2015, we worked with IBM to run a user experience survey (the results of which are posted on <a href="https://github.com/jupyter/design/tree/master/surveys/2015-notebook-ux">GitHub</a>). Based on all of this feedback, three key factors led us to develop JupyterLab.</p>
#
#
#
# <p>First, users love the notebook experience, and want it to improve, but without losing the core characteristics that make it the Jupyter notebook. This is important, because we could have re-thought the entire notebook abstraction itself in JupyterLab—but we didn’t. Thus, while we are making improvements to the notebook UI/UX in JupyterLab, notebooks are essentially the same (in fact, it is still 100% the same document format and server).</p>
#
#
#
# <p>Second, users want to be able to combine, remix, and integrate the different building blocks to better support their workflows. A classic usage pattern we see is data scientists who begin working in an interactive Python shell, then migrate to a notebook, and eventually build and deploy a service based on that code. In the classic notebook, those transitions are really painful. In JupyterLab, we are trying to address the pain points of such an evolving workflow. For example, in JupyterLab we offer a document-less code console for quick exploration that supports Jupyter’s rich output, and which is integrated with the text file editor, so you can run blocks of code in a text file interactively, outside the notebook.</p>
#
#
#
# <p>Third, collaboration is a significant area of need. As more and more groups and organizations adopt Jupyter, they need to work together with others on notebooks. Sure, notebooks can be shared on GitHub, Dropbox or email, but that is really painful and doesn’t represent how most of us work together. The next step beyond that is full real-time collaboration, in the style of Google Drive or Dropbox Paper. We have built JupyterLab with the abstractions needed to offer real-time collaboration on all documents (notebooks, text files, etc.). One of our postdocs at UC Berkeley has a prototype of real-time collaboration working in JupyterLab and our designers at Cal Poly are working on the UI/UX of this. We are having a lot of fun working on this right now, and are hopeful it is going to really help our users. It is worth mentioning that <a href="https://cocalc.com/">CoCalc</a> (formerly SageMathCloud) now also offers a custom notebook front end for Jupyter that supports real-time collaboration.</p>
#
#
#
# <h2>What has surprised you about the evolution of this project?</h2>
#
#
#
# <p>We worked on designing the core abstractions of JupyterLab while iterating many times on the implementation. As we have converged on the current architecture and implementation, I have been surprised to see how the different abstractions can be combined to provide features we hadn’t initially envisioned. An example is the support we have for GeoJSON and CSV files. JupyterLab allows third-party extensions to declare handlers that enable users to edit or view different file types. We hadn’t appreciated how that would make it very easy for us and others to improve the user experience of working with common data formats. In JupyterLab, a user can double-click on a GeoJSON file and see a nicely rendered map based on <a href="http://leafletjs.com/">Leaflet</a>, or a nice table view of a CSV file. Those views are integrated with our document models, so a user can edit the files in the text editor and immediately see updated versions of the rendered file. The same abstractions also gave us an integrated Markdown editor/renderer for free.</p>
#
# <h2>There are a number of features planned for the summer release of JupyterLab 1.0, including theme switching, porting nbextensions, and hooking up kernels to output areas. How has the team prioritized features for beta and 1.0?</h2>
#
# <p>Originally, the primary characteristic of JupyterLab 1.0 was going to be its feature parity with the classic Jupyter Notebook. That is evolving and we are starting to make deliberate choices to postpone work on more obscure features of the classic notebook, to make sure that the commonly used features in JupyterLab are well designed, both from the software/API perspective and the UI/UX design. From the UI/UX side, we are attempting to address a number of usability issues that have been with the classic notebook from the beginning, such as collapsable code cells and a better user experience for creating, running, deleting and moving cells. Users do those things hundreds or thousands of times and they are a bit too clunky. From the software/API perspective, we are working hard to offer clean public APIs that can used and extended by other developers. Those APIs are, in a sense, UI/UX for developers.</p>
#
#
#
# <h2>Beyond 1.0, what are some planned features of JupyterLab, and how have they been determined?</h2>
#
# <p>A main priority after 1.0 is released is to help users and organizations make the transition from the classic notebook to JupyterLab. We realize the transition will take time and that we will need to provide a lot of support and documentation, etc. Beyond that, the real-time collaboration probably won’t be done for the 1.0 release, so that will be a significant area of focus beyond 1.0.</p>
#
#
#
# <h2>How do notebooks feature in your academic work at Cal Poly?</h2>
#
# <p>There are two components of my academic work: teaching and research. On the teaching side I am currently teaching in Cal Poly’s undergraduate Data Science degree program (for Statistics and CS majors). I, and the other instructors in this program, use the notebook (through <a href="https://github.com/jupyterhub/jupyterhub">JupyterHub</a>) for in-class lectures, homework, and projects. The same is true in the Computational Physics course in our department. These courses are really fun to teach and at this point, I can’t imagine teaching about code+data without the notebook.</p>
#
#
#
# <p>On the research side, Jupyter is my primary area of research. In very broad terms, academia is struggling to understand how code and data, rather than traditional peer-reviewed papers, can be the primary output of academic research. At Cal Poly, the key phrase is “external validation,” which basically means, they want evidence that others find your research significant and impactful. Publications in traditional, peer-reviewed journals are one form of external validation. I assert that open source software, with significant user and developer communities, also has external validation. To their credit, Cal Poly and my department granted my tenure in 2014, largely based on my work in developing the Jupyter Notebook. Today, interactive computing with data remains my main area of research. This includes Jupyter and other open source projects such as <a href="https://github.com/altair-viz/altair">Altair</a>.</p>
#
#
#
# <h2>Notebooks have broad utility in the computer science and data science communities. Are you seeing notebook usage increase in other related communities?</h2>
#
#
#
# <p>One usage that I am particularly pleased with is Jupyter’s usage in the data journalism community. In the past few years, major news organizations have invested significantly in data journalism. Amongst others, this includes <a href="https://fivethirtyeight.com/">FiveThirtyEight</a>, <a href="http://www.latimes.com/">LA Times</a>, <a href="https://www.propublica.org/">Pro Publica</a>, and to many a surprise, <a href="https://www.buzzfeed.com/news">BuzzFeedNews</a>. Jeremy Singer-Vine and the team at BuzzFeedNews have led the way in setting a high bar for open and reproducible data journalism. In their <a href="https://github.com/BuzzFeedNews">GitHub repository</a>, they provide the dataset and analysis (as a Jupyter Notebook) for all of the data-backed news articles published on BuzzFeedNews. Other news organizations are now following this practice as well. Given the highly politicized backlash against science and data-backed reality we are seeing in the U.S., I find this work extremely important and am proud that Jupyter has, in a small way, enabled it.</p>
# <p>Continue reading <a href="https://www.oreilly.com/ideas/jupyterlab-the-evolution-of-the-jupyter-web-interface">JupyterLab: The evolution of the Jupyter web interface.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/AW0YMQ37-EA" width="1" />
# Jason Laska and Michael Akilian on using AI to schedule meetings
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/chg_TZEGgVw/jason-laska-and-michael-akilian-on-scheduling-bots
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/clocks-1098080_1920_crop-a25b3623b5b5c152b019ec97b1b0dd3f.jpg" /></p><p><em>The O’Reilly Bots Podcast: The technical and social dynamics of solving scheduling problems.</em></p><p>In this episode of the <a href="https://www.oreilly.com/topics/oreilly-bots-podcast">O’Reilly Bots Podcast</a>, Pete Skomoroch and I talk to <a href="https://www.linkedin.com/in/jasonlaska">Jason Laska</a> and <a href="https://twitter.com/akilian">Michael Akilian</a> of <a href="https://claralabs.com/">Clara Labs</a>, creator of a virtual assistant—Clara—that schedules meetings and interacts in natural language through email.</p>
#
# <p>E-mail is, to me, a highly promising (and somewhat underrated) venue for bots. Messaging is growing quickly, but e-mail is still the standard way to communicate within businesses and especially between businesses. E-mail conventions are somewhat standardized, and much of it is highly routinized—automatically generated reports, receipts, etc.—so it’s ripe for automation.</p>
#
# <p>Laska, who leads the machine learning efforts at Clara Labs, and Akilian, the company’s co-founder and CTO, talk about the reality of developing an AI-driven product, and explain Clara’s human-in-the-loop system. “People are still there to do some of the most challenging aspects of this work, and that’s exactly what you want to use people for,” says Laska.</p><p>Continue reading <a href="https://www.oreilly.com/ideas/jason-laska-and-michael-akilian-on-scheduling-bots">Jason Laska and Michael Akilian on using AI to schedule meetings.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/chg_TZEGgVw" width="1" />
# Four short links: 25 May 2017
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/ajnAFd1qRJc/four-short-links-25-may-2017
# <p><em>Crypto vs. Regulation, Crippling Genomic Research, There Are Bots, and Web Security</em></p><ol>
# <li>
# <a href="http://www.cl.cam.ac.uk/~rnc1/Chaffinch.html">Chaffinch</a> -- crypto system that's an interesting response to an attempt to regulate crypto. <i>The Chaffinch system allows several further messages to be steganographically concealed behind the main message. This allows cover traffic to be divulged to any authorities who wish to inspect the confidential information, without compromising the hidden material. The system is evaluated not only in terms of the traditional threat to confidentiality, eavesdroppers with significant computing power, but also in terms of its interaction with the U.K.'s Regulation of Investigatory Powers (RIP) Act, one of the first laws to attempt to engage with cryptography.</i>
# </li>
# <li>
# <a href="https://shift.newco.co/were-about-to-cripple-the-genomic-medical-era-5b998264a9a1">We’re About to Cripple the Genomic Medical Era</a> (DJ Patil) -- <i>When we were developing the Precision Medicine Initiative and meeting with Americans across the country, a key concern was ensuring that their data couldn’t be used against them or their families (this is genetic information, so if you share a biological basis, you have overlap in the data). If there is any threat of this data being used in a way that is contrary to research, my deep fear is that people won’t be willing to donate their data. And there are too many people who have diseases who need us to donate our data to help.</i>
# </li>
# <li>
# <a href="https://www.ribbonfarm.com/2017/05/23/there-are-bots-look-around/">There Are Bots, Look Around</a> (Renee DiResta) -- <i>Something very similar happened in finance with the advent of high-frequency trading (the world I came from as a trader at Jane Street): technology was used to distort information flows and access in much the same way it is now being used to distort and game the marketplace of ideas. The future arrived a lot earlier for finance than for politics.</i>
# </li>
# <li>
# <a href="https://simplesecurity.sensedeep.com/web-developer-security-checklist-f2e4f43c9c56">Web Developer Security Checklist</a> -- <i>This checklist is simple, and by no means complete. I’ve been developing secure web applications for over 14 years, and this list contains some of the more important issues that I’ve painfully learned over this period. I hope you will consider them seriously when creating a web application.</i>
# </li>
# </ol>
# <p>Continue reading <a href="https://www.oreilly.com/ideas/four-short-links-25-may-2017">Four short links: 25 May 2017.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/ajnAFd1qRJc" width="1" />
# Real-time intelligence gives Uber the edge
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/c3Ezs90MePA/real-time-intelligence-gives-uber-the-edge-strata-london-2017
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/6170496511_b6cd5cb388_o_crop-8721b22fb79a1bacfbfb75c1052119fc.jpg" /></p><p><em>M. C. Srivas covers Uber's big data architecture and explores the real-time problems Uber needs to solve to make ride sharing smooth.</em></p><p>Continue reading <a href="https://www.oreilly.com/ideas/real-time-intelligence-gives-uber-the-edge-strata-london-2017">Real-time intelligence gives Uber the edge.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/c3Ezs90MePA" width="1" />
# Another one bytes the dust
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/A2gNBsfgn4k/another-one-bytes-the-dust
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/matrix-1013613_1920_crop-8e4a233e051231f89890033ae2b593c5.jpg" /></p><p><em>Using the music industry as an example, Paul Brook shows how modern information points bring new data that changes the way an organization will make decisions.</em></p><p>Continue reading <a href="https://www.oreilly.com/ideas/another-one-bytes-the-dust">Another one bytes the dust.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/A2gNBsfgn4k" width="1" />
# Machine learning is a moonshot for us all
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/UvjPQaBTQqI/machine-learning-is-a-moonshot-for-us-all
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/full-moon-1775765_1920_crop-63d64c140fafd41842a23a457182c4fd.jpg" /></p><p><em>Darren Strange asks: What part will we each play in what is sure to be one of the most exciting times in computer science?</em></p><p>Continue reading <a href="https://www.oreilly.com/ideas/machine-learning-is-a-moonshot-for-us-all">Machine learning is a moonshot for us all .</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/UvjPQaBTQqI" width="1" />
# The data subject first?
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/S0j6KQZCmgY/the-data-subject-first
# ...
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 		</tr>
# 		<tr>
# 			<td>
# 			<p>Speed-of-thought performance?</p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 		</tr>
# 		<tr>
# 			<td>
# 			<p>Support for streaming data?</p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 		</tr>
# 		<tr>
# 			<td>
# 			<p>Support for blending of data from multiple sources without data movement/ETL?</p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 			<td>
# 			<p> </p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>
#
# <h2>Requirements for embedded analytics solutions</h2>
#
# <p>Done right, embedded analytics will become part of your product and help build your competitive advantage. Your embedded analytics solutions should integrate into your product cycle; be low cost and commercially flexible (in terms of royalties and licensing) so it can provide good ROI; and connect quickly, easily, and in an architecturally sound and extensible way to a variety of modern data sources.</p>
#
# <p>Most importantly, an embedded analytics solution should provide a great user experience. Performance, particularly during interactive data exploration, must be quick or you’ll quash the business analyst’s creativity while he or she sits and waits for charts to be refreshed. Performance can be particularly demanding when combining and analyzing large volumes of data from multiple sources. And remember, when you embed analytics into your application, users and customers see it all as the face of your application, so you need to make sure whatever you embed has a modern look and feel with a well-designed interface and informative visualizations.</p>
#
# <p><em>This post is a collaboration between O'Reilly and Zoomdata. <a href="http://www.oreilly.com/about/editorial_independence.html">See our statement of editorial independence</a>.</em></p>
# <p>Continue reading <a href="https://www.oreilly.com/ideas/the-business-advantages-of-embedding-analytics-into-applications">The business advantages of embedding analytics into applications.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/3-HFPCVk2BA" width="1" />
# How can I deploy a multi-container application with Docker Compose?
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/HLT052gosms/how-can-i-deploy-a-multi-container-application-with-docker-compose
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/multi-container-app-docker-compose-screen-5e3d94267521988b1fb25a77940327d8.png" /></p><p><em>Learn how to use Docker to distribute multi-container applications into a standardized unit for seamless software development.</em></p><p>Continue reading <a href="https://www.oreilly.com/learning/how-can-i-deploy-a-multi-container-application-with-docker-compose">How can I deploy a multi-container application with Docker Compose?.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/HLT052gosms" width="1" />
# How do I package my Java application as a Docker image using Gradle?
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/_k9qWr2KpL8/how-do-i-package-my-java-application-as-a-docker-image-using-gradle
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/package-java-app-docker-gradle-screen-d10942cc92b3435fd9b225d229b54b8b.png" /></p><p><em>Learn how to use Gradle, a popular build tool for Java developers, to package your Java application as a Docker image and run as a Docker container.</em></p><p>Continue reading <a href="https://www.oreilly.com/learning/how-do-i-package-my-java-application-as-a-docker-image-using-gradle">How do I package my Java application as a Docker image using Gradle?.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/_k9qWr2KpL8" width="1" />
# How do I create Docker images and run containers using Maven?
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/YRw0XJPSB_4/how-do-i-create-docker-images-and-run-containers-using-maven
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/package-java-app-docker-screen-eac071a3803f8e5b9793d7302495e77e.png" /></p><p><em>Learn how to use Apache Maven, a project management and comprehension tool, to package your Java application as a Docker image and run as a Docker container.</em></p><p>Continue reading <a href="https://www.oreilly.com/learning/how-do-i-create-docker-images-and-run-containers-using-maven">How do I create Docker images and run containers using Maven?.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/YRw0XJPSB_4" width="1" />
# Get introduced to the new Java® 9 Platform Module System (JPMS) with Paul Deitel
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/jYJhY8Q41a0/get-introduced-to-the-java-9-platform-module-system-with-paul-deitel
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/paul-deitel-20f465ac2b112e04551e6906869eed69.jpg" /></p><p><em>This two-day live online training covers JPMS, a tool Paul Deitel calls “the most significant new Java software-engineering technology since the inception of Java.”</em></p><p><a href="http://www.deitel.com/Deitel/AboutDeitelAssociatesInc/tabid/196/Default.aspx">Paul Deitel</a>, CEO of Deitel &amp; Associates, Inc., co-author of <a href="https://www.safaribooksonline.com/library/view/java-9-for/9780134778167/?utm_source=oreilly&amp;utm_medium=newsite&amp;utm_campaign=get-introduced-jpms-deitel-body-text-cta"><em>Java<sup>®</sup> 9 for Programmers</em></a>, and an Oracle Java Champion, is leading a live online introduction to the Java Platform Module System (JPMS).</p>
#
# <p>Deitel’s two-day live online training will be <a href="https://www.safaribooksonline.com/live-training/courses/introduction-to-modularity-with-the-java-9-platform-module-system-jpms/0636920091318/?utm_source=oreilly&amp;utm_medium=newsite&amp;utm_campaign=get-introduced-jpms-deitel-body-text-cta">presented only on Safari</a>, O’Reilly’s learning platform.</p>
#
# <p>Modularity—the result of <a href="http://openjdk.java.net/projects/jigsaw/">Project Jigsaw</a>—benefits developers at all levels by helping them manage and reduce complexity, leading to increased productivity in the construction, maintenance, and evolution of software systems—especially large-scale software systems.</p>
#
# <h2>What you’ll learn in <em>Introduction to Modularity with the Java<sup>®</sup> 9 Platform Module System</em>
# </h2>
#
# <p>In this <a href="https://www.safaribooksonline.com/live-training/courses/introduction-to-modularity-with-the-java-9-platform-module-system-jpms/0636920091318/?utm_source=oreilly&amp;utm_medium=newsite&amp;utm_campaign=get-introduced-jpms-deitel-body-text-cta">live online training</a>, you’ll:</p>
#
# <ul>
# 	<li>Understand the motivation for modularity.</li>
# 	<li>Review key JPMS requirements.</li>
# 	<li>Modularize pre-Java-9 code, then execute the modularized version.</li>
# 	<li>Create module declarations that specify module dependencies with <strong>requires</strong>, and specify the packages a module makes available to other modules with <strong>exports</strong>.</li>
# 	<li>Selectively allow runtime <em>reflection</em> of types with <strong>open</strong> and <strong>opens</strong>.</li>
# 	<li>Use <em>services</em> to loosely couple system components, making large-scale systems easier to develop and maintain.</li>
# 	<li>Indicate that a module explicitly uses a service or provides a service implementation with <strong>uses</strong> and <strong>provides...with</strong>, respectively.</li>
# 	<li>Use the <strong>jdeps</strong> command to determine a module’s dependencies.</li>
# 	<li>Understand how <em>unnamed</em> and <em>automatic modules</em> enable you to continue using non-modularized pre-Java-9 code in Java 9.</li>
# 	<li>Use the NetBeans IDE to create <em>module graphs</em> to visualize the modular JDK as well as your own modular systems.</li>
# 	<li>See the <em>module resolver</em> in action as it determines runtime dependencies.</li>
# 	<li>Use <strong>jlink</strong> to create smaller runtimes appropriate for resource-constrained devices—for example, Internet of Things (IoT) devices.</li>
# 	<li>And more.</li>
# </ul>
#
# <br />
#
# <p>Visit <a href="https://www.safaribooksonline.com/live-training/courses/introduction-to-modularity-with-the-java-9-platform-module-system-jpms/0636920091318/?utm_source=oreilly&amp;utm_medium=newsite&amp;utm_campaign=get-introduced-jpms-deitel-body-text-cta">Safari</a> for the detailed course outline and prerequisites for <a href="https://www.safaribooksonline.com/live-training/courses/introduction-to-modularity-with-the-java-9-platform-module-system-jpms/0636920091318/?utm_source=oreilly&amp;utm_medium=newsite&amp;utm_campaign=get-introduced-jpms-deitel-body-text-cta"><em>Introduction to Modularity with the Java<sup>®</sup> 9 Platform Module System</em></a>.</p>
#
#
# <h2>How Java 9 modularity will make developers’ lives easier</h2>
#
# <p>According to <a href="https://jcp.org/en/jsr/detail?id=376">JSR 376: Java Platform Module System</a>, the key goals of modularizing the Java SE Platform are:</p>
#
# <p><strong>Reliable configuration</strong>—You must explicitly declare dependencies between modules in a manner that’s recognized <em>both</em> at compile time and execution time. The system can automatically walk through these dependencies (via the module resolver) to determine the subset of all modules required to support your app.</p>
#
# <p><strong>Strong encapsulation</strong>—The packages in a module are accessible to other modules only if the module explicitly “exports” them (that exporting can be restricted to select modules). Even then, another module cannot use those packages unless it explicitly states that it “requires” the other module’s capabilities.</p>
#
# <p><strong>Scalable Java Platform</strong>—Previously, the Java Platform was a <em>monolith</em> consisting of a massive number of packages, making it challenging to develop, maintain, and evolve. It couldn’t easily be subsetted. The platform is now modularized into 95 modules. You can create custom runtimes consisting of <em>only</em> the modules you need for your apps or the devices you’re targeting. For example, if a device does not support GUIs, you could create a runtime that does not include the GUI modules, significantly reducing the runtime’s size.</p>
#
# <p><strong>Greater platform integrity</strong>—Before Java 9, it was possible for application and library developers to use internal APIs in the platform that were not intended for such use. With strong encapsulation, these internal APIs can be truly hidden. This can be problematic when migrating code to Java 9—this issue is being dealt with via deprecation and new comparable public APIs.</p>
#
# <p><strong>Improved performance</strong>—The JVM uses various optimization techniques to improve application performance. <a href="https://www.jcp.org/en/jsr/detail?id=376">JSR 376</a> indicates that these techniques are more effective when it’s known in advance that required types are located only in specific modules.</p>
#
# <p>Other benefits of modularity include:</p>
#
# <p><strong>Eliminating "classpath hell"</strong>—Prior to modularity, developers used the classpath to specify libraries for use at compilation and execution time. Most developers have experienced classpath problems, some to the extent that the term “classpath hell” was coined to describe them. With modularity, developers switch from using the classpath to using the module path, which eliminates the vast majority of classpath-related problems.</p>
#
# <p><strong>Better system designs</strong>—You may find that modularity helps you come up with cleaner, more logical designs.</p>
#
# <h2>About O'Reilly's live online training</h2>
#
# <p>Since launching <a href="https://www.safaribooksonline.com/live-training/?utm_source=oreilly&amp;utm_medium=newsite&amp;utm_campaign=get-introduced-jpms-deitel-body-text-cta">live online training courses</a> in December, 2016, O'Reilly has trained over 14,000 people in more than 150 courses, including <em>Docker: Up and Running</em>, <em>Designing for Voice: Conversational UI</em>, <em>Python: Beyond the Basics</em>, <em>High-Performance TensorFlow in Production</em>, and <em>Design Thinking: Practice and Measurement Essentials</em>.</p>
# <p>Continue reading <a href="https://www.oreilly.com/learning/get-introduced-to-the-java-9-platform-module-system-with-paul-deitel">Get introduced to the new Java® 9 Platform Module System (JPMS) with Paul Deitel.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/jYJhY8Q41a0" width="1" />
# Jupyter Digest: 15 May 2017
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/Wbxtv1PWx4g/jupyter-digest-15-may-2017
# <p><img src="https://d3tdunqjn7n0wj.cloudfront.net/600x450/jupyter_digest_1400x950_vc-0e3d158b1ef12913af3c1fca4137b977.png" /></p><p><em>TSFRESH, 100 days of algorithms, how JupyterHub tamed big science, colorizing photos.</em></p><ul>
# 	<li>
# <a href="https://github.com/blue-yonder/tsfresh">TSFRESH</a>. TSFRESH is a "time series feature extraction based on scalable hypothesis tests." In layman's terms, it finds interesting things on a time-series chart for you automatically. The <a href="https://github.com/blue-yonder/tsfresh/tree/master/notebooks">notebooks</a> folder has Jupyter examples that show how to use it in your work, like this one that <a href="https://github.com/blue-yonder/tsfresh/blob/master/notebooks/human_activity_recognition_example.ipynb">uses accelerometer data</a> to figure out when you're walking, climbing stairs, or just doing nothing at all. (Submitted anonymously.)</li>
# 	<li>
# <a href="https://github.com/coells/100days">100 Days of Algorithms</a>. Tomáš Bouda (@<a href="https://github.com/coells">coells</a> on GitHub) compiles a nice list of examples that illustrate a host of different algorithms with Python. If a title like "<a href="https://github.com/coells/100days/blob/master/day%2014%20-%20huffman%20codes.ipynb">Day 14 - huffman codes.ipynb</a>" lights you up, then you're gonna love this (times 100). Also, bravo for not calling it "50 algorithms to whiteboard before you die."</li>
# 	<li>
# <a href="https://conferences.oreilly.com/jupyter/jup-ny/public/schedule/detail/60085?intcmp=il-data-confreg-update-jpny17_new_site_jupyter_digest_051517_body_text_cta">How JupyterHub tamed big science: Experiences deploying Jupyter at a supercomputing center</a>. If you're trying to deploy Jupyter at scale in your org, then this session at the upcoming <a href="https://conferences.oreilly.com/jupyter/jup-ny?intcmp=il-data-confreg-update-jpny17_new_site_jupyter_digest_051517_body_text_cta">JupyterCon</a> (Aug 22-23 in NYC) will be the place to be to learn how.</li>
# 	<li>
# <a href="https://github.com/junyanz/interactive-deep-colorization">Interactive Deep Colorization</a>. <a href="https://richzhang.github.io/">Richard Zhang</a>, a PhD candidate at UC Berkeley, uses this <a href="https://github.com/junyanz/interactive-deep-colorization/blob/master/DemoGlobalHistogramTransfer.ipynb">notebook to illustrate a technique he's developed</a> to colorize black and white photos (see below). Take that, <a href="https://en.wikipedia.org/wiki/Dorothea_Lange">Dorothea Lang</a>.</li>
# </ul>
#
# <p> </p>
#
# <div class="responsive-video"></div>
#
# <p> </p>
# <p>Continue reading <a href="https://www.oreilly.com/ideas/jupyter-digest-15-may-2017">Jupyter Digest: 15 May 2017.</a></p><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/Wbxtv1PWx4g" width="1" />

# %% [markdown]
# ## Example 3. Pseudocode for a breadth-first search

# %%
Create an empty graph
Create an empty queue to keep track of nodes that need to be processed

Add the starting point to the graph as the root node
Add the root node to a queue for processing

Repeat until some maximum depth is reached or the queue is empty:
  Remove a node from the queue 
  For each of the node's neighbors: 
    If the neighbor hasn't already been processed: 
      Add it to the queue 
      Add it to the graph 
      Create an edge in the graph that connects the node and its neighbor

# %% [markdown]
# **Naive sentence detection based on periods**

# %%
txt = "Mr. Green killed Colonel Mustard in the study with the candlestick. Mr. Green is not a very nice fellow."
print txt.split(".")
# Out:
# ['Mr', ' Green killed Colonel Mustard in the study with the candlestick', ' Mr', ' Green is not a very nice fellow', '']

# %% [markdown]
# **More sophisticated sentence detection**

# %%
import nltk

# Downloading nltk packages used in this example
nltk.download('punkt')

sentences = nltk.tokenize.sent_tokenize(txt)
print sentences
# Out:
# [nltk_data] Downloading package punkt to /Users/santteegt/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['Mr. Green killed Colonel Mustard in the study with the candlestick.', 'Mr. Green is not a very nice fellow.']

# %% [markdown]
# **Tokenization of sentences**

# %%
tokens = [nltk.tokenize.word_tokenize(s) for s in sentences]
print tokens
# Out:
# [['Mr.', 'Green', 'killed', 'Colonel', 'Mustard', 'in', 'the', 'study', 'with', 'the', 'candlestick', '.'], ['Mr.', 'Green', 'is', 'not', 'a', 'very', 'nice', 'fellow', '.']]

# %% [markdown]
# **Part of speech tagging for tokens**

# %%
# Downloading nltk packages used in this example
nltk.download('maxent_treebank_pos_tagger')
nltk.download('averaged_perceptron_tagger')

pos_tagged_tokens = [nltk.pos_tag(t) for t in tokens]
print pos_tagged_tokens
# Out:
# [nltk_data] Downloading package maxent_treebank_pos_tagger to
# [nltk_data]     /Users/santteegt/nltk_data...
# [nltk_data]   Package maxent_treebank_pos_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/santteegt/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [[('Mr.', 'NNP'), ('Green', 'NNP'), ('killed', 'VBD'), ('Colonel', 'NNP'), ('Mustard', 'NNP'), ('in', 'IN'), ('the', 'DT'), ('study', 'NN'), ('with', 'IN'), ('the', 'DT'), ('candlestick', 'NN'), ('.', '.')], [('Mr.', 'NNP'), ('Green', 'NNP'), ('is', 'VBZ'), ('not', 'RB'), ('a', 'DT'), ('very', 'RB'), ('nice', 'JJ'), ('fellow', 'NN'), ('.', '.')]]

# %% [markdown]
# **Named entity extraction/chunking for tokens**

# %%
# Downloading nltk packages used in this example
nltk.download('maxent_ne_chunker')
nltk.download('words')

# ne_chunks = nltk.batch_ne_chunk(pos_tagged_tokens)
ne_chunks = nltk.ne_chunk_sents(pos_tagged_tokens)

for chunk in ne_chunks:
    print chunk
# print ne_chunks
# print ne_chunks[0].pprint() # You can prettyprint each chunk in the tree
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/santteegt/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /Users/santteegt/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# (S
#   (PERSON Mr./NNP)
#   (PERSON Green/NNP)
#   killed/VBD
#   (ORGANIZATION Colonel/NNP Mustard/NNP)
#   in/IN
#   the/DT
#   study/NN
#   with/IN
#   the/DT
#   candlestick/NN
#   ./.)
# (S
#   (PERSON Mr./NNP)
#   (ORGANIZATION Green/NNP)
#   is/VBZ
#   not/RB
#   a/DT
#   very/RB
#   nice/JJ
#   fellow/NN
#   ./.)

# %% [markdown]
# ## Example 4. Harvesting blog data by parsing feeds

# %%
import os
import sys
import json
import feedparser
# from BeautifulSoup import BeautifulStoneSoup
from bs4 import BeautifulSoup
from nltk import clean_html

FEED_URL = 'http://feeds.feedburner.com/oreilly/radar/atom'

def cleanHtml(html):
    if html == "": return ""

    soup = BeautifulSoup(html, 'lxml').get_text()
  
    return soup
#     return BeautifulStoneSoup(clean_html(html),
#                 convertEntities=BeautifulStoneSoup.HTML_ENTITIES).contents[0]

fp = feedparser.parse(FEED_URL)

print "Fetched %s entries from '%s'" % (len(fp.entries[0].title), fp.feed.title)

blog_posts = []
for e in fp.entries:
    blog_posts.append({'title': e.title, 'content'
                      : cleanHtml(e.content[0].value), 'link': e.links[0].href})

out_file = os.path.join('resources', 'ch05-webpages', 'feed.json')
f = open(out_file, 'w')
f.write(json.dumps(blog_posts, indent=1))
f.close()

print 'Wrote output file to %s' % (f.name, )
# Out:
# Fetched 29 entries from 'All - O'Reilly Media'
# Wrote output file to resources/ch05-webpages/feed.json

# %% [markdown]
# ## Example 5. Using NLTK’s NLP tools to process human language in blog data

# %%
import json
import nltk

# Download nltk packages used in this example
nltk.download('stopwords')

BLOG_DATA = "resources/ch05-webpages/feed.json"

blog_data = json.loads(open(BLOG_DATA).read())

# Customize your list of stopwords as needed. Here, we add common
# punctuation and contraction artifacts.

stop_words = nltk.corpus.stopwords.words('english') + [
    '.',
    ',',
    '--',
    '\'s',
    '?',
    ')',
    '(',
    ':',
    '\'',
    '\'re',
    '"',
    '-',
    '}',
    '{',
    u'—',
    ]

print 'English stop words:'
print stop_words

for post in blog_data:
    sentences = nltk.tokenize.sent_tokenize(post['content'])

    words = [w.lower() for sentence in sentences for w in
             nltk.tokenize.word_tokenize(sentence)]

    fdist = nltk.FreqDist(words)

    # Basic stats

    num_words = sum([i[1] for i in fdist.items()])
    num_unique_words = len(fdist.keys())

    # Hapaxes are words that appear only once

    num_hapaxes = len(fdist.hapaxes())

    top_10_words_sans_stop_words = sorted([w for w in fdist.items() if w[0]
                                    not in stop_words], key=lambda x: x[1], reverse=True)[:10]

    print post['title']
    print '\tNum Sentences:'.ljust(25), len(sentences)
    print '\tNum Words:'.ljust(25), num_words
    print '\tNum Unique Words:'.ljust(25), num_unique_words
    print '\tNum Hapaxes:'.ljust(25), num_hapaxes
    print '\tTop 10 Most Frequent Words (sans stop words):\n\t\t', \
            '\n\t\t'.join(['%s (%s)'
            % (w[0], w[1]) for w in top_10_words_sans_stop_words])
    print
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/santteegt/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# English stop words:
# [u'i', u'me', u'my', u'myself', u'we', u'our', u'ours', u'ourselves', u'you', u'your', u'yours', u'yourself', u'yourselves', u'he', u'him', u'his', u'himself', u'she', u'her', u'hers', u'herself', u'it', u'its', u'itself', u'they', u'them', u'their', u'theirs', u'themselves', u'what', u'which', u'who', u'whom', u'this', u'that', u'these', u'those', u'am', u'is', u'are', u'was', u'were', u'be', u'been', u'being', u'have', u'has', u'had', u'having', u'do', u'does', u'did', u'doing', u'a', u'an', u'the', u'and', u'but', u'if', u'or', u'because', u'as', u'until', u'while', u'of', u'at', u'by', u'for', u'with', u'about', u'against', u'between', u'into', u'through', u'during', u'before', u'after', u'above', u'below', u'to', u'from', u'up', u'down', u'in', u'out', u'on', u'off', u'over', u'under', u'again', u'further', u'then', u'once', u'here', u'there', u'when', u'where', u'why', u'how', u'all', u'any', u'both', u'each', u'few', u'more', u'most', u'other', u'some', u'such', u'no', u'nor', u'not', u'only', u'own', u'same', u'so', u'than', u'too', u'very', u's', u't', u'can', u'will', u'just', u'don', u'should', u'now', u'd', u'll', u'm', u'o', u're', u've', u'y', u'ain', u'aren', u'couldn', u'didn', u'doesn', u'hadn', u'hasn', u'haven', u'isn', u'ma', u'mightn', u'mustn', u'needn', u'shan', u'shouldn', u'wasn', u'weren', u'won', u'wouldn', '.', ',', '--', "'s", '?', ')', '(', ':', "'", "'re", '"', '-', '}', '{', u'\u2014']
# Four short links: 30 May 2017
# 	Num Sentences:           11
# 	Num Words:               412
# 	Num Unique Words:        228
# 	Num Hapaxes:             164
# 	Top 10 Most Frequent Words (sans stop words):
# 		hypothesis (5)
# 		story (5)
# 		pacemaker (5)
# 		security (4)
# 		common (3)
# 		open (3)
# 		source (3)
# 		sense (3)
# 		medical (3)
# 		oss (2)
#
# Jupyter Digest: 30 May 2017
# 	Num Sentences:           14
# 	Num Words:               241
# 	Num Unique Words:        133
# 	Num Hapaxes:             95
# 	Top 10 Most Frequent Words (sans stop words):
# 		notebooks (8)
# 		learning (5)
# 		tensorflow (5)
# 		machine (5)
# 		`` (4)
# 		'' (4)
# 		companion (4)
# 		transportation (3)
# 		jupyter (3)
# 		rnns (2)
#
# Jupyter Insights: Carol Willing, director of the Python Software Foundation
# 	Num Sentences:           39
# 	Num Words:               685
# 	Num Unique Words:        300
# 	Num Hapaxes:             206
# 	Top 10 Most Frequent Words (sans stop words):
# 		jupyter (20)
# 		jupyterhub (5)
# 		software (5)
# 		work (5)
# 		using (4)
# 		projects (4)
# 		team (4)
# 		notebook (4)
# 		jupytercon (4)
# 		notebooks (3)
#
# How do I configure a Cisco router for secure remote access using SSH?
# 	Num Sentences:           1
# 	Num Words:               42
# 	Num Unique Words:        33
# 	Num Hapaxes:             24
# 	Top 10 Most Frequent Words (sans stop words):
# 		cisco (2)
# 		secure (2)
# 		ssh (2)
# 		router (2)
# 		accept (1)
# 		connections (1)
# 		shell (1)
# 		lines.continue (1)
# 		access (1)
# 		virtual (1)
#
# How do I recover the password on a Cisco router without losing its configuration?
# 	Num Sentences:           1
# 	Num Words:               36
# 	Num Unique Words:        28
# 	Num Hapaxes:             20
# 	Top 10 Most Frequent Words (sans stop words):
# 		configuration (2)
# 		losing (2)
# 		password (2)
# 		without (2)
# 		router (2)
# 		cisco (1)
# 		recover (1)
# 		configurations.continue (1)
# 		reading (1)
# 		recovered (1)
#
# What is the OSI model?
# 	Num Sentences:           2
# 	Num Words:               28
# 	Num Unique Words:        23
# 	Num Hapaxes:             18
# 	Top 10 Most Frequent Words (sans stop words):
# 		osi (2)
# 		model (2)
# 		concept (1)
# 		communicate—the (1)
# 		single (1)
# 		networking (1)
# 		helps (1)
# 		reading (1)
# 		systems (1)
# 		may (1)
#
# Four short links: 29 May 2017
# 	Num Sentences:           21
# 	Num Words:               472
# 	Num Unique Words:        266
# 	Num Hapaxes:             198
# 	Top 10 Most Frequent Words (sans stop words):
# 		datalog (7)
# 		game (5)
# 		learn (4)
# 		deepmind (3)
# 		grice (3)
# 		verified (3)
# 		sure (3)
# 		maxims (3)
# 		alphago (3)
# 		leads (2)
#
# Intelligent Bits: 26 May 2017
# 	Num Sentences:           8
# 	Num Words:               177
# 	Num Unique Words:        122
# 	Num Hapaxes:             99
# 	Top 10 Most Frequent Words (sans stop words):
# 		technological (2)
# 		styles (2)
# 		pricing (2)
# 		learning (2)
# 		transfer (2)
# 		much (2)
# 		route-based (2)
# 		productivity (2)
# 		machine (2)
# 		recipe (1)
#
# Four short links: 26 May 2017
# 	Num Sentences:           11
# 	Num Words:               223
# 	Num Unique Words:        136
# 	Num Hapaxes:             97
# 	Top 10 Most Frequent Words (sans stop words):
# 		service (5)
# 		critical (4)
# 		dependencies (4)
# 		data (4)
# 		availability (3)
# 		learning (3)
# 		deep (3)
# 		% (3)
# 		source (2)
# 		available (2)
#
# Running a word count application using Spark
# 	Num Sentences:           1
# 	Num Words:               23
# 	Num Unique Words:        22
# 	Num Hapaxes:             21
# 	Top 10 Most Frequent Words (sans stop words):
# 		spark (2)
# 		application (1)
# 		dataset (1)
# 		’ (1)
# 		use (1)
# 		distributed (1)
# 		api.continue (1)
# 		resilient (1)
# 		reading (1)
# 		count (1)
#
# Peeking into the black box: Lessons from the front lines of machine-learning product launches
# 	Num Sentences:           1
# 	Num Words:               28
# 	Num Unique Words:        24
# 	Num Hapaxes:             20
# 	Top 10 Most Frequent Words (sans stop words):
# 		lessons (2)
# 		machine-learning (2)
# 		experiments.continue (1)
# 		shares (1)
# 		black (1)
# 		learned (1)
# 		product (1)
# 		running (1)
# 		interpreting (1)
# 		huang (1)
#
# Using AI to create new jobs
# 	Num Sentences:           1
# 	Num Words:               41
# 	Num Unique Words:        37
# 	Num Hapaxes:             33
# 	Top 10 Most Frequent Words (sans stop words):
# 		ai (2)
# 		right (1)
# 		speculates (1)
# 		past (1)
# 		looks (1)
# 		’ (1)
# 		transitions (1)
# 		us (1)
# 		create (1)
# 		tim (1)
#
# Lessons from piloting the London Office of Data Analytics
# 	Num Sentences:           1
# 	Num Words:               38
# 	Num Unique Words:        29
# 	Num Hapaxes:             22
# 	Top 10 Most Frequent Words (sans stop words):
# 		data (3)
# 		office (2)
# 		analytics (2)
# 		london (2)
# 		sector (1)
# 		eddie (1)
# 		analyzing (1)
# 		copeland (1)
# 		city (1)
# 		overcame (1)
#
# Enabling data science in the enterprise
# 	Num Sentences:           1
# 	Num Words:               33
# 	Num Unique Words:        29
# 	Num Hapaxes:             25
# 	Top 10 Most Frequent Words (sans stop words):
# 		data (2)
# 		science (2)
# 		office (1)
# 		accurate (1)
# 		statistical (1)
# 		research.continue (1)
# 		statistics (1)
# 		create (1)
# 		smith (1)
# 		tom (1)
#
# Is finance ready for AI?
# 	Num Sentences:           1
# 	Num Words:               21
# 	Num Unique Words:        20
# 	Num Hapaxes:             19
# 	Top 10 Most Frequent Words (sans stop words):
# 		play (1)
# 		world.continue (1)
# 		explores (1)
# 		finance (1)
# 		ai (1)
# 		might (1)
# 		aida (1)
# 		artificial (1)
# 		role (1)
# 		ready (1)
#
# Accelerate analytics and AI innovations with Intel
# 	Num Sentences:           1
# 	Num Words:               34
# 	Num Unique Words:        28
# 	Num Hapaxes:             24
# 	Top 10 Most Frequent Words (sans stop words):
# 		learning (2)
# 		intel (2)
# 		ai (1)
# 		deep (1)
# 		innovations (1)
# 		challenges (1)
# 		analytics (1)
# 		scale (1)
# 		shares (1)
# 		machine (1)
#
# Data science and deep learning in retail
# 	Num Sentences:           5
# 	Num Words:               135
# 	Num Unique Words:        82
# 	Num Hapaxes:             59
# 	Top 10 Most Frequent Words (sans stop words):
# 		data (6)
# 		instacart (4)
# 		stores (3)
# 		stanley (3)
# 		show (2)
# 		learning (2)
# 		’ (2)
# 		jeremy (2)
# 		products (2)
# 		customers (2)
#
# Travis Lowdermilk and Jessica Rich on building a customer-driven culture at Microsoft
# 	Num Sentences:           2
# 	Num Words:               97
# 	Num Unique Words:        64
# 	Num Hapaxes:             47
# 	Top 10 Most Frequent Words (sans stop words):
# 		rich (3)
# 		lowdermilk (3)
# 		customer (3)
# 		microsoft (3)
# 		travis (2)
# 		design (2)
# 		’ (2)
# 		jessica (2)
# 		ux (2)
# 		healthy (2)
#
# JupyterLab: The evolution of the Jupyter web interface
# 	Num Sentences:           79
# 	Num Words:               1865
# 	Num Unique Words:        573
# 	Num Hapaxes:             351
# 	Top 10 Most Frequent Words (sans stop words):
# 		notebook (27)
# 		jupyterlab (23)
# 		jupyter (23)
# 		data (14)
# 		’ (12)
# 		work (10)
# 		working (9)
# 		users (9)
# 		notebooks (8)
# 		classic (8)
#
# Jason Laska and Michael Akilian on using AI to schedule meetings
# 	Num Sentences:           6
# 	Num Words:               208
# 	Num Unique Words:        119
# 	Num Hapaxes:             87
# 	Top 10 Most Frequent Words (sans stop words):
# 		’ (6)
# 		akilian (3)
# 		e-mail (3)
# 		laska (3)
# 		clara (3)
# 		bots (3)
# 		jason (2)
# 		meetings (2)
# 		still (2)
# 		reilly (2)
#
# Four short links: 25 May 2017
# 	Num Sentences:           13
# 	Num Words:               398
# 	Num Unique Words:        218
# 	Num Hapaxes:             157
# 	Top 10 Most Frequent Words (sans stop words):
# 		’ (5)
# 		data (5)
# 		web (4)
# 		used (4)
# 		crypto (3)
# 		system (3)
# 		information (3)
# 		distort (2)
# 		finance (2)
# 		security (2)
#
# Real-time intelligence gives Uber the edge
# 	Num Sentences:           1
# 	Num Words:               31
# 	Num Unique Words:        26
# 	Num Hapaxes:             22
# 	Top 10 Most Frequent Words (sans stop words):
# 		uber (3)
# 		real-time (2)
# 		smooth.continue (1)
# 		intelligence (1)
# 		covers (1)
# 		srivas (1)
# 		explores (1)
# 		needs (1)
# 		make (1)
# 		m. (1)
#
# Another one bytes the dust
# 	Num Sentences:           1
# 	Num Words:               34
# 	Num Unique Words:        31
# 	Num Hapaxes:             29
# 	Top 10 Most Frequent Words (sans stop words):
# 		modern (1)
# 		bring (1)
# 		another (1)
# 		paul (1)
# 		information (1)
# 		make (1)
# 		brook (1)
# 		music (1)
# 		way (1)
# 		new (1)
#
# Machine learning is a moonshot for us all
# 	Num Sentences:           1
# 	Num Words:               37
# 	Num Unique Words:        34
# 	Num Hapaxes:             31
# 	Top 10 Most Frequent Words (sans stop words):
# 		moonshot (1)
# 		one (1)
# 		computer (1)
# 		learning (1)
# 		asks (1)
# 		darren (1)
# 		machine (1)
# 		strange (1)
# 		play (1)
# 		sure (1)
#
# The data subject first?
# 	Num Sentences:           1
# 	Num Words:               28
# 	Num Unique Words:        24
# 	Num Hapaxes:             22
# 	Top 10 Most Frequent Words (sans stop words):
# 		data (3)
# 		right (1)
# 		pols (1)
# 		philosophical (1)
# 		aurélie (1)
# 		hones (1)
# 		subject (1)
# 		draws (1)
# 		broad (1)
# 		portability.continue (1)
#
# What Kaggle has learned from almost a million data scientists
# 	Num Sentences:           1
# 	Num Words:               33
# 	Num Unique Words:        29
# 	Num Hapaxes:             25
# 	Top 10 Most Frequent Words (sans stop words):
# 		learned (2)
# 		kaggle (2)
# 		goldbloom (1)
# 		almost (1)
# 		community (1)
# 		techniques (1)
# 		lessons (1)
# 		top (1)
# 		shares (1)
# 		machine-learning (1)
#
# Highlights from Strata Data Conference in London 2017
# 	Num Sentences:           30
# 	Num Words:               566
# 	Num Unique Words:        237
# 	Num Hapaxes:             149
# 	Top 10 Most Frequent Words (sans stop words):
# 		data (20)
# 		watch (13)
# 		`` (12)
# 		'' (12)
# 		ai (7)
# 		london (6)
# 		lessons (6)
# 		learning (6)
# 		science (6)
# 		analytics (5)
#
# The science of visual interactions
# 	Num Sentences:           1
# 	Num Words:               30
# 	Num Unique Words:        26
# 	Num Hapaxes:             23
# 	Top 10 Most Frequent Words (sans stop words):
# 		videos (1)
# 		learning (1)
# 		images (1)
# 		redi (1)
# 		detect (1)
# 		creativity (1)
# 		machine (1)
# 		reading (1)
# 		beauty (1)
# 		interactions (1)
#
# 12 qualities of effective design organizations
# 	Num Sentences:           299
# 	Num Words:               7470
# 	Num Unique Words:        1802
# 	Num Hapaxes:             1108
# 	Top 10 Most Frequent Words (sans stop words):
# 		design (151)
# 		’ (88)
# 		team (76)
# 		work (48)
# 		organization (38)
# 		” (35)
# 		people (35)
# 		“ (35)
# 		quality (27)
# 		designers (23)
#
# Kelly Shortridge on overcoming common missteps affecting security decision-making
# 	Num Sentences:           2
# 	Num Words:               99
# 	Num Unique Words:        66
# 	Num Hapaxes:             46
# 	Top 10 Most Frequent Words (sans stop words):
# 		security (5)
# 		dynamic (2)
# 		common (2)
# 		decision (2)
# 		build (2)
# 		shortridge (2)
# 		defenses (2)
# 		decision-making (2)
# 		trees (2)
# 		ux (2)
#
# 5 things to learn before learning React
# 	Num Sentences:           6
# 	Num Words:               185
# 	Num Unique Words:        118
# 	Num Hapaxes:             93
# 	Top 10 Most Frequent Words (sans stop words):
# 		react (8)
# 		easier (2)
# 		skills (2)
# 		set (2)
# 		people (2)
# 		list (2)
# 		javascript (2)
# 		learning (2)
# 		much (2)
# 		learn (2)
#
# Reliability with Kafka
# 	Num Sentences:           5
# 	Num Words:               108
# 	Num Unique Words:        71
# 	Num Hapaxes:             48
# 	Top 10 Most Frequent Words (sans stop words):
# 		kafka (4)
# 		’ (3)
# 		gwen (2)
# 		exciting (2)
# 		use (2)
# 		cases (2)
# 		shapira (2)
# 		talk (2)
# 		particularly (1)
# 		kafka—why (1)
#
# Four short links: 24 May 2017
# 	Num Sentences:           12
# 	Num Words:               298
# 	Num Unique Words:        178
# 	Num Hapaxes:             132
# 	Top 10 Most Frequent Words (sans stop words):
# 		justice (5)
# 		travel (5)
# 		mode (4)
# 		word (4)
# 		voice (4)
# 		threat (3)
# 		sentence (2)
# 		via (2)
# 		also (2)
# 		phonemes (2)
#
# Four short links: 23 May 2017
# 	Num Sentences:           8
# 	Num Words:               157
# 	Num Unique Words:        109
# 	Num Hapaxes:             87
# 	Top 10 Most Frequent Words (sans stop words):
# 		patent (4)
# 		classification (3)
# 		tensorflow (3)
# 		face (3)
# 		cookbook (3)
# 		code (2)
# 		texas (2)
# 		% (2)
# 		welcome (2)
# 		newcomers (2)
#
# Jupyter Digest: 22 May 2017
# 	Num Sentences:           17
# 	Num Words:               254
# 	Num Unique Words:        136
# 	Num Hapaxes:             87
# 	Top 10 Most Frequent Words (sans stop words):
# 		python (5)
# 		notebooks (4)
# 		series (4)
# 		software (4)
# 		source (3)
# 		carpentry (3)
# 		jupyter (3)
# 		also (2)
# 		overthinking (2)
# 		@ (2)
#
# Four short links: 22 May 2017
# 	Num Sentences:           10
# 	Num Words:               316
# 	Num Unique Words:        182
# 	Num Hapaxes:             133
# 	Top 10 Most Frequent Words (sans stop words):
# 		facebook (6)
# 		indigenous (3)
# 		game (3)
# 		via (3)
# 		feel (3)
# 		“ (3)
# 		@ (2)
# 		online (2)
# 		tutorial (2)
# 		learn (2)
#
# Intelligent Bits: 19 May 2017
# 	Num Sentences:           8
# 	Num Words:               166
# 	Num Unique Words:        118
# 	Num Hapaxes:             98
# 	Top 10 Most Frequent Words (sans stop words):
# 		photo (3)
# 		apple (3)
# 		editing (3)
# 		ai (3)
# 		data (3)
# 		dark (3)
# 		studio (2)
# 		automl (2)
# 		results (1)
# 		brain (1)
#
# Four short links: 19 May 2017
# 	Num Sentences:           8
# 	Num Words:               166
# 	Num Unique Words:        108
# 	Num Hapaxes:             78
# 	Top 10 Most Frequent Words (sans stop words):
# 		drawings (2)
# 		web (2)
# 		get (2)
# 		ones (2)
# 		traffic (2)
# 		fallibility (2)
# 		sketches (2)
# 		best (2)
# 		algorithmic (2)
# 		pendulum (2)
#
# Activating human intrusion detection systems
# 	Num Sentences:           1
# 	Num Words:               17
# 	Num Unique Words:        17
# 	Num Hapaxes:             17
# 	Top 10 Most Frequent Words (sans stop words):
# 		blue (1)
# 		building (1)
# 		security (1)
# 		intrusion (1)
# 		expanding (1)
# 		systems (1)
# 		detection (1)
# 		culture (1)
# 		human (1)
# 		team (1)
#
# Exploring progressive web apps in the real world
# 	Num Sentences:           1
# 	Num Words:               20
# 	Num Unique Words:        19
# 	Num Hapaxes:             18
# 	Top 10 Most Frequent Words (sans stop words):
# 		real (1)
# 		exploring (1)
# 		world (1)
# 		reading (1)
# 		progressive (1)
# 		mobile (1)
# 		apps (1)
# 		companies (1)
# 		experiences (1)
# 		apps.continue (1)
#
# How to write a sound hypothesis when conducting user research
# 	Num Sentences:           1
# 	Num Words:               28
# 	Num Unique Words:        24
# 	Num Hapaxes:             20
# 	Top 10 Most Frequent Words (sans stop words):
# 		hypothesis (2)
# 		examples (1)
# 		unsuccessful (1)
# 		hypotheses.continue (1)
# 		shares (1)
# 		research (1)
# 		write (1)
# 		alvarez (1)
# 		reading (1)
# 		sound (1)
#
# How AI is used to infer human emotion
# 	Num Sentences:           61
# 	Num Words:               1397
# 	Num Unique Words:        524
# 	Num Hapaxes:             342
# 	Top 10 Most Frequent Words (sans stop words):
# 		emotion (19)
# 		data (13)
# 		emotional (11)
# 		ai (11)
# 		technology (10)
# 		expressions (9)
# 		facial (8)
# 		use (7)
# 		learning (7)
# 		applications (6)
#
# Paris Buttfield-Addison on what’s new in Swift programming
# 	Num Sentences:           2
# 	Num Words:               95
# 	Num Unique Words:        59
# 	Num Hapaxes:             39
# 	Top 10 Most Frequent Words (sans stop words):
# 		swift (5)
# 		’ (3)
# 		programming (3)
# 		video (2)
# 		learning (2)
# 		podcast (2)
# 		buttfield-addison (2)
# 		paris (2)
# 		reilly (2)
# 		mobile (2)
#
# Four short links: 18 May 2017
# 	Num Sentences:           13
# 	Num Words:               282
# 	Num Unique Words:        180
# 	Num Hapaxes:             136
# 	Top 10 Most Frequent Words (sans stop words):
# 		; (5)
# 		fact-checkers (4)
# 		fact-checking (3)
# 		java (3)
# 		checking (2)
# 		mathematics (2)
# 		agreement (2)
# 		language (2)
# 		social (2)
# 		feed (2)
#
# Using Docker in production
# 	Num Sentences:           11
# 	Num Words:               280
# 	Num Unique Words:        151
# 	Num Hapaxes:             108
# 	Top 10 Most Frequent Words (sans stop words):
# 		docker (12)
# 		years (3)
# 		using (3)
# 		bit (3)
# 		really (3)
# 		container (3)
# 		orchestration (3)
# 		tools (3)
# 		ecosystem (3)
# 		focus (2)
#
# How do I build an API?
# 	Num Sentences:           2
# 	Num Words:               25
# 	Num Unique Words:        22
# 	Num Hapaxes:             19
# 	Top 10 Most Frequent Words (sans stop words):
# 		build (2)
# 		application (1)
# 		api (1)
# 		web (1)
# 		reading (1)
# 		apis (1)
# 		interfaces (1)
# 		programming (1)
# 		traditional (1)
# 		continue (1)
#
# How do I use an API?
# 	Num Sentences:           1
# 	Num Words:               23
# 	Num Unique Words:        21
# 	Num Hapaxes:             19
# 	Top 10 Most Frequent Words (sans stop words):
# 		use (2)
# 		application (1)
# 		different (1)
# 		interfaces (1)
# 		apis (1)
# 		programming (1)
# 		api (1)
# 		learn (1)
# 		.continue (1)
# 		reading (1)
#
# What is an API?
# 	Num Sentences:           2
# 	Num Words:               30
# 	Num Unique Words:        26
# 	Num Hapaxes:             23
# 	Top 10 Most Frequent Words (sans stop words):
# 		api (1)
# 		underlying (1)
# 		technology (1)
# 		application (1)
# 		reading (1)
# 		apis (1)
# 		interfaces (1)
# 		learn (1)
# 		purpose (1)
# 		key (1)
#
# How to do client-side form validation with Elm
# 	Num Sentences:           7
# 	Num Words:               165
# 	Num Unique Words:        100
# 	Num Hapaxes:             71
# 	Top 10 Most Frequent Words (sans stop words):
# 		’ (4)
# 		validation (4)
# 		form (3)
# 		error (3)
# 		user (3)
# 		elm (2)
# 		easy (2)
# 		messages (2)
# 		service (2)
# 		need (2)
#
# The stages of enterprise IoT adoption
# 	Num Sentences:           1
# 	Num Words:               20
# 	Num Unique Words:        18
# 	Num Hapaxes:             16
# 	Top 10 Most Frequent Words (sans stop words):
# 		building (1)
# 		stages (1)
# 		business (1)
# 		things.continue (1)
# 		teresa (1)
# 		case (1)
# 		adoption (1)
# 		enterprise (1)
# 		internet (1)
# 		reading (1)
#
# Four short links: 17 May 2017
# 	Num Sentences:           13
# 	Num Words:               376
# 	Num Unique Words:        223
# 	Num Hapaxes:             172
# 	Top 10 Most Frequent Words (sans stop words):
# 		cloud (4)
# 		pricing (3)
# 		; (3)
# 		learning (3)
# 		apps (3)
# 		imitation (3)
# 		’ (3)
# 		models (3)
# 		usage (2)
# 		summary (2)
#
# Augmenting industrial reality
# 	Num Sentences:           11
# 	Num Words:               185
# 	Num Unique Words:        122
# 	Num Hapaxes:             95
# 	Top 10 Most Frequent Words (sans stop words):
# 		ar (4)
# 		’ (3)
# 		systems (2)
# 		poised (2)
# 		big (2)
# 		creating (2)
# 		make (2)
# 		reality (2)
# 		building (2)
# 		space (2)
#
# Four short links: 16 May 2017
# 	Num Sentences:           20
# 	Num Words:               513
# 	Num Unique Words:        282
# 	Num Hapaxes:             209
# 	Top 10 Most Frequent Words (sans stop words):
# 		data (10)
# 		media (5)
# 		organizations (4)
# 		flash (3)
# 		individuals (3)
# 		users (3)
# 		economics (3)
# 		use (3)
# 		work (3)
# 		’ (3)
#
# Architecting actionable insights
# 	Num Sentences:           1
# 	Num Words:               27
# 	Num Unique Words:        26
# 	Num Hapaxes:             25
# 	Top 10 Most Frequent Words (sans stop words):
# 		forecasting (1)
# 		geerdink (1)
# 		ing (1)
# 		technology (1)
# 		outbound (1)
# 		outlines (1)
# 		details (1)
# 		architecting (1)
# 		reading (1)
# 		communications.continue (1)
#
# The business advantages of embedding analytics into applications
# 	Num Sentences:           59
# 	Num Words:               1268
# 	Num Unique Words:        491
# 	Num Hapaxes:             334
# 	Top 10 Most Frequent Words (sans stop words):
# 		data (28)
# 		analytics (26)
# 		’ (16)
# 		embedded (13)
# 		business (8)
# 		product (7)
# 		modern (7)
# 		solutions (7)
# 		; (6)
# 		options (6)
#
# How can I deploy a multi-container application with Docker Compose?
# 	Num Sentences:           1
# 	Num Words:               30
# 	Num Unique Words:        25
# 	Num Hapaxes:             20
# 	Top 10 Most Frequent Words (sans stop words):
# 		multi-container (2)
# 		docker (2)
# 		distribute (1)
# 		development.continue (1)
# 		unit (1)
# 		use (1)
# 		compose (1)
# 		seamless (1)
# 		application (1)
# 		reading (1)
#
# How do I package my Java application as a Docker image using Gradle?
# 	Num Sentences:           1
# 	Num Words:               45
# 	Num Unique Words:        29
# 	Num Hapaxes:             18
# 	Top 10 Most Frequent Words (sans stop words):
# 		java (3)
# 		docker (3)
# 		image (2)
# 		application (2)
# 		package (2)
# 		gradle (2)
# 		use (1)
# 		build (1)
# 		developers (1)
# 		run (1)
#
# How do I create Docker images and run containers using Maven?
# 	Num Sentences:           1
# 	Num Words:               43
# 	Num Unique Words:        31
# 	Num Hapaxes:             22
# 	Top 10 Most Frequent Words (sans stop words):
# 		docker (3)
# 		run (2)
# 		maven (2)
# 		application (1)
# 		image (1)
# 		comprehension (1)
# 		images (1)
# 		use (1)
# 		management (1)
# 		java (1)
#
# Get introduced to the new Java® 9 Platform Module System (JPMS) with Paul Deitel
# 	Num Sentences:           37
# 	Num Words:               872
# 	Num Unique Words:        364
# 	Num Hapaxes:             245
# 	Top 10 Most Frequent Words (sans stop words):
# 		module (18)
# 		’ (13)
# 		platform (11)
# 		java (11)
# 		modules (10)
# 		use (8)
# 		modularity (8)
# 		system (8)
# 		9 (7)
# 		live (6)
#
# Jupyter Digest: 15 May 2017
# 	Num Sentences:           16
# 	Num Words:               269
# 	Num Unique Words:        157
# 	Num Hapaxes:             117
# 	Top 10 Most Frequent Words (sans stop words):
# 		jupyter (4)
# 		algorithms (4)
# 		100 (3)
# 		`` (3)
# 		tsfresh (3)
# 		'' (3)
# 		tamed (2)
# 		big (2)
# 		jupyterhub (2)
# 		like (2)

# %% [markdown]
# ## Example 6. A document summarization algorithm based principally upon sentence detection and frequency analysis within sentences

# %%
import json
import nltk
import numpy

BLOG_DATA = "resources/ch05-webpages/feed.json"

N = 100  # Number of words to consider
CLUSTER_THRESHOLD = 5  # Distance between words to consider
TOP_SENTENCES = 5  # Number of sentences to return for a "top n" summary

# Approach taken from "The Automatic Creation of Literature Abstracts" by H.P. Luhn

def _score_sentences(sentences, important_words):
    scores = []
    sentence_idx = -1

    for s in [nltk.tokenize.word_tokenize(s) for s in sentences]:

        sentence_idx += 1
        word_idx = []

        # For each word in the word list...
        for w in important_words:
            try:
                # Compute an index for where any important words occur in the sentence.

                word_idx.append(s.index(w))
            except ValueError, e: # w not in this particular sentence
                pass

        word_idx.sort()

        # It is possible that some sentences may not contain any important words at all.
        if len(word_idx)== 0: continue

        # Using the word index, compute clusters by using a max distance threshold
        # for any two consecutive words.

        clusters = []
        cluster = [word_idx[0]]
        i = 1
        while i < len(word_idx):
            if word_idx[i] - word_idx[i - 1] < CLUSTER_THRESHOLD:
                cluster.append(word_idx[i])
            else:
                clusters.append(cluster[:])
                cluster = [word_idx[i]]
            i += 1
        clusters.append(cluster)

        # Score each cluster. The max score for any given cluster is the score 
        # for the sentence.

        max_cluster_score = 0
        for c in clusters:
            significant_words_in_cluster = len(c)
            total_words_in_cluster = c[-1] - c[0] + 1
            score = 1.0 * significant_words_in_cluster \
                * significant_words_in_cluster / total_words_in_cluster

            if score > max_cluster_score:
                max_cluster_score = score

#         scores.append((sentence_idx, score))
        scores.append((sentence_idx, max_cluster_score))

    return scores

def summarize(txt):
    sentences = [s for s in nltk.tokenize.sent_tokenize(txt)]
    normalized_sentences = [s.lower() for s in sentences]

    words = [w.lower() for sentence in normalized_sentences for w in
             nltk.tokenize.word_tokenize(sentence)]

    fdist = nltk.FreqDist(words)

    top_n_words = [w[0] for w in sorted(fdist.items(), key=lambda item: item[1], reverse=True) # changed to consider order
            if w[0] not in nltk.corpus.stopwords.words('english')][:N]

    scored_sentences = _score_sentences(normalized_sentences, top_n_words)

    # Summarization Approach 1:
    # Filter out nonsignificant sentences by using the average score plus a
    # fraction of the std dev as a filter

    avg = numpy.mean([s[1] for s in scored_sentences])
    std = numpy.std([s[1] for s in scored_sentences])
    mean_scored = [(sent_idx, score) for (sent_idx, score) in scored_sentences
                   if score > avg + 0.5 * std]

    # Summarization Approach 2:
    # Another approach would be to return only the top N ranked sentences

    top_n_scored = sorted(scored_sentences, key=lambda s: s[1])[-TOP_SENTENCES:]
    top_n_scored = sorted(top_n_scored, key=lambda s: s[0])

    # Decorate the post object with summaries

    return dict(top_n_summary=[sentences[idx] for (idx, score) in top_n_scored],
                mean_scored_summary=[sentences[idx] for (idx, score) in mean_scored])

blog_data = json.loads(open(BLOG_DATA).read())

for post in blog_data:
       
    post.update(summarize(post['content']))

    print post['title']
    print '=' * len(post['title'])
    print
    print 'Top N Summary'
    print '-------------'
    print ' '.join(post['top_n_summary'])
    print
    print 'Mean Scored Summary'
    print '-------------------'
    print ' '.join(post['mean_scored_summary'])
    print
# Out:
# Four short links: 30 May 2017
# =============================
#
# Top N Summary
# -------------
# World Problems, Story AI, Medical Security Horrors, and OSS Fuzz Winning
#
# The World's Biggest Problems -- data for you to consider when you choose to work on Stuff That Matters. The Strong Story Hypothesis and the Directed Perception Hypothesis -- I ask why humans are smarter than other primates, and I hypothesize that an important part of the answer lies in what I call the Strong Story Hypothesis, which holds that storytelling and understanding have a central role in human intelligence. Medical Implants and Hospital Systems are Still Infosec Dumpster Fires (Cory Doctorow) -- has pointers to two writeups of the horrors in various medical systems. OSS Fuzz Improving Open Source -- Google's open source fuzzer has found numerous security vulnerabilities in several critical open source projects: 10 in FreeType2, 17 in FFmpeg, 33 in LibreOffice, 8 in SQLite 3, 10 in GnuTLS, 25 in PCRE2, 9 in gRPC, and 7 in Wireshark. Their criteria for accepting projects: a large user base and/or be critical to Global IT infrastructure.
#
# Mean Scored Summary
# -------------------
# World Problems, Story AI, Medical Security Horrors, and OSS Fuzz Winning
#
# The World's Biggest Problems -- data for you to consider when you choose to work on Stuff That Matters. Medical Implants and Hospital Systems are Still Infosec Dumpster Fires (Cory Doctorow) -- has pointers to two writeups of the horrors in various medical systems. OSS Fuzz Improving Open Source -- Google's open source fuzzer has found numerous security vulnerabilities in several critical open source projects: 10 in FreeType2, 17 in FFmpeg, 33 in LibreOffice, 8 in SQLite 3, 10 in GnuTLS, 25 in PCRE2, 9 in gRPC, and 7 in Wireshark.
#
# Jupyter Digest: 30 May 2017
# ===========================
#
# Top N Summary
# -------------
# Manning's "MEAP" program is great, providing early access to manuscripts as they're being developed. Delivering Transportation Insights using Jupyter Notebooks, Interactive Dashboards, and Apache Spark. This post from Justin Tyberg at IBM shows how to pull a bunch of open source tools together to analyze data for the swank-sounding "Executive Transportation Group" (via @mikeloukides). Another great open Jupyter resource from O'Reilly, and a companion to Hands-On Machine Learning with Scikit-Learn & TensorFlow. Continue reading Jupyter Digest: 30 May 2017.
#
# Mean Scored Summary
# -------------------
# Manning's "MEAP" program is great, providing early access to manuscripts as they're being developed. Delivering Transportation Insights using Jupyter Notebooks, Interactive Dashboards, and Apache Spark. This post from Justin Tyberg at IBM shows how to pull a bunch of open source tools together to analyze data for the swank-sounding "Executive Transportation Group" (via @mikeloukides). Another great open Jupyter resource from O'Reilly, and a companion to Hands-On Machine Learning with Scikit-Learn & TensorFlow.
#
# Jupyter Insights: Carol Willing, director of the Python Software Foundation
# ===========================================================================
#
# Top N Summary
# -------------
# Jupyter as a learning tool, the JupyterHub Project, and Music21.Carol Willing is a director of the Python Software Foundation, a Jupyter Steering Council member, and a geek in residence at FabLab San Diego, where she teaches wearable electronics and software development. Jupyter Notebooks changed the way I learn new concepts, languages, and libraries. I've found that the ability to rapidly prototype and document ideas in the same notebook to be particularly handy. This looks like a fascinating combination of robots, software, and biology to improve collaboration between software engineers and scientists. Continue reading Jupyter Insights: Carol Willing, director of the Python Software Foundation.
#
# Mean Scored Summary
# -------------------
# Jupyter as a learning tool, the JupyterHub Project, and Music21.Carol Willing is a director of the Python Software Foundation, a Jupyter Steering Council member, and a geek in residence at FabLab San Diego, where she teaches wearable electronics and software development. Jupyter Notebooks changed the way I learn new concepts, languages, and libraries. I've found that the ability to rapidly prototype and document ideas in the same notebook to be particularly handy. This looks like a fascinating combination of robots, software, and biology to improve collaboration between software engineers and scientists. Continue reading Jupyter Insights: Carol Willing, director of the Python Software Foundation.
#
# How do I configure a Cisco router for secure remote access using SSH?
# =====================================================================
#
# Top N Summary
# -------------
# Learn the configuration steps required to enable a Cisco router to accept Secure Shell (SSH) connections over the virtual terminal (VTY) lines.Continue reading How do I configure a Cisco router for secure remote access using SSH?.
#
# Mean Scored Summary
# -------------------
#
#
# How do I recover the password on a Cisco router without losing its configuration?
# =================================================================================
#
# Top N Summary
# -------------
# Learn how to change the configuration register so that a router password can be recovered without losing any configurations.Continue reading How do I recover the password on a Cisco router without losing its configuration?.
#
# Mean Scored Summary
# -------------------
#
#
# What is the OSI model?
# ======================
#
# Top N Summary
# -------------
# Learn about what may be the single most important networking concept that helps different systems communicate—the OSI model. Continue reading What is the OSI model?.
#
# Mean Scored Summary
# -------------------
# Learn about what may be the single most important networking concept that helps different systems communicate—the OSI model.
#
# Four short links: 29 May 2017
# =============================
#
# Top N Summary
# -------------
# Formal Correctness, Conversational Maxims, Learn Datalog, and AlphaGo Retires
#
# An Empirical Study on the Correctness of Formally Verified Distributed Systems (Paper a Day) -- the formal verification ensured the protocol was bug free. Google's Three Secrets to Designing Perfect Conversations -- One secret to making sure that line one leads to two, and two leads to three, comes from James Giongola, creative lead on conversation design and voice direction at Google. Learn Datalog Today -- Learn Datalog Today is an interactive tutorial designed to teach you the Datomic dialect of Datalog. Ke Jie will collaborate with DeepMind on the tool, which Hassabis says should give “all players and fans the opportunity to see the game through the lens of AlphaGo.” I certainly hope this happens. If it means the humans never get to learn how to beat the software, then this feels like the engineers using the game rather than loving the game.
#
# Mean Scored Summary
# -------------------
# Formal Correctness, Conversational Maxims, Learn Datalog, and AlphaGo Retires
#
# An Empirical Study on the Correctness of Formally Verified Distributed Systems (Paper a Day) -- the formal verification ensured the protocol was bug free. Google's Three Secrets to Designing Perfect Conversations -- One secret to making sure that line one leads to two, and two leads to three, comes from James Giongola, creative lead on conversation design and voice direction at Google. Ke Jie will collaborate with DeepMind on the tool, which Hassabis says should give “all players and fans the opportunity to see the game through the lens of AlphaGo.” I certainly hope this happens. If it means the humans never get to learn how to beat the software, then this feels like the engineers using the game rather than loving the game.
#
# Intelligent Bits: 26 May 2017
# =============================
#
# Top N Summary
# -------------
# Deep recipe transfer — Many recent results have shown the ability to transfer visual patterns and styles across images. Brick, mortar, and bucks — Google can now associate digital ad campaigns with in-store visits and sales by applying machine learning to its wealth of user data, including geolocation, search history, web browsing, app interactions, and now credit card transaction records. — Uber applies machine learning to route-based pricing in an effort to become more sustainable by predicting how much you’re willing to pay. Phew, false alarm — Contrary to popular outcry about technological dislocation of labor, this think tank argues that more innovation is needed to drive productivity and, therefore, jobs. Continue reading Intelligent Bits: 26 May 2017.
#
# Mean Scored Summary
# -------------------
# Brick, mortar, and bucks — Google can now associate digital ad campaigns with in-store visits and sales by applying machine learning to its wealth of user data, including geolocation, search history, web browsing, app interactions, and now credit card transaction records. Phew, false alarm — Contrary to popular outcry about technological dislocation of labor, this think tank argues that more innovation is needed to drive productivity and, therefore, jobs.
#
# Four short links: 26 May 2017
# =============================
#
# Top N Summary
# -------------
# Internally at Google, we use the following rule of thumb: critical dependencies must offer one additional 9 relative to your service—in the example case, 99.999% availability—because any service will have several critical dependencies, as well as its own idiosyncratic problems. datproject -- open source crypto—guaranteed distributed data share, designed for versioned data sets. It follows the original (entertaining) paper by Leslie Lamport but spells everything out clearly for non-computer-scientists. OpenAI Baselines -- open source implementations of the interesting published algorithms in deep learning. Continue reading Four short links: 26 May 2017.
#
# Mean Scored Summary
# -------------------
# Internally at Google, we use the following rule of thumb: critical dependencies must offer one additional 9 relative to your service—in the example case, 99.999% availability—because any service will have several critical dependencies, as well as its own idiosyncratic problems. datproject -- open source crypto—guaranteed distributed data share, designed for versioned data sets.
#
# Running a word count application using Spark
# ============================================
#
# Top N Summary
# -------------
# How to use Apache Spark’s Resilient Distributed Dataset (RDD) API.Continue reading Running a word count application using Spark.
#
# Mean Scored Summary
# -------------------
#
#
# Peeking into the black box: Lessons from the front lines of machine-learning product launches
# =============================================================================================
#
# Top N Summary
# -------------
# Grace Huang shares lessons learned from running and interpreting machine-learning experiments.Continue reading Peeking into the black box: Lessons from the front lines of machine-learning product launches.
#
# Mean Scored Summary
# -------------------
#
#
# Using AI to create new jobs
# ===========================
#
# Top N Summary
# -------------
# Tim O’Reilly delves into past technological transitions, speculates on the possibilities of AI, and looks at what's keeping us from making the right choices to govern our creations.Continue reading Using AI to create new jobs.
#
# Mean Scored Summary
# -------------------
#
#
# Lessons from piloting the London Office of Data Analytics
# =========================================================
#
# Top N Summary
# -------------
# Eddie Copeland explores how the London Office of Data Analytics overcame the barriers to joining, analyzing, and acting upon public sector data at city scale.Continue reading Lessons from piloting the London Office of Data Analytics.
#
# Mean Scored Summary
# -------------------
#
#
# Enabling data science in the enterprise
# =======================================
#
# Top N Summary
# -------------
# Tom Smith explains how the UK's Office of National Statistics is using data science to create repeatable, accurate, and transferable statistical research.Continue reading Enabling data science in the enterprise.
#
# Mean Scored Summary
# -------------------
#
#
# Is finance ready for AI?
# ========================
#
# Top N Summary
# -------------
# Aida Mehonic explores the role artificial intelligent might play in the financial world.Continue reading Is finance ready for AI?.
#
# Mean Scored Summary
# -------------------
#
#
# Accelerate analytics and AI innovations with Intel
# ==================================================
#
# Top N Summary
# -------------
# Ziya Ma outlines the challenges for applying machine learning and deep learning at scale and shares solutions that Intel has enabled for customers and partners.Continue reading Accelerate analytics and AI innovations with Intel.
#
# Mean Scored Summary
# -------------------
#
#
# Data science and deep learning in retail
# ========================================
#
# Top N Summary
# -------------
# The O’Reilly Data Show Podcast: Jeremy Stanley on hiring and leading machine learning engineers to build world-class data products.In this episode of the Data Show, I spoke with Jeremy Stanley, VP of data science at Instacart, a popular grocery delivery service that is expanding rapidly. As Stanley describes it, Instacart operates a four-sided marketplace comprised of retail stores, products within the stores, shoppers assigned to the stores, and customers who order from Instacart. The objective is to get fresh groceries from popular retailers delivered to customers in a timely fashion. Instacart’s goals land them in the center of the many opportunities and challenges involved in building high-impact data products. Continue reading Data science and deep learning in retail.
#
# Mean Scored Summary
# -------------------
# The O’Reilly Data Show Podcast: Jeremy Stanley on hiring and leading machine learning engineers to build world-class data products.In this episode of the Data Show, I spoke with Jeremy Stanley, VP of data science at Instacart, a popular grocery delivery service that is expanding rapidly.
#
# Travis Lowdermilk and Jessica Rich on building a customer-driven culture at Microsoft
# =====================================================================================
#
# Top N Summary
# -------------
# The O’Reilly Design Podcast: What makes healthy teams healthy, being customer obsessed, and design and research at Microsoft.This week, I sit down with Travis Lowdermilk senior UX designer at Microsoft, and Jessica Rich, UX researcher at Microsoft; Lowdermilk and Rich are also co-authors of the Customer Driven Playbook. We talk about why failing fast is not always a good approach, sensemaking, and never losing track of the customer’s voice.Continue reading Travis Lowdermilk and Jessica Rich on building a customer-driven culture at Microsoft.
#
# Mean Scored Summary
# -------------------
# We talk about why failing fast is not always a good approach, sensemaking, and never losing track of the customer’s voice.Continue reading Travis Lowdermilk and Jessica Rich on building a customer-driven culture at Microsoft.
#
# JupyterLab: The evolution of the Jupyter web interface
# ======================================================
#
# Top N Summary
# -------------
# We recently discussed JupyterLab, how feedback from notebook users informed its design, how its features could benefit the scientific and technical computing communities, and the role of notebooks in academia and even data journalism. What is JupyterLab and how does it represent what you've called the “evolution of the Jupyter web interface?”
# The classic Jupyter Notebook offers a number of different building blocks for interactive computing: the notebook, file browser, text editor, terminal, outputs, etc. What need is JupyterLab fulfilling among Jupyter Notebook users, particularly those who work in data science or scientific/technical computing? We have built JupyterLab with the abstractions needed to offer real-time collaboration on all documents (notebooks, text files, etc.). I assert that open source software, with significant user and developer communities, also has external validation.
#
# Mean Scored Summary
# -------------------
# His primary area of research is interactive computing with data and, specifically, Jupyter. We recently discussed JupyterLab, how feedback from notebook users informed its design, how its features could benefit the scientific and technical computing communities, and the role of notebooks in academia and even data journalism. What is JupyterLab and how does it represent what you've called the “evolution of the Jupyter web interface?”
# The classic Jupyter Notebook offers a number of different building blocks for interactive computing: the notebook, file browser, text editor, terminal, outputs, etc. What need is JupyterLab fulfilling among Jupyter Notebook users, particularly those who work in data science or scientific/technical computing? In the classic notebook, those transitions are really painful. Third, collaboration is a significant area of need. As more and more groups and organizations adopt Jupyter, they need to work together with others on notebooks. We have built JupyterLab with the abstractions needed to offer real-time collaboration on all documents (notebooks, text files, etc.). Originally, the primary characteristic of JupyterLab 1.0 was going to be its feature parity with the classic Jupyter Notebook. We realize the transition will take time and that we will need to provide a lot of support and documentation, etc. There are two components of my academic work: teaching and research. On the teaching side I am currently teaching in Cal Poly’s undergraduate Data Science degree program (for Statistics and CS majors). On the research side, Jupyter is my primary area of research. In very broad terms, academia is struggling to understand how code and data, rather than traditional peer-reviewed papers, can be the primary output of academic research. I assert that open source software, with significant user and developer communities, also has external validation. Today, interactive computing with data remains my main area of research.
#
# Jason Laska and Michael Akilian on using AI to schedule meetings
# ================================================================
#
# Top N Summary
# -------------
# The O’Reilly Bots Podcast: The technical and social dynamics of solving scheduling problems.In this episode of the O’Reilly Bots Podcast, Pete Skomoroch and I talk to Jason Laska and Michael Akilian of Clara Labs, creator of a virtual assistant—Clara—that schedules meetings and interacts in natural language through email. Messaging is growing quickly, but e-mail is still the standard way to communicate within businesses and especially between businesses. E-mail conventions are somewhat standardized, and much of it is highly routinized—automatically generated reports, receipts, etc.—so it’s ripe for automation. Laska, who leads the machine learning efforts at Clara Labs, and Akilian, the company’s co-founder and CTO, talk about the reality of developing an AI-driven product, and explain Clara’s human-in-the-loop system. “People are still there to do some of the most challenging aspects of this work, and that’s exactly what you want to use people for,” says Laska.Continue reading Jason Laska and Michael Akilian on using AI to schedule meetings.
#
# Mean Scored Summary
# -------------------
# The O’Reilly Bots Podcast: The technical and social dynamics of solving scheduling problems.In this episode of the O’Reilly Bots Podcast, Pete Skomoroch and I talk to Jason Laska and Michael Akilian of Clara Labs, creator of a virtual assistant—Clara—that schedules meetings and interacts in natural language through email. Laska, who leads the machine learning efforts at Clara Labs, and Akilian, the company’s co-founder and CTO, talk about the reality of developing an AI-driven product, and explain Clara’s human-in-the-loop system. “People are still there to do some of the most challenging aspects of this work, and that’s exactly what you want to use people for,” says Laska.Continue reading Jason Laska and Michael Akilian on using AI to schedule meetings.
#
# Four short links: 25 May 2017
# =============================
#
# Top N Summary
# -------------
# Crypto vs. Regulation, Crippling Genomic Research, There Are Bots, and Web Security
#
# Chaffinch -- crypto system that's an interesting response to an attempt to regulate crypto. The Chaffinch system allows several further messages to be steganographically concealed behind the main message. The system is evaluated not only in terms of the traditional threat to confidentiality, eavesdroppers with significant computing power, but also in terms of its interaction with the U.K.'s Regulation of Investigatory Powers (RIP) Act, one of the first laws to attempt to engage with cryptography. We’re About to Cripple the Genomic Medical Era (DJ Patil) -- When we were developing the Precision Medicine Initiative and meeting with Americans across the country, a key concern was ensuring that their data couldn’t be used against them or their families (this is genetic information, so if you share a biological basis, you have overlap in the data). There Are Bots, Look Around (Renee DiResta) -- Something very similar happened in finance with the advent of high-frequency trading (the world I came from as a trader at Jane Street): technology was used to distort information flows and access in much the same way it is now being used to distort and game the marketplace of ideas.
#
# Mean Scored Summary
# -------------------
# Crypto vs. Regulation, Crippling Genomic Research, There Are Bots, and Web Security
#
# Chaffinch -- crypto system that's an interesting response to an attempt to regulate crypto. We’re About to Cripple the Genomic Medical Era (DJ Patil) -- When we were developing the Precision Medicine Initiative and meeting with Americans across the country, a key concern was ensuring that their data couldn’t be used against them or their families (this is genetic information, so if you share a biological basis, you have overlap in the data). There Are Bots, Look Around (Renee DiResta) -- Something very similar happened in finance with the advent of high-frequency trading (the world I came from as a trader at Jane Street): technology was used to distort information flows and access in much the same way it is now being used to distort and game the marketplace of ideas.
#
# Real-time intelligence gives Uber the edge
# ==========================================
#
# Top N Summary
# -------------
# M. C. Srivas covers Uber's big data architecture and explores the real-time problems Uber needs to solve to make ride sharing smooth.Continue reading Real-time intelligence gives Uber the edge.
#
# Mean Scored Summary
# -------------------
#
#
# Another one bytes the dust
# ==========================
#
# Top N Summary
# -------------
# Using the music industry as an example, Paul Brook shows how modern information points bring new data that changes the way an organization will make decisions.Continue reading Another one bytes the dust.
#
# Mean Scored Summary
# -------------------
#
#
# Machine learning is a moonshot for us all
# =========================================
#
# Top N Summary
# -------------
# Darren Strange asks: What part will we each play in what is sure to be one of the most exciting times in computer science?Continue reading Machine learning is a moonshot for us all .
#
# Mean Scored Summary
# -------------------
#
#
# The data subject first?
# =======================
#
# Top N Summary
# -------------
# Aurélie Pols draws a broad philosophical picture of the data ecosystem and then hones in on the right to data portability.Continue reading The data subject first?.
#
# Mean Scored Summary
# -------------------
#
#
# What Kaggle has learned from almost a million data scientists
# =============================================================
#
# Top N Summary
# -------------
# Anthony Goldbloom shares lessons learned from top performers in the Kaggle community and explores the types of machine-learning techniques typically used.Continue reading What Kaggle has learned from almost a million data scientists.
#
# Mean Scored Summary
# -------------------
#
#
# Highlights from Strata Data Conference in London 2017
# =====================================================
#
# Top N Summary
# -------------
# Watch "Using AI to create new jobs." Watch "Real-time intelligence gives Uber the edge." Watch "Lessons from piloting the London Office of Data Analytics." Peeking into the black box: Lessons from the front lines of machine-learning product launches
# Grace Huang shares lessons learned from running and interpreting machine-learning experiments. Watch "Peeking into the black box: Lessons from the front lines of machine-learning product launches."
#
# Mean Scored Summary
# -------------------
# Watch "Using AI to create new jobs." Watch "What Kaggle has learned from almost a million data scientists." Watch "Another one bytes the dust." Watch "Real-time intelligence gives Uber the edge." Watch "Lessons from piloting the London Office of Data Analytics." Watch "Accelerate analytics and AI innovations with Intel." Watch "Enabling data science in the enterprise." Peeking into the black box: Lessons from the front lines of machine-learning product launches
# Grace Huang shares lessons learned from running and interpreting machine-learning experiments. Watch "Peeking into the black box: Lessons from the front lines of machine-learning product launches."
#
# The science of visual interactions
# ==================================
#
# Top N Summary
# -------------
# Miriam Redi investigates how machine learning can detect subjective properties of images and videos, such as beauty, creativity, and sentiment.Continue reading The science of visual interactions.
#
# Mean Scored Summary
# -------------------
#
#
# 12 qualities of effective design organizations
# ==============================================
#
# Top N Summary
# -------------
# The qualities are broken up into three groups: Foundation, Output, and Management (Table 1-1). The 12 qualities of effective design organizations
#
# Foundation
# Output
# Management
#
#
#
# 1. This runs contrary to a common practice, where companies often have two teams—a product or UX design team and a marketing design team. Design leadership must make the effort, which can run contrary to the broader organization’s approach, to engage the team members as people. These leaders must also place their work alongside others, and accept others’ critique with grace and humility.
#
# Mean Scored Summary
# -------------------
# After years of apathetic leadership and poor performance, new owners made big moves, trading perceived franchise player Monta Ellis for Andrew Bogut and hiring coach Mark Jackson. The second lesson is that to get the most out of a team requires sensitive management, visionary leadership, and well-run operations. Design teams often suffer in this second area because, compared with other corporate functions like engineering and marketing, design is newer and its appreciation is less sophisticated. This nascency means that (a) most people in an organization have never worked with a truly effective design team, and (b) most designers haven’t been part of fully actualized teams, and so they don’t know what they need in order to realize their own potential. Many design teams have the raw talent to realize the expanded role outlined in the prior chapter, but don’t yet have the maturity to embrace it. A design team’s output is the result not only of their skill, but the sophistication and sensitivity of how they operate. In this chapter, we present a set of qualities of effective design organizations. The qualities are broken up into three groups: Foundation, Output, and Management (Table 1-1). These qualities are indicative of the broader creative/operational split that is required to sustainably deliver good design, and is a theme throughout this book. Output addresses what most people think of when considering design—is the team able to produce quality work across the necessary set of capabilities? To realize team longevity and continued broadening impact, it’s imperative to treat operations as seriously as the work product. The 12 qualities of effective design organizations
#
# Foundation
# Output
# Management
#
#
#
# 1. Focused, empowered leadership
# 3. Treat team members as people, not resources
# 10. Manage operations effectively
#
#
#
# Foundation
# Often, in the rush to just get a design team in place and producing work, laying foundational components such as values, principles, and mindset is neglected. Being intentional about the foundation leads to stronger work and more committed team members. Shared Sense of Purpose
# Meaning and purpose are important for organizations at every level of scale. Every design team is different, so no one charter will apply universally. Focused, Empowered Leadership
# Successful teams, including design teams, have strong, formal leadership. Leaders have an intimate understanding of how the team should work, make decisions that benefit the team, and have the respect of the team’s members. With small design teams, it is common for a squad of junior-to-senior designers to report to someone who is not a designer, but instead in product management, engineering, or marketing. An example was a Silicon Valley company (that shall remain nameless) that had four design directors as peers, each reporting to the VP of Product Management. And that person was making decisions that affected the design team, even though he didn’t understand the potential that design could be delivering. Focused leadership
# We’re using the phrase “focused leadership” to mean one or two people are running design and are from within the design organization—these leaders are not also overseeing other functions. While design leaders must be attentive to issues of quality, a common mistake made by many companies is that they place in this role a design visionary, a creative director with big ideas and an obsessive attention to detail. Instead, this design leader’s primary responsibilities will prove organizational, working with other executives to clear the path for design, and serving as a manager, mentor, team builder, and operator for the team itself, creating both a figurative and literal space where design can thrive. In fact, this quality was originally labeled “singular, empowered leadership,” because it’s important that there is a clear line of authority within the design organization (and not a set of supposed leaders, all as peers, reporting into a non-design role). Executive engagement (whether in the form of sponsorship, organizational cover, or simple reporting structures) demonstrates the importance that design has within the organization. Such executive support will prove necessary as the expanded role of design inevitably upsets corporate “business as usual.”3. Authentic User Empathy
# Essential in design’s ability to succeed is an authentic understanding of user contexts and behaviors. Good user research, particularly out in the field, reveals a richness of understanding that you simply cannot get anywhere else. It is this work that ends up revealing a customer’s journey, and inevitably, the experiential breakdowns that happen when people try to accomplish things that require them to unknowingly cross siloed departments in an organization. A secondary benefit that can be just as important is when executives and other people with authority outside of design witness the results of such user research, whether it’s the raw data (e.g., videos of people expressing frustration with the current situation), or the analyses that makes clear problematic patterns. Understand, Articulate, and Create Value
# After the dot-com bust in 2001 and the recession that followed, a cry heard throughout the software design community was “How do I demonstrate return on investment (ROI)?” At that time, most companies saw design as a cost of doing business, and something to minimize when times were tight. At Adaptive Path, we pursued this question through research that led to a 2003 report, “Leveraging Business Value: How ROI Changes User Experience.”1 While unable to identify a simple equation of x design leading to y value, the report stated:
# Our research revealed that using ROI and other valuation methods helps to evolve design competency within organizations. The valuation methods provide tools for developing and measuring a design strategy as a component of a larger business strategy: The ability to “value” user experience design makes it a visible and credible business lever on par with marketing, research and development, and channel strategy. Too often, designers practice design-for-design’s-sake, where what’s produced, however cool or innovative, isn’t connected with the company’s goals. Savvy design leaders embrace business value, realizing it can serve as a powerful input into the design process. And when these business objectives are paired with authentic user empathy, new means of value creation can emerge. When design organizations propose ways to unlock new business value, their credibility and impact increases.Output
# We are finally at the place where most people begin when thinking about design—making stuff! The following four qualities address the design organization’s capability to produce sufficient, robust, and relevant work. Another implication is that there should be only one design organization to undergird the entire customer journey. This runs contrary to a common practice, where companies often have two teams—a product or UX design team and a marketing design team. “Marketing” and “product” experiences are simply milestones on the same customer journey. Also, whereas traditional marketing design was delivered through media (publications, broadcast, billboards) and product design was for a thing placed on a retail shelf, in a world of connected software, the platform for many marketing and product experiences has converged in digital realms such as email, web, and mobile. Companies beholden to the archaic “marketing” and “product” distinctions also get in the way of new opportunities, such as the rise of “growth” product development, where what would have been considered a classic marketing function (acquiring users) becomes part of product development. Given a single design organization invited to work end to end throughout the customer’s journey, a third implication arises: the need for a vast array of design skills to address the totality of that journey (Table 1-2). Still, the design organization must be accountable and responsible for the delivery of these design practices, whether they are done by people employed full-time, or external contractors and agencies brought in on a project basis. They need to facilitate the creative output of others throughout the organization, tapping into a resource often left dormant. Imagine a conceptual scale that spans a product and services view from 10,000 feet to 1 foot, and place design work along that scale (Figure 1-1). What the percentages show is that while the effort placed in the lower, execution-focused levels will far outweigh that which is spent in the higher levels, in order for design to fulfill its potential, it must deliver across all levels. Instead, bring on two designers as quickly as you can, one who can take the bulk of the lower level work (spending 80% of their time in Surface and 20% in Structure), and another who can do some of that, but also engage strategically and across the organization (spending 60% of their time in Structure, 30% of their time in Strategy, and 10% addressing The Big Picture). When Peter was hired to run design at one company, he inherited an organization whose efforts mostly consisted of turning product managers’ requirements into comps, and where user research made an impact only at the interface level. This drove Peter’s decision to recruit designers who could deliver quality work at the Structure and Strategy levels. As they came onboard, design’s influence grew organically.7. Establish and Uphold Standards of Quality
# A design organization is ultimately judged by the quality of its output. What’s tricky is that there’s no universal definition of design quality. Sure, design solutions can have quantitative performance measures such as conversion rates and task completion, but they are insufficient in establishing quality. To overcome this, the design organization must be empowered to define quality standards for their team and their organization. Once the design org has established such quality standards, they must hold themselves up to those standards, and not sacrifice. People outside of the design team don’t understand what it takes to maintain a high quality bar, and design teams are asked to do too many things with too few people in too little time. Designers want to make others (clients, colleagues, users) happy. Design leaders need to wield the power of “No.” Design work should only be done when adequately prioritized and staffed, and when there is time to develop quality solutions. What it does mean is empowering the design organization to uphold what it takes to deliver quality, and to decline work that doesn’t fit. Many design organizations rely on process as a proxy for quality. Critical thinking is essential for delivering great work, and an over-adherence to a methodology leads to teams making unthinking decisions. “We must follow a user-centered design process” may sound like a good plan, but when any process becomes an assumption or accepted dogma, it becomes a crutch that replaces critical thinking. Instead of following a well-trod process, design leadership should make the effort to figure out the best ways to tackle different challenges, drawing from a broad methodological toolkit.8. Value Delivery Over Perfection
# In a world where speed is often vaunted above all else, this talk of upholding quality makes some people nervous. So, “delivery over perfection” is meant to balance “establish and uphold quality.” There’s a quote attributed to Steve Jobs during the development of Macintosh: “Real artists ship.” This recognizes that even the most masterful craftspeople, if they are actually hoping to have some kind of impact, must stop what they’re doing and get their work out into the world. For those who went to design school, every time they made something, they had one chance to get it right. Without sound management practices, a design team turns into a hornet’s nest of disillusionment, putting the quality of the team’s output in jeopardy, and risking retention. Teams Are Made of People, Not Resources
# The department name “Human Resources” demonstrates how many companies think of their employees—not as people, but as economic units whose role is to contribute to a company’s productivity. Design leadership must make the effort, which can run contrary to the broader organization’s approach, to engage the team members as people. Actualized design teams overcome such practices by treating team members as individuals, with all the messiness implied. They recognize job titles are imperfect, and two people with the same title may have different skills. While maintaining this individualistic perspective is challenging as the design organization grows, it’s worth the effort. Let their freak flags fly.Do team members work reasonable hours? Constant production and overlong hours stagnates work quality, as designers rely on what is basic and safe. Productivity can even go backward—poor decisions designers make while fatigued have to then be undone before the team can move on.Are team members encouraged to grow? Managers must understand how team members want to evolve—do they want to deepen their craft, cross-train into other skills, learn how to lead?—and find ways to support them. Great design managers provide little direction and lots of mentorship—they don’t tell folks what to do, but teach them tools and techniques to help them figure out solutions on their own. When Peter joined one company, he inherited a product design team of 11 men and 2 women, almost all in their mid-20s. Earning one another’s respect is necessary in order for the team to “get real,” because frank and candid critique and feedback are essential for upholding the quality standards. Greatness comes from the tension and collision of different perspectives (a concept known as “creative abrasion”), addressed openly and honestly. Design teams that favor politeness over candor will rarely produce great work. Great design leaders encourage everyone to speak up, and, for themselves, wait to speak last, if at all. These leaders must also place their work alongside others, and accept others’ critique with grace and humility. Great design work takes space—places to collaborate, whiteboards for sketching and ideation, walls to show work. Just because design is “creative,” it shouldn’t get a pass in terms of running effectively. If done well, team members will learn to appreciate the ability to remain focused on the work, instead of being sucked into the work-about-the-work that insidiously steals a surprising amount of time.Our Humanistic Agenda
# Twentieth-century management practices were dominated by Scientific Management, which sought to squeeze the most productivity out of a workforce, and bureaucracy, which treated employees as interchangeable widgets. This humanistic orientation is even more important for the design team, as the very nature of their work exploits their humanity, from the empathy they draw from customer research to their design solutions expressing their perspectives. Use these 12 qualities as guidelines for assessing a design organization. Have all the team members score the organization against each quality, and use the results to identify areas that need work. 2The levels Strategy, Structure, and Surface are informed by, though slightly altered, from Jesse James Garrett’s The Elements of User Experience (New Riders, 2010). Continue reading 12 qualities of effective design organizations.
#
# Kelly Shortridge on overcoming common missteps affecting security decision-making
# =================================================================================
#
# Top N Summary
# -------------
# The O’Reilly Security Podcast: How adversarial posture affects decision-making, how decision trees can build more dynamic defenses, and the imperative role of UX in security.In this episode, I talk with Kelly Shortridge, detection product manager at BAE Systems Applied Intelligence. We talk about how common cognitive biases apply to security roles, how decision trees can help security practitioners overcome assumptions and build more dynamic defenses, and how combining security and UX could lead to a more secure future.Continue reading Kelly Shortridge on overcoming common missteps affecting security decision-making.
#
# Mean Scored Summary
# -------------------
# The O’Reilly Security Podcast: How adversarial posture affects decision-making, how decision trees can build more dynamic defenses, and the imperative role of UX in security.In this episode, I talk with Kelly Shortridge, detection product manager at BAE Systems Applied Intelligence.
#
# 5 things to learn before learning React
# =======================================
#
# Top N Summary
# -------------
# Level up your skills set before diving into React.If you haven’t built a single-page application before, React really forces you to level-up your skill set. React as a library has a lot to offer - you can build shareable components that have a clear flow of data (which makes debugging much, much easier). Many times, React just lets you write JavaScript to get your work done. After watching people struggle with out-of-date tutorials and blog posts, and the JavaScript ecosystem in general, I compiled a list of things you might want to know BEFORE you start learning React. The list below may sound exhaustive, but once you feel fluent in these concepts and skills, it will make building your first app in React easier and more fun.Continue reading 5 things to learn before learning React.
#
# Mean Scored Summary
# -------------------
# React as a library has a lot to offer - you can build shareable components that have a clear flow of data (which makes debugging much, much easier). After watching people struggle with out-of-date tutorials and blog posts, and the JavaScript ecosystem in general, I compiled a list of things you might want to know BEFORE you start learning React. The list below may sound exhaustive, but once you feel fluent in these concepts and skills, it will make building your first app in React easier and more fun.Continue reading 5 things to learn before learning React.
#
# Reliability with Kafka
# ======================
#
# Top N Summary
# -------------
# Five questions for Gwen Shapira about how Kafka can enable business agility.I recently sat down with Gwen Shapira, system architect at Confluent, to talk about Kafka—why it’s becoming popular (particularly with financial organizations), the benefits it can have for your organization, and how to adopt it safely and reliably. Here are some highlights from our talk. What are some of the more exciting use cases for Kafka? I’d say it’s most exciting to see how Apache Kafka use cases have evolved over the last few years. Continue reading Reliability with Kafka.
#
# Mean Scored Summary
# -------------------
# Five questions for Gwen Shapira about how Kafka can enable business agility.I recently sat down with Gwen Shapira, system architect at Confluent, to talk about Kafka—why it’s becoming popular (particularly with financial organizations), the benefits it can have for your organization, and how to adopt it safely and reliably.
#
# Four short links: 24 May 2017
# =============================
#
# Top N Summary
# -------------
# Travel Mode, Justice Data, Threat Dragon, and Voice Editing
#
# 1Password Travel Mode -- enable Travel Mode, and all devices not marked Safe For Travel are deleted from your devices. As Bach says, “Justice in America happens in 3,000 counties, each with its own justice system.” (via Wired)
#
# OWASP Threat Dragon -- open source threat modeling tool from OWASP. (via Tech Beacon)
#
# More Detail on Adobe's Voice Editing Software -- VoCo is based on an optimization algorithm that searches the voice recording and chooses the best possible combinations of phonemes (partial word sounds) to build new words in the user’s voice. [...] In case the synthesized word isn’t quite right, VoCo offers users several versions of the word to choose from. The system also provides an advanced editor to modify pitch and duration, allowing expert users to further polish the track.
#
# Mean Scored Summary
# -------------------
# Travel Mode, Justice Data, Threat Dragon, and Voice Editing
#
# 1Password Travel Mode -- enable Travel Mode, and all devices not marked Safe For Travel are deleted from your devices. As Bach says, “Justice in America happens in 3,000 counties, each with its own justice system.” (via Wired)
#
# OWASP Threat Dragon -- open source threat modeling tool from OWASP. (via Tech Beacon)
#
# More Detail on Adobe's Voice Editing Software -- VoCo is based on an optimization algorithm that searches the voice recording and chooses the best possible combinations of phonemes (partial word sounds) to build new words in the user’s voice. [...] In case the synthesized word isn’t quite right, VoCo offers users several versions of the word to choose from. The system also provides an advanced editor to modify pitch and duration, allowing expert users to further polish the track.
#
# Four short links: 23 May 2017
# =============================
#
# Top N Summary
# -------------
# TensorFlow Cookbook, Welcoming Newcomers, Patent Win, and Face Classification
#
# ...
#
# Mean Scored Summary
# -------------------
# Learn the basics of application programming interfaces (APIs), their purpose, and the key concepts underlying the technology.
#
# How to do client-side form validation with Elm
# ==============================================
#
# Top N Summary
# -------------
# Elm’s static typing and compiler error messages lead to more productivity.Form validation, taking user entered data and giving them hints about what they need to do, is one of the most common tasks that a web developer encounters. Even though it’s everywhere, it’s easy to forget how nuanced and tricky form validation can be. At the crucial time when a user is signing up for your service, or filling out their profile, it’s easy to irritate a user with incomplete feedback, fields that are deleted upon failed validation, and cryptic error messages. Form validators are nuanced because every field usually has a different set of error states that could potentially pop up. Terms of service can be, well, not agreed to.Continue reading How to do client-side form validation with Elm.
#
# Mean Scored Summary
# -------------------
# Elm’s static typing and compiler error messages lead to more productivity.Form validation, taking user entered data and giving them hints about what they need to do, is one of the most common tasks that a web developer encounters. At the crucial time when a user is signing up for your service, or filling out their profile, it’s easy to irritate a user with incomplete feedback, fields that are deleted upon failed validation, and cryptic error messages. Form validators are nuanced because every field usually has a different set of error states that could potentially pop up.
#
# The stages of enterprise IoT adoption
# =====================================
#
# Top N Summary
# -------------
# Teresa Tung on building a business case for the Internet of Things.Continue reading The stages of enterprise IoT adoption.
#
# Mean Scored Summary
# -------------------
#
#
# Four short links: 17 May 2017
# =============================
#
# Top N Summary
# -------------
# Shipping Apps, Cloud Economics, Computational Theory, and Imitation Learning
#
# How Etsy Ships Apps -- starts with a nifty summary of their chatops-based push process, then moves to how they tackle shipping for mobile apps. Here’s how Ship helps: (1) keeps track of who committed changes to a release; (2) sends Slack messages and emails to the right people about the relevant events; (3) manages the state and schedule of all releases. Usage Patterns and the Economics of the Cloud (Adrian Colyer) -- cloud providers overwhelmingly use static pricing models; what’s going on? One-Shot Imitation Learning -- ideally, robots should be able to learn from very few demonstrations of any given task and instantly generalize to new situations of the same task, without requiring task-specific engineering. (via OpenAI)
#
# Continue reading Four short links: 17 May 2017.
#
# Mean Scored Summary
# -------------------
# Shipping Apps, Cloud Economics, Computational Theory, and Imitation Learning
#
# How Etsy Ships Apps -- starts with a nifty summary of their chatops-based push process, then moves to how they tackle shipping for mobile apps. Here’s how Ship helps: (1) keeps track of who committed changes to a release; (2) sends Slack messages and emails to the right people about the relevant events; (3) manages the state and schedule of all releases. (via OpenAI)
#
# Continue reading Four short links: 17 May 2017.
#
# Augmenting industrial reality
# =============================
#
# Top N Summary
# -------------
# Integration tools and vision systems represent two developments in enterprise AR that point to bigger things to come.Augmented Reality is clearly poised to shift everything about our world. Facebook just devoted a whole building, Building 8, to creating AR—they’re currently hiring camera systems architects and neural imaging engineers. Companies like Chevrolet are creating amazing examples of realtime AR—in which cars are digitally rendered so realistically you’d swear they were filmed (nope). AR is poised to make a big leap in the next five years. Namely: manufacturing and industry—enterprise.Continue reading Augmenting industrial reality.
#
# Mean Scored Summary
# -------------------
# Integration tools and vision systems represent two developments in enterprise AR that point to bigger things to come.Augmented Reality is clearly poised to shift everything about our world. Facebook just devoted a whole building, Building 8, to creating AR—they’re currently hiring camera systems architects and neural imaging engineers. Companies like Chevrolet are creating amazing examples of realtime AR—in which cars are digitally rendered so realistically you’d swear they were filmed (nope).
#
# Four short links: 16 May 2017
# =============================
#
# Top N Summary
# -------------
# Flash Organizations, Collaboration Data Set, De-Anonymizing Mobile Data, and Hacking Economics
#
# Flash Organizations: Crowdsourcing Complex Work By Structuring Crowds As Organizations -- Our system introduces two technical contributions: 1) encoding the crowd’s division of labor into de-individualized roles, much as movie crews or disaster response teams use roles to support coordination between on-demand workers who have not worked together before; and 2) reconfiguring these structures through a model inspired by version control, enabling continuous adaptation of the work and the division of labor. What motivates media manipulation? Their particular context is mobile location data, but underpinning the discovery mechanism is a reliance on two key characteristics: (1) individuals tend to do the same things over and over (regularity)—i.e., there are patterns in the data relating to given individuals, and (2) these patterns are different across different users (uniqueness). I love the idea of the minimum wage machine: Turning the crank yielded a one cent euro coin every 4.018 seconds, that’s €8.96 an hour, the minimum wage in The Netherlands right now. Continue reading Four short links: 16 May 2017.
#
# Mean Scored Summary
# -------------------
# Flash Organizations, Collaboration Data Set, De-Anonymizing Mobile Data, and Hacking Economics
#
# Flash Organizations: Crowdsourcing Complex Work By Structuring Crowds As Organizations -- Our system introduces two technical contributions: 1) encoding the crowd’s division of labor into de-individualized roles, much as movie crews or disaster response teams use roles to support coordination between on-demand workers who have not worked together before; and 2) reconfiguring these structures through a model inspired by version control, enabling continuous adaptation of the work and the division of labor. Their particular context is mobile location data, but underpinning the discovery mechanism is a reliance on two key characteristics: (1) individuals tend to do the same things over and over (regularity)—i.e., there are patterns in the data relating to given individuals, and (2) these patterns are different across different users (uniqueness). I love the idea of the minimum wage machine: Turning the crank yielded a one cent euro coin every 4.018 seconds, that’s €8.96 an hour, the minimum wage in The Netherlands right now.
#
# Architecting actionable insights
# ================================
#
# Top N Summary
# -------------
# Bas Geerdink details the technology stack for real-time account forecasting at ING, and outlines how Spark is used for outbound communications.Continue reading Architecting actionable insights.
#
# Mean Scored Summary
# -------------------
#
#
# The business advantages of embedding analytics into applications
# ================================================================
#
# Top N Summary
# -------------
# There are many ways to embed analytics, depending on your requirements (see Figure 1), but the goal is always the same: to help business users explore data efficiently and make the best data-driven decisions for their organizations. Looking at Figure 1, the continuum of embedded analytics options runs from white-label solutions that are quick and easy to integrate up to extended custom developed solutions. Lightweight integrated options are low-effort and quick time-to-market, while providing a seamless user experience because they are integrated into apps with an iFrame (although some product managers will object to using iFrames for technical reasons). And finally, the extended option provides custom visualizations and data source integrations for your applications. Most importantly, an embedded analytics solution should provide a great user experience.
#
# Mean Scored Summary
# -------------------
# There are NoSQL databases like Cassandra, HBase, and MongoDB; data processing frameworks like Hadoop and Spark; query engines like Impala and Hive; stream processing tools like Storm and Kafka; and text indexing frameworks like ElasticSearch and Solr. As you can see, building your own visual analytics within your product could quickly strain architectural and developer resources, and their knowledge. Enter embedded analytics
# Embedded analytics is the use of reporting and analytic capabilities (including visualizations) from packaged software running within business applications. There are many ways to embed analytics, depending on your requirements (see Figure 1), but the goal is always the same: to help business users explore data efficiently and make the best data-driven decisions for their organizations. Looking at Figure 1, the continuum of embedded analytics options runs from white-label solutions that are quick and easy to integrate up to extended custom developed solutions. White-label rebranding options are very low-effort and very quick time-to-market solutions that run as a separate app, so they don’t provide a seamless user experience. Lightweight integrated options are low-effort and quick time-to-market, while providing a seamless user experience because they are integrated into apps with an iFrame (although some product managers will object to using iFrames for technical reasons). Deeply embedded analytics provide API/SDK-level integration that requires a higher effort and longer time-to-market ,while providing a completely seamless user experience. And finally, the extended option provides custom visualizations and data source integrations for your applications. Source: Zoomdata, used with permission. Flexible deployment options (cloud, on-premise, hybrid)? Connects to wide set of modern data sources? Extensible—add custom data sources? Your embedded analytics solutions should integrate into your product cycle; be low cost and commercially flexible (in terms of royalties and licensing) so it can provide good ROI; and connect quickly, easily, and in an architecturally sound and extensible way to a variety of modern data sources. Most importantly, an embedded analytics solution should provide a great user experience.
#
# How can I deploy a multi-container application with Docker Compose?
# ===================================================================
#
# Top N Summary
# -------------
# Learn how to use Docker to distribute multi-container applications into a standardized unit for seamless software development.Continue reading How can I deploy a multi-container application with Docker Compose?.
#
# Mean Scored Summary
# -------------------
#
#
# How do I package my Java application as a Docker image using Gradle?
# ====================================================================
#
# Top N Summary
# -------------
# Learn how to use Gradle, a popular build tool for Java developers, to package your Java application as a Docker image and run as a Docker container.Continue reading How do I package my Java application as a Docker image using Gradle?.
#
# Mean Scored Summary
# -------------------
#
#
# How do I create Docker images and run containers using Maven?
# =============================================================
#
# Top N Summary
# -------------
# Learn how to use Apache Maven, a project management and comprehension tool, to package your Java application as a Docker image and run as a Docker container.Continue reading How do I create Docker images and run containers using Maven?.
#
# Mean Scored Summary
# -------------------
#
#
# Get introduced to the new Java® 9 Platform Module System (JPMS) with Paul Deitel
# ================================================================================
#
# Top N Summary
# -------------
# This two-day live online training covers JPMS, a tool Paul Deitel calls “the most significant new Java software-engineering technology since the inception of Java.”Paul Deitel, CEO of Deitel & Associates, Inc., co-author of Java® 9 for Programmers, and an Oracle Java Champion, is leading a live online introduction to the Java Platform Module System (JPMS). What you’ll learn in Introduction to Modularity with the Java® 9 Platform Module System
#
# In this live online training, you’ll:
#
# Understand the motivation for modularity. Use services to loosely couple system components, making large-scale systems easier to develop and maintain. How Java 9 modularity will make developers’ lives easier
# According to JSR 376: Java Platform Module System, the key goals of modularizing the Java SE Platform are:
# Reliable configuration—You must explicitly declare dependencies between modules in a manner that’s recognized both at compile time and execution time. Continue reading Get introduced to the new Java® 9 Platform Module System (JPMS) with Paul Deitel.
#
# Mean Scored Summary
# -------------------
# This two-day live online training covers JPMS, a tool Paul Deitel calls “the most significant new Java software-engineering technology since the inception of Java.”Paul Deitel, CEO of Deitel & Associates, Inc., co-author of Java® 9 for Programmers, and an Oracle Java Champion, is leading a live online introduction to the Java Platform Module System (JPMS). Deitel’s two-day live online training will be presented only on Safari, O’Reilly’s learning platform. What you’ll learn in Introduction to Modularity with the Java® 9 Platform Module System
#
# In this live online training, you’ll:
#
# Understand the motivation for modularity. Use services to loosely couple system components, making large-scale systems easier to develop and maintain. Visit Safari for the detailed course outline and prerequisites for Introduction to Modularity with the Java® 9 Platform Module System. How Java 9 modularity will make developers’ lives easier
# According to JSR 376: Java Platform Module System, the key goals of modularizing the Java SE Platform are:
# Reliable configuration—You must explicitly declare dependencies between modules in a manner that’s recognized both at compile time and execution time. The system can automatically walk through these dependencies (via the module resolver) to determine the subset of all modules required to support your app. Continue reading Get introduced to the new Java® 9 Platform Module System (JPMS) with Paul Deitel.
#
# Jupyter Digest: 15 May 2017
# ===========================
#
# Top N Summary
# -------------
# TSFRESH, 100 days of algorithms, how JupyterHub tamed big science, colorizing photos. Tomáš Bouda (@coells on GitHub) compiles a nice list of examples that illustrate a host of different algorithms with Python. If a title like "Day 14 - huffman codes.ipynb" lights you up, then you're gonna love this (times 100). How JupyterHub tamed big science: Experiences deploying Jupyter at a supercomputing center. Richard Zhang, a PhD candidate at UC Berkeley, uses this notebook to illustrate a technique he's developed to colorize black and white photos (see below).
#
# Mean Scored Summary
# -------------------
# TSFRESH, 100 days of algorithms, how JupyterHub tamed big science, colorizing photos. If a title like "Day 14 - huffman codes.ipynb" lights you up, then you're gonna love this (times 100). Richard Zhang, a PhD candidate at UC Berkeley, uses this notebook to illustrate a technique he's developed to colorize black and white photos (see below).

# %% [markdown]
# ## Example 7. Visualizing document summarization results with HTML output

# %%
import os
import json
import nltk
import numpy
from IPython.display import IFrame
from IPython.core.display import display

BLOG_DATA = "resources/ch05-webpages/feed.json"

HTML_TEMPLATE = """<html>
    <head>
        <title>%s</title>
        <meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>
    </head>
    <body>%s</body>
</html>"""

blog_data = json.loads(open(BLOG_DATA).read())

for post in blog_data:
   
    # Uses previously defined summarize function.
    post.update(summarize(post['content']))

    # You could also store a version of the full post with key sentences marked up
    # for analysis with simple string replacement...

    for summary_type in ['top_n_summary', 'mean_scored_summary']:
        post[summary_type + '_marked_up'] = '<p>%s</p>' % (post['content'], )
        for s in post[summary_type]:
            post[summary_type + '_marked_up'] = \
            post[summary_type + '_marked_up'].replace(s, '<strong>%s</strong>' % (s, ))

        filename = post['title'].replace("?", "") + '.summary.' + summary_type + '.html'
        f = open(os.path.join('resources', 'ch05-webpages', filename), 'w')
        html = HTML_TEMPLATE % (post['title'] + \
          ' Summary', post[summary_type + '_marked_up'],)
              
        f.write(html.encode('utf-8'))
        f.close()

        print "Data written to", f.name

# Display any of these files with an inline frame. This displays the
# last file processed by using the last value of f.name...

print "Displaying %s:" % f.name
display(IFrame('files/%s' % f.name, '100%', '600px'))
# Out:
# Data written to resources/ch05-webpages/Four short links: 30 May 2017.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Four short links: 30 May 2017.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Jupyter Insights: Carol Willing, director of the Python Software Foundation.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Jupyter Insights: Carol Willing, director of the Python Software Foundation.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Jupyter Digest: 30 May 2017.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Jupyter Digest: 30 May 2017.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/What is the OSI model.summary.top_n_summary.html
# Data written to resources/ch05-webpages/What is the OSI model.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/How do I configure a Cisco router for secure remote access using SSH.summary.top_n_summary.html
# Data written to resources/ch05-webpages/How do I configure a Cisco router for secure remote access using SSH.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/How do I recover the password on a Cisco router without losing its configuration.summary.top_n_summary.html
# Data written to resources/ch05-webpages/How do I recover the password on a Cisco router without losing its configuration.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Four short links: 29 May 2017.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Four short links: 29 May 2017.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Intelligent Bits: 26 May 2017.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Intelligent Bits: 26 May 2017.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Four short links: 26 May 2017.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Four short links: 26 May 2017.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Running a word count application using Spark.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Running a word count application using Spark.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Peeking into the black box: Lessons from the front lines of machine-learning product launches.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Peeking into the black box: Lessons from the front lines of machine-learning product launches.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Using AI to create new jobs.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Using AI to create new jobs.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Lessons from piloting the London Office of Data Analytics.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Lessons from piloting the London Office of Data Analytics.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Enabling data science in the enterprise.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Enabling data science in the enterprise.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Is finance ready for AI.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Is finance ready for AI.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Accelerate analytics and AI innovations with Intel.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Accelerate analytics and AI innovations with Intel.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Data science and deep learning in retail.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Data science and deep learning in retail.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Travis Lowdermilk and Jessica Rich on building a customer-driven culture at Microsoft.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Travis Lowdermilk and Jessica Rich on building a customer-driven culture at Microsoft.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/JupyterLab: The evolution of the Jupyter web interface.summary.top_n_summary.html
# Data written to resources/ch05-webpages/JupyterLab: The evolution of the Jupyter web interface.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Jason Laska and Michael Akilian on using AI to schedule meetings.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Jason Laska and Michael Akilian on using AI to schedule meetings.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Four short links: 25 May 2017.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Four short links: 25 May 2017.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Real-time intelligence gives Uber the edge.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Real-time intelligence gives Uber the edge.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Another one bytes the dust.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Another one bytes the dust.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Machine learning is a moonshot for us all.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Machine learning is a moonshot for us all.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/The data subject first.summary.top_n_summary.html
# Data written to resources/ch05-webpages/The data subject first.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/What Kaggle has learned from almost a million data scientists.summary.top_n_summary.html
# Data written to resources/ch05-webpages/What Kaggle has learned from almost a million data scientists.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Highlights from Strata Data Conference in London 2017.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Highlights from Strata Data Conference in London 2017.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/The science of visual interactions.summary.top_n_summary.html
# Data written to resources/ch05-webpages/The science of visual interactions.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/12 qualities of effective design organizations.summary.top_n_summary.html
# Data written to resources/ch05-webpages/12 qualities of effective design organizations.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Kelly Shortridge on overcoming common missteps affecting security decision-making.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Kelly Shortridge on overcoming common missteps affecting security decision-making.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/5 things to learn before learning React.summary.top_n_summary.html
# Data written to resources/ch05-webpages/5 things to learn before learning React.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Reliability with Kafka.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Reliability with Kafka.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Four short links: 24 May 2017.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Four short links: 24 May 2017.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Four short links: 23 May 2017.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Four short links: 23 May 2017.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Jupyter Digest: 22 May 2017.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Jupyter Digest: 22 May 2017.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Four short links: 22 May 2017.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Four short links: 22 May 2017.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Intelligent Bits: 19 May 2017.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Intelligent Bits: 19 May 2017.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Four short links: 19 May 2017.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Four short links: 19 May 2017.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Activating human intrusion detection systems.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Activating human intrusion detection systems.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Exploring progressive web apps in the real world.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Exploring progressive web apps in the real world.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/How to write a sound hypothesis when conducting user research.summary.top_n_summary.html
# Data written to resources/ch05-webpages/How to write a sound hypothesis when conducting user research.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/How AI is used to infer human emotion.summary.top_n_summary.html
# Data written to resources/ch05-webpages/How AI is used to infer human emotion.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Paris Buttfield-Addison on what’s new in Swift programming.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Paris Buttfield-Addison on what’s new in Swift programming.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Four short links: 18 May 2017.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Four short links: 18 May 2017.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Using Docker in production.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Using Docker in production.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/How do I build an API.summary.top_n_summary.html
# Data written to resources/ch05-webpages/How do I build an API.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/How do I use an API.summary.top_n_summary.html
# Data written to resources/ch05-webpages/How do I use an API.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/What is an API.summary.top_n_summary.html
# Data written to resources/ch05-webpages/What is an API.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/How to do client-side form validation with Elm.summary.top_n_summary.html
# Data written to resources/ch05-webpages/How to do client-side form validation with Elm.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/The stages of enterprise IoT adoption.summary.top_n_summary.html
# Data written to resources/ch05-webpages/The stages of enterprise IoT adoption.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Four short links: 17 May 2017.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Four short links: 17 May 2017.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Augmenting industrial reality.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Augmenting industrial reality.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Four short links: 16 May 2017.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Four short links: 16 May 2017.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Architecting actionable insights.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Architecting actionable insights.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/The business advantages of embedding analytics into applications.summary.top_n_summary.html
# Data written to resources/ch05-webpages/The business advantages of embedding analytics into applications.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/How can I deploy a multi-container application with Docker Compose.summary.top_n_summary.html
# Data written to resources/ch05-webpages/How can I deploy a multi-container application with Docker Compose.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/How do I package my Java application as a Docker image using Gradle.summary.top_n_summary.html
# Data written to resources/ch05-webpages/How do I package my Java application as a Docker image using Gradle.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/How do I create Docker images and run containers using Maven.summary.top_n_summary.html
# Data written to resources/ch05-webpages/How do I create Docker images and run containers using Maven.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Get introduced to the new Java® 9 Platform Module System (JPMS) with Paul Deitel.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Get introduced to the new Java® 9 Platform Module System (JPMS) with Paul Deitel.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Jupyter Digest: 15 May 2017.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Jupyter Digest: 15 May 2017.summary.mean_scored_summary.html
# Displaying resources/ch05-webpages/Jupyter Digest: 15 May 2017.summary.mean_scored_summary.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Jupyter Digest: 15 May 2017.summary.mean_scored_summary.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Example 8. Extracting entities from a text with NLTK

# %%
import nltk
import json

BLOG_DATA = "resources/ch05-webpages/feed.json"

blog_data = json.loads(open(BLOG_DATA).read())

for post in blog_data:

    sentences = nltk.tokenize.sent_tokenize(post['content'])
    tokens = [nltk.tokenize.word_tokenize(s) for s in sentences]
    pos_tagged_tokens = [nltk.pos_tag(t) for t in tokens]

    # Flatten the list since we're not using sentence structure
    # and sentences are guaranteed to be separated by a special
    # POS tuple such as ('.', '.')

    pos_tagged_tokens = [token for sent in pos_tagged_tokens for token in sent]

    all_entity_chunks = []
    previous_pos = None
    current_entity_chunk = []
    for (token, pos) in pos_tagged_tokens:

        if pos == previous_pos and pos.startswith('NN'):
            current_entity_chunk.append(token)
        elif pos.startswith('NN'):
            if current_entity_chunk != []:

                # Note that current_entity_chunk could be a duplicate when appended,
                # so frequency analysis again becomes a consideration

                all_entity_chunks.append((' '.join(current_entity_chunk), pos))
            current_entity_chunk = [token]

        previous_pos = pos

    # Store the chunks as an index for the document
    # and account for frequency while we're at it...

    post['entities'] = {}
    for c in all_entity_chunks:
        post['entities'][c] = post['entities'].get(c, 0) + 1

    # For example, we could display just the title-cased entities

    print post['title']
    print '-' * len(post['title'])
    proper_nouns = []
    for (entity, pos) in post['entities']:
        if entity.istitle():
            print '\t%s (%s)' % (entity, post['entities'][(entity, pos)])
    print
# Out:
# Four short links: 30 May 2017
# -----------------------------
# 	Google (1)
# 	World Problems (1)
# 	Biggest (1)
# 	Paper (1)
# 	Strong Story Hypothesis (1)
# 	Driven Perception Hypothesis (1)
# 	Problems (1)
# 	World (1)
# 	Implants (1)
# 	Continue (1)
# 	Matters (1)
# 	Google (1)
# 	Stuff (1)
# 	Cory (1)
# 	Medical Security Horrors (1)
# 	Whitescope (1)
# 	Cory Doctorow (1)
# 	Genesis (1)
# 	Infosec Dumpster Fires (1)
# 	Directed Perception Hypothesis (1)
# 	Systems (1)
# 	Strong Story Hypothesis (1)
# 	Wireshark (1)
# 	Hospital (1)
#
# Jupyter Digest: 30 May 2017
# ---------------------------
# 	Transportation Insights (1)
# 	O'Reilly (1)
# 	Jupyter (1)
# 	Machine Learning (1)
# 	Justin Tyberg (1)
# 	Continue (1)
# 	Jupyter Notebooks (1)
# 	Jupyter Digest (1)
# 	Apache Spark (1)
# 	Generation (1)
# 	Executive Transportation Group (1)
# 	Notebook (1)
# 	Notebooks (1)
# 	Tensorflow (1)
# 	Manning (1)
# 	Hands-On Machine Learning (1)
# 	Scikit-Learn (2)
# 	Interactive Dashboards (1)
# 	Python (1)
# 	Machine Learning (1)
#
# Jupyter Insights: Carol Willing, director of the Python Software Foundation
# ---------------------------------------------------------------------------
# 	Jupyter (9)
# 	Maarten Breddels (1)
# 	Carol Willing (1)
# 	August (1)
# 	Marc Colangelo (1)
# 	Jupyter Notebooks (1)
# 	Education (1)
# 	Jupyter (3)
# 	Python Software Foundation (1)
# 	Maarten (1)
# 	Jupyter (3)
# 	Jupyter Notebook (1)
# 	Yoshi Nobu Masatani (1)
# 	Jupyter Steering Council (1)
# 	Julia (1)
# 	New York City (1)
# 	Danelle Chou (1)
# 	Project Jupyter (1)
# 	Collaboration (1)
# 	Music21.Carol Willing (1)
# 	Justin Nand (1)
# 	Insights (1)
# 	Continue (1)
# 	August (1)
#
# How do I configure a Cisco router for secure remote access using SSH?
# ---------------------------------------------------------------------
# 	Cisco (2)
# 	Secure Shell (1)
# 	How (1)
#
# How do I recover the password on a Cisco router without losing its configuration?
# ---------------------------------------------------------------------------------
# 	How (1)
# 	Cisco (1)
#
# What is the OSI model?
# ----------------------
#
# Four short links: 29 May 2017
# -----------------------------
# 	Paul Grice (1)
# 	Buffers (1)
# 	Deep Blue (1)
# 	Learn Datalog (1)
# 	Kasparov (1)
# 	Learn Datalog Today (1)
# 	Correctness (2)
# 	Big Data (1)
# 	Datalog (1)
# 	Retires (1)
# 	Google (1)
# 	Datalog (1)
# 	Grice (1)
# 	Formally Verified Distributed Systems (1)
# 	Secrets (1)
# 	Three (1)
# 	Hassabis (1)
# 	Day (1)
# 	Prolog (1)
# 	Continue (1)
# 	Maxims (1)
# 	Google (1)
# 	Datomic (1)
# 	James Giongola (1)
# 	Datalog (2)
# 	Go (1)
# 	Ke Jie (1)
# 	Empirical Study (1)
# 	Designing Perfect Conversations (1)
# 	Cooperative Principle (1)
# 	Learn Datalog Today (1)
# 	Paper (1)
# 	Conversational Maxims (1)
# 	Grice ’ (1)
#
# Intelligent Bits: 26 May 2017
# -----------------------------
# 	Continue (1)
# 	French (1)
# 	Sukiyaki (1)
# 	Uber (1)
# 	Bits (1)
# 	Google (1)
# 	Intelligent (1)
# 	Deep (1)
# 	— Many (1)
# 	Phew (1)
# 	Brick (1)
# 	Contrary (1)
#
# Four short links: 26 May 2017
# -----------------------------
# 	Data (1)
# 	Stored (1)
# 	Deep Learning (1)
# 	Data Share (1)
# 	Service Availability (1)
# 	Service Availability (1)
# 	Google (1)
# 	Leslie Lamport (1)
# 	Calculus (1)
# 	Eventual Consistency Explained (1)
# 	Continue (1)
#
# Running a word count application using Spark
# --------------------------------------------
# 	Apache Spark ’ (1)
# 	Resilient Distributed Dataset (1)
#
# Peeking into the black box: Lessons from the front lines of machine-learning product launches
# ---------------------------------------------------------------------------------------------
# 	Grace Huang (1)
# 	Lessons (1)
#
# Using AI to create new jobs
# ---------------------------
# 	Tim O ’ Reilly (1)
#
# Lessons from piloting the London Office of Data Analytics
# ---------------------------------------------------------
# 	Data Analytics (1)
# 	Eddie Copeland (1)
# 	Lessons (1)
# 	London Office (2)
#
# Enabling data science in the enterprise
# ---------------------------------------
# 	National (1)
# 	Office (1)
# 	Enabling (1)
# 	Statistics (1)
# 	Tom Smith (1)
#
# Is finance ready for AI?
# ------------------------
# 	Aida Mehonic (1)
#
# Accelerate analytics and AI innovations with Intel
# --------------------------------------------------
# 	Ziya Ma (1)
# 	Accelerate (1)
# 	Intel (1)
#
# Data science and deep learning in retail
# ----------------------------------------
# 	Stanley (1)
# 	Data Show (1)
# 	O ’ Reilly Data Show Podcast (1)
# 	Jeremy Stanley (1)
# 	Instacart ’ (1)
# 	Jeremy Stanley (1)
# 	Continue (1)
# 	Data (1)
# 	Instacart (3)
#
# Travis Lowdermilk and Jessica Rich on building a customer-driven culture at Microsoft
# -------------------------------------------------------------------------------------
# 	Travis Lowdermilk (2)
# 	Jessica Rich (1)
# 	Lowdermilk (1)
# 	Jessica Rich (1)
# 	Microsoft.This (1)
# 	Microsoft (2)
# 	Rich (1)
# 	O ’ Reilly Design Podcast (1)
# 	Customer Driven Playbook (1)
#
# JupyterLab: The evolution of the Jupyter web interface
# ------------------------------------------------------
# 	Jupyter (9)
# 	Cal Poly (1)
# 	Dropbox Paper (1)
# 	Dropbox (1)
# 	Jupyter Notebook (5)
# 	Users (1)
# 	Jupyter Notebook (2)
# 	Google Drive (1)
# 	Brian Granger (1)
# 	Project Jupyter (1)
# 	Brian Granger (1)
# 	U.S. (1)
# 	Today (1)
# 	Publications (1)
# 	Project (1)
# 	Altair (1)
# 	Continue (1)
# 	Notebooks (1)
# 	Cal Poly (1)
# 	Fernando Perez (1)
# 	Jupyter (1)
# 	Leaflet (1)
# 	Cal Poly ’ (1)
# 	Are (1)
# 	Jupyter (2)
# 	Statistics (1)
# 	Jupyter ’ (2)
# 	Amongst (1)
# 	Physics (1)
# 	Beyond (1)
# 	Jupyter Steering Council (1)
# 	Jeremy Singer-Vine (1)
# 	Pro Publica (1)
# 	Cal Poly (2)
# 	Third (1)
# 	Markdown (1)
# 	Python (1)
# 	Data Science (1)
# 	Computational (1)
# 	Cal Poly San Luis Obispo (1)
#
# Jason Laska and Michael Akilian on using AI to schedule meetings
# ----------------------------------------------------------------
# 	Jason Laska (2)
# 	Michael Akilian (2)
# 	Clara ’ (1)
# 	O ’ Reilly Bots Podcast (1)
# 	Clara Labs (1)
# 	Laska (1)
# 	People (1)
# 	Laska.Continue (1)
# 	Clara Labs (1)
# 	O ’ Reilly Bots Podcast (1)
# 	Pete Skomoroch (1)
# 	Akilian (1)
#
# Four short links: 25 May 2017
# -----------------------------
# 	Crippling Genomic Research (1)
# 	Regulation (2)
# 	Look Around (1)
# 	Web Developer Security Checklist (1)
# 	Genomic Medical Era (1)
# 	U.K. (1)
# 	Investigatory Powers (1)
# 	Crypto (1)
# 	Jane Street (1)
# 	Americans (1)
# 	Precision Medicine Initiative (1)
# 	Are Bots (2)
# 	Act (1)
# 	Continue (1)
# 	Chaffinch (1)
# 	Web Security Chaffinch (1)
#
# Real-time intelligence gives Uber the edge
# ------------------------------------------
# 	M. C. Srivas (1)
# 	Uber (2)
# 	Uber (1)
#
# Another one bytes the dust
# --------------------------
# 	Paul Brook (1)
#
# Machine learning is a moonshot for us all
# -----------------------------------------
# 	Continue (1)
# 	Darren Strange (1)
# 	Machine (1)
#
# The data subject first?
# -----------------------
# 	Aurélie Pols (1)
#
# What Kaggle has learned from almost a million data scientists
# -------------------------------------------------------------
# 	Kaggle (2)
# 	Anthony Goldbloom (1)
#
# Highlights from Strata Data Conference in London 2017
# -----------------------------------------------------
# 	Data Analytics Eddie Copeland (1)
# 	London (1)
# 	Miriam Redi (1)
# 	Aida Mehonic (1)
# 	Accelerate (2)
# 	Anthony Goldbloom (1)
# 	Uber (3)
# 	Statistics (1)
# 	London (1)
# 	Tim O ’ Reilly (1)
# 	Strata Data Conference (2)
# 	National (1)
# 	Uber (1)
# 	Mike Olson (1)
# 	Watch (1)
# 	Aurélie Pols (1)
# 	Is (1)
# 	London Office (3)
# 	Lessons (2)
# 	Continue (1)
# 	Kaggle (3)
# 	Data Analytics (1)
# 	Lessons (2)
# 	Office (1)
# 	Intel (2)
# 	Intel Ziya Ma (1)
# 	M. C. Srivas (1)
# 	Watch (1)
# 	Grace Huang (1)
# 	Enabling (1)
# 	Paul Brook (1)
# 	Machine (1)
# 	Darren Strange (1)
# 	Data Analytics (1)
# 	Highlights (1)
# 	Strata Data Conference (1)
#
# The science of visual interactions
# ----------------------------------
# 	Miriam Redi (1)
#
# 12 qualities of effective design organizations
# ----------------------------------------------
# 	Foundation Often (1)
# 	“ Human (1)
# 	Deliver (1)
# 	Race (1)
# 	Monta Ellis (1)
# 	Great (3)
# 	Savvy (1)
# 	Strategy (1)
# 	Chapter (3)
# 	Productivity (1)
# 	Difficulty (1)
# 	Perspective (1)
# 	Leadership ’ (1)
# 	Structure (2)
# 	Output (1)
# 	Start (1)
# 	Entire Journey “ Support (1)
# 	Trello (1)
# 	Continue (1)
# 	Environments Marketing (1)
# 	Scale (1)
# 	Strategy (2)
# 	Empowered Leadership Successful (1)
# 	Operations (1)
# 	Resources (1)
# 	Technology (1)
# 	Table (1)
# 	Figure (1)
# 	Andrew Bogut (1)
# 	Job (1)
# 	Communications Interaction Design Information Architecture Visual Design Prototyping Industrial Design Wayfinding Interior Architecture Brand Identity Design Graphic Design Information Design Motion Graphics Packaging (1)
# 	Structure (1)
# 	Collaborative Environment (1)
# 	Mural (1)
# 	Background A (1)
# 	Facilitation (1)
# 	Designers (3)
# 	Macintosh (1)
# 	All Levels (1)
# 	Adaptive Path (1)
# 	Services (1)
# 	Inappropriate (1)
# 	Greatness (1)
# 	Authentic User Empathy Essential (1)
# 	User Experience (1)
# 	Use (1)
# 	Understand (1)
# 	Connect (1)
# 	Manage (2)
# 	Quality A (1)
# 	Internal (1)
# 	” Design (1)
# 	Output (3)
# 	Foundation (1)
# 	Silicon Valley (1)
# 	Foster (1)
# 	Harrison Barnes (1)
# 	Adam Cutler (1)
# 	Mark Jackson (1)
# 	Org (1)
# 	Tradecraft (1)
# 	Inneract Project (1)
# 	Sade (1)
# 	Designers (3)
# 	Work (1)
# 	Producer (1)
# 	Charters (1)
# 	Structure (2)
# 	Steve Jobs (1)
# 	Standards (1)
# 	Scientific Management (1)
# 	Strategy (1)
# 	Engineering (1)
# 	Purpose Meaning (1)
# 	Andre Iguodala (1)
# 	Managers (1)
# 	Key (1)
# 	Elements (1)
# 	Product Management (1)
# 	Diversity (1)
# 	New Riders (1)
# 	Mark Jackson ’ (1)
# 	Management (1)
# 	Jesse James Garrett ’ (1)
# 	Andrew Bogut (1)
# 	Adaptive Path (1)
# 	Creative Director (1)
# 	Software Products Hardware (1)
# 	Golden State (1)
# 	Surface (2)
# 	Journey → Service Design Don ’ (1)
# 	Actualized (1)
# 	Are (1)
# 	Nothing (1)
# 	Foundation (1)
# 	Discrete (1)
# 	Peter ’ (1)
# 	Foster (1)
# 	Editors (1)
# 	Leaders (1)
# 	Peter (3)
# 	Management (2)
# 	Klay Thompson (1)
# 	Avoid (1)
# 	Yes. ” (1)
# 	Launch (1)
# 	Dismissiveness (1)
# 	Level Playing Field Institute (1)
# 	Symptoms (1)
# 	Create Value (1)
# 	Figure (2)
# 	Draymond Green (1)
# 	Companies (2)
# 	Deliver (1)
# 	Articulate (1)
# 	Design (6)
# 	Warriors (2)
# 	Marketing (1)
# 	Design Practices Director (1)
# 	Management (1)
# 	Delivery Over Perfection (1)
# 	Publications (1)
# 	How (1)
# 	Mark Jackson (1)
# 	Slack (1)
# 	Products (1)
# 	No. (1)
# 	Stephen Curry (1)
# 	Lack (1)
# 	“ Leveraging Business Value (1)
# 	Understand (1)
# 	Thanks (1)
# 	Surface (1)
# 	General Assembly (1)
# 	Warriors (1)
# 	Foundation Output Management (1)
# 	Basecamp (1)
# 	Design (2)
# 	Seniority (1)
# 	No (1)
# 	Chapter (1)
# 	Picture (1)
# 	Teams (2)
# 	Steve Kerr (1)
# 	A (3)
# 	Individuals (1)
# 	Diversity (1)
# 	People (3)
# 	Treat (1)
# 	Sense (1)
# 	Foundation (1)
# 	Big (1)
# 	Director (1)
#
# Kelly Shortridge on overcoming common missteps affecting security decision-making
# ---------------------------------------------------------------------------------
# 	O ’ Reilly Security Podcast (1)
# 	Kelly Shortridge (1)
# 	Kelly Shortridge (1)
#
# 5 things to learn before learning React
# ---------------------------------------
# 	Level (1)
# 	React (3)
# 	Redux (1)
# 	React (3)
# 	React (1)
# 	Redux (1)
# 	React.If (1)
#
# Reliability with Kafka
# ----------------------
# 	Reliability (1)
# 	Confluent (1)
# 	Gwen Shapira (1)
# 	Apache Kafka (1)
# 	Continue (1)
# 	Gwen Shapira (1)
# 	Kafka (1)
# 	Kafka (1)
#
# Four short links: 24 May 2017
# -----------------------------
# 	Travel Mode (2)
# 	Threat Dragon (1)
# 	Adobe (1)
# 	Detail (1)
# 	Words (1)
# 	Travel Mode (2)
# 	Bach (1)
# 	Voice Editing (1)
# 	Safe (1)
# 	Tech Beacon (1)
# 	Justice (1)
# 	“ Justice (1)
# 	Continue (1)
# 	Wired (1)
# 	Windows (1)
# 	Zuckerberg (1)
# 	Voice Editing Software (1)
# 	Justice Data (1)
# 	Gates (1)
# 	Measures (1)
# 	Linux (1)
# 	America (1)
# 	Travel (1)
#
# Four short links: 23 May 2017
# -----------------------------
# 	Face Classification (1)
# 	Supreme Court Smacks Down Venue Shopping (1)
# 	Continue (1)
# 	Eastern District (1)
# 	Texas (1)
# 	Dan Meyer (1)
# 	Newcomers (1)
# 	East Texas (1)
# 	Welcoming Newcomers (1)
# 	Chrome (1)
# 	Stanford Law School (1)
# 	Patent Cases (1)
# 	Patent Win (1)
#
# Jupyter Digest: 22 May 2017
# ---------------------------
# 	Safari (1)
# 	Jupyter (1)
# 	Numerical Python (1)
# 	Allen Downey (1)
# 	R (1)
# 	Fortran (1)
# 	Packt (1)
# 	Unix (1)
# 	Python (1)
# 	Scientific Python Lectures (1)
# 	Continue (1)
# 	Software Carpentry (3)
# 	Tensorflow Machine Learning Cookbook (1)
# 	Robert Johansson (1)
# 	C (1)
# 	Jupyter Notebooks (1)
# 	Git (1)
# 	Jupyter Digest (1)
# 	Python (2)
# 	Are (1)
#
# Four short links: 22 May 2017
# -----------------------------
# 	Interactive Tutorial (1)
# 	Network Game (1)
# 	Oculus Rift (1)
# 	Continue (1)
# 	Tutorials (1)
# 	Guardian (1)
# 	Facebook (1)
# 	Meta Tutorial (1)
# 	Facebook Moderation (1)
# 	Netsim (1)
# 	Facebook (3)
# 	Indigenous Australia (1)
# 	Facebook Files (1)
# 	Aboriginal (1)
#
# Intelligent Bits: 19 May 2017
# -----------------------------
# 	Lattice (1)
# 	Apple (1)
# 	Structuring (1)
# 	General Catalyst (1)
# 	Google Brain (1)
# 	Alyosha Efros ’ (1)
# 	Berkeley (1)
# 	Intelligent (1)
# 	Turtles — Phil Libin (1)
# 	Continue (1)
# 	Apple (2)
# 	Bits (1)
#
# Four short links: 19 May 2017
# -----------------------------
# 	Magenta (1)
# 	Google Chrome (1)
# 	Economic Organization (1)
# 	Algorithmic Fallibility (1)
# 	Traffic Obfuscation (1)
# 	Bedlam (1)
# 	Google Releases Sketches (1)
# 	Engineer-Manager Pendulum (1)
# 	Comes (1)
# 	Continue (1)
# 	Engineer-Manager Pendulum Algorithmic Fallibility (1)
# 	Charity Majors (1)
#
# Activating human intrusion detection systems
# --------------------------------------------
# 	Activating (1)
#
# Exploring progressive web apps in the real world
# ------------------------------------------------
# 	Exploring (1)
#
# How to write a sound hypothesis when conducting user research
# -------------------------------------------------------------
# 	How (1)
# 	Cindy Alvarez (1)
#
# How AI is used to infer human emotion
# -------------------------------------
# 	Pepsi (1)
# 	Kaliouby (1)
# 	Technology (1)
# 	Think (1)
# 	Alexa (1)
# 	Fortune (1)
# 	Things (1)
# 	Facial Action Coding System (1)
# 	June (1)
# 	Experience (1)
# 	Internet (1)
# 	Ph.D. (1)
# 	Media Lab (1)
# 	New York City (1)
# 	Kaliouby (1)
# 	Rana (1)
# 	Affectiva (3)
# 	Artificial Intelligence Conference (1)
# 	Twitter (1)
# 	Canada (1)
# 	Emotion (1)
# 	U.S. (1)
# 	Rana (1)
# 	Affectiva ’ (1)
# 	Brain Power (1)
# 	Siri (1)
# 	Continue (1)
# 	Rana (1)
# 	Are (1)
# 	Google Glass (1)
#
# Paris Buttfield-Addison on what’s new in Swift programming
# ----------------------------------------------------------
# 	Swift (1)
# 	Paris Buttfield-Addison (1)
# 	Secret Lab (1)
# 	O ’ Reilly Programming Podcast (1)
# 	Learning Path Getting (1)
# 	Ultimate Swift Programming.Continue (1)
# 	Paris Buttfield-Addison (1)
# 	Learning Swift (1)
# 	O ’ Reilly Programming Podcast (1)
# 	Swift (2)
#
# Four short links: 18 May 2017
# -----------------------------
# 	Atom (1)
# 	Simpler Java (1)
# 	Steve Yegge (1)
# 	Dimensions (1)
# 	Politfact (1)
# 	Continue (1)
# 	Cohen ’ (1)
# 	Java (1)
# 	Kotlin (1)
# 	Tampa Bay Times (1)
# 	Marginal Revolution (1)
# 	Fact-Checkers (1)
# 	Android (1)
# 	Easy (1)
# 	Washington Post (1)
# 	Lumping (1)
# 	Fact Checker (1)
# 	Analogy (1)
# 	Mathematics (2)
# 	Pictorial (1)
# 	Java (1)
#
# Using Docker in production
# --------------------------
# 	Laura Frank (1)
# 	Laura Frank (1)
# 	Docker (1)
# 	Mesosphere (1)
# 	Docker Captain (1)
# 	Orchestration (1)
# 	Swarm Mode (1)
# 	Kubernetes (1)
# 	Docker (2)
# 	Docker (7)
# 	Codeship (1)
#
# How do I build an API?
# ----------------------
# 	Continue (1)
# 	How (1)
#
# How do I use an API?
# --------------------
# 	How (1)
#
# What is an API?
# ---------------
#
# How to do client-side form validation with Elm
# ----------------------------------------------
# 	How (1)
# 	Terms (1)
# 	Elm ’ (1)
# 	Emails (1)
# 	Form (1)
# 	Passwords (1)
#
# The stages of enterprise IoT adoption
# -------------------------------------
# 	Internet (1)
# 	Things.Continue (1)
# 	Teresa Tung (1)
#
# Four short links: 17 May 2017
# -----------------------------
# 	Economics (1)
# 	Cloud (1)
# 	Computational Theory (1)
# 	Stephen Wolfram (1)
# 	Apps (1)
# 	Science (1)
# 	Usage (1)
# 	Patterns (1)
# 	Imitation Learning (1)
# 	New Kind (1)
# 	Imitation Learning How Etsy Ships Apps (1)
# 	Continue (1)
# 	Adrian Colyer (1)
# 	Cloud Economics (1)
#
# Augmenting industrial reality
# -----------------------------
# 	Building (1)
# 	Integration (1)
# 	Economist (1)
# 	Augmenting (1)
# 	Chevrolet (1)
# 	Reality (1)
# 	Companies (1)
# 	Facebook (1)
#
# Four short links: 16 May 2017
# -----------------------------
# 	Data (1)
# 	Economics (1)
# 	De-Anonymizing Mobile Data (1)
# 	Ash (1)
# 	Crowds (1)
# 	Flash Organizations (1)
# 	Media Manipulation (1)
# 	Work (1)
# 	Trajectory Recovery (1)
# 	Netherlands (1)
# 	Economists (1)
# 	Economia (1)
# 	Disinformation Online (1)
# 	Organizations (1)
# 	Play (1)
# 	Money (1)
# 	Continue (1)
# 	Society (1)
# 	Collaboration Data Set (1)
# 	Complex (1)
# 	Olga Mink (1)
# 	Festival (1)
# 	Adrian Colyer (1)
# 	Flash (1)
# 	Organizations (1)
# 	Economy (1)
# 	Art (1)
# 	Wiepko Oosterhuis (1)
#
# Architecting actionable insights
# --------------------------------
# 	Architecting (1)
# 	Bas Geerdink (1)
# 	Spark (1)
#
# The business advantages of embedding analytics into applications
# ----------------------------------------------------------------
# 	Source (1)
# 	Logi Analytics (1)
# 	Solr (1)
# 	Spanner (1)
# 	Easy (1)
# 	Storm (1)
# 	Employees (1)
# 	Modern (1)
# 	Impala (1)
# 	Deeply (1)
# 	Done (1)
# 	O ’ Reilly (1)
# 	Cassandra (1)
# 	Jaspersoft (1)
# 	Access (1)
# 	Continue (1)
# 	Enter (1)
# 	Support (1)
# 	Modern Applications (1)
# 	Zoomdata (3)
# 	Amazon ’ (1)
# 	Business (1)
# 	Microsoft ’ (1)
# 	Connects (1)
# 	Criterion (1)
# 	Hive (1)
# 	O'Reilly (1)
# 	Google ’ (1)
# 	Combine (1)
# 	Hadoop (1)
# 	Requirements (1)
# 	Lightweight (1)
# 	Analytics (1)
# 	Spark (1)
# 	Figure (2)
# 	Kafka (1)
# 	Support (1)
# 	Figure (1)
# 	Organizations (1)
# 	Performance (2)
# 	Pentaho (1)
# 	Redshift (1)
# 	Categories (1)
# 	Delivering Embedded (1)
#
# How can I deploy a multi-container application with Docker Compose?
# -------------------------------------------------------------------
# 	Docker (1)
#
# How do I package my Java application as a Docker image using Gradle?
# --------------------------------------------------------------------
# 	Java (1)
# 	Java (2)
# 	How (1)
# 	Gradle (1)
# 	Docker (3)
#
# How do I create Docker images and run containers using Maven?
# -------------------------------------------------------------
# 	Java (1)
# 	How (1)
# 	Docker (1)
# 	Apache Maven (1)
# 	Docker (2)
#
# Get introduced to the new Java® 9 Platform Module System (JPMS) with Paul Deitel
# --------------------------------------------------------------------------------
# 	Paul Deitel (1)
# 	Java (4)
# 	Java. ” Paul Deitel (1)
# 	Basics (1)
# 	Docker (1)
# 	O ’ Reilly ’ (1)
# 	Programmers (1)
# 	Things (1)
# 	Java Platform—Previously (1)
# 	Java® (1)
# 	Oracle Java Champion (1)
# 	Deitel (1)
# 	Safari (1)
# 	Associates (1)
# 	Use (1)
# 	Internet (1)
# 	Voice (1)
# 	Up (1)
# 	Designing (1)
# 	Understand (1)
# 	Visit Safari (1)
# 	O'Reilly (1)
# 	O'Reilly (1)
# 	Java (1)
# 	December (1)
# 	Deitel ’ (1)
# 	Python (1)
# 	Java® (3)
# 	Review (1)
# 	Java Platform (1)
# 	Greater (1)
# 	Platform Module System (1)
# 	Introduction (2)
# 	Production (1)
# 	Indicate (1)
# 	Get (1)
# 	Measurement Essentials (1)
# 	Java Platform Module System (1)
# 	Modularize (1)
# 	Practice (1)
# 	Create (1)
# 	Design Thinking (1)
# 	Java Platform Module System (1)
# 	Continue (1)
# 	Use (1)
# 	Platform Module System (2)
# 	Better (1)
# 	Modularity (2)
# 	Running (1)
# 	Inc. (1)
#
# Jupyter Digest: 15 May 2017
# ---------------------------
# 	Jupyter (2)
# 	Tomáš Bouda (1)
# 	Day (1)
# 	Richard Zhang (1)
# 	Algorithms (1)
# 	Python (1)
# 	Continue (1)
# 	Deep Colorization (1)
# 	Experiences (1)
# 	Aug (1)
# 	Dorothea Lang (1)
# 	Jupyter (1)
# 	Days (1)
# 	Jupyter Digest (1)

# %% [markdown]
# ## Example 9. Discovering interactions between entities

# %%
import nltk
import json

BLOG_DATA = "resources/ch05-webpages/feed.json"

def extract_interactions(txt):
    sentences = nltk.tokenize.sent_tokenize(txt)
    tokens = [nltk.tokenize.word_tokenize(s) for s in sentences]
    pos_tagged_tokens = [nltk.pos_tag(t) for t in tokens]

    entity_interactions = []
    for sentence in pos_tagged_tokens:

        all_entity_chunks = []
        previous_pos = None
        current_entity_chunk = []

        for (token, pos) in sentence:

            if pos == previous_pos and pos.startswith('NN'):
                current_entity_chunk.append(token)
            elif pos.startswith('NN'):
                if current_entity_chunk != []:
                    all_entity_chunks.append((' '.join(current_entity_chunk),
                            pos))
                current_entity_chunk = [token]

            previous_pos = pos

        if len(all_entity_chunks) > 1:
            entity_interactions.append(all_entity_chunks)
        else:
            entity_interactions.append([])

    assert len(entity_interactions) == len(sentences)

    return dict(entity_interactions=entity_interactions,
                sentences=sentences)

blog_data = json.loads(open(BLOG_DATA).read())

# Display selected interactions on a per-sentence basis

for post in blog_data:

    post.update(extract_interactions(post['content']))

    print post['title']
    print '-' * len(post['title'])
    for interactions in post['entity_interactions']:
        print '; '.join([i[0] for i in interactions])
    print
# Out:
# Four short links: 30 May 2017
# -----------------------------
# World Problems; Story AI; Medical Security Horrors; OSS Fuzz; World; Biggest; Problems; data; Stuff
# Strong Story Hypothesis; Directed Perception Hypothesis; humans; primates; part; answer; Strong Story Hypothesis; role
# hypothesis; Driven Perception Hypothesis; sense; sense; story understanding; apparatus
# Paper; CSAIL; Genesis; story system; tells; stories; sense; rules; level concept
# Implants; Hospital; Systems; Infosec Dumpster Fires; Cory Doctorow; pointers; writeups; horrors
# Whitescope; whitepaper; pacemaker security; pacemaker; devices; manufacturers; devices; pacemaker; radio; signals; vulnerabilities; authentication; pacemakers; pacemaker; programmers; way; pacemaker; device; attacker
# Cory; points; DMCA; exemption; paper; expiring; b; release; code; stuff
# OSS Fuzz Improving Open Source; Google; source fuzzer; security; vulnerabilities; source; projects; FreeType2; FFmpeg; LibreOffice; SQLite; GnuTLS; PCRE2; gRPC
# service; Google
# criteria; projects; base and/or; IT
# Continue; links
#
# Jupyter Digest: 30 May 2017
# ---------------------------
# generation; RNNs; Tensorflow; book companion; notebooks; transportation; insights; notebooks; machine learning
#
# list; paint; names; network; Notebook; walkthrough; theory
# TensorFlow Book; companion
# Manning; MEAP; program; access
# Machine Learning; TensorFlow MEAP; winner; companion
# progress; books
# Transportation Insights; Jupyter Notebooks; Interactive Dashboards
#
# post; Justin Tyberg; IBM; bunch; source; data; Executive Transportation Group; @
#
# set; notebooks for—you; machine learning; Python; Scikit-Learn
# Jupyter; resource; O'Reilly; companion; Hands-On Machine Learning; Scikit-Learn
# Continue; Jupyter Digest
#
# Jupyter Insights: Carol Willing, director of the Python Software Foundation
# ---------------------------------------------------------------------------
# Jupyter; learning tool; JupyterHub Project; Music21.Carol Willing; director; Python Software Foundation; Jupyter Steering Council; member; geek; residence; FabLab San Diego; electronics
# shares; thoughts; state
# JupyterCon; August
#
#
# Jupyter Notebooks; way; concepts; languages
# example; Julia; ability; prose; code; snippets; YouTube video; snippets; notebook document
#
# notebooks; students; ability; interact; material; confidence; notebooks; takeaway
#
# Jupyter; way; team
#
# Project Jupyter; developers
# ability; ideas
# concepts; share
#
#
#
# JupyterHub; person; organization; notebook; servers; group
# installation; configuration; management; JupyterHub
# enhancements; Jupyter; projects; project; list; newsletters; Jupyter; team; work; Jupyter
# ways; community; share; projects; practices
# Education; research; team; community; share
#
#
# JupyterHub; learners; music; music21 library; TensorFlow; Jupyter
# attendees; newcomers; Jupyter
# hallway track; ideas
#
#
#
# conference attendee replicator; August; forward; stars; Jupyter Notebook
# Maarten; work; visualization; interactivity; documentation; projects
# Collaboration; operation; literate computing; infrastructure; Yoshi Nobu Masatani; work; Jupyter; DevOps; infrastructure
# Jupyter; intersection; robots; biology; Marc Colangelo; Justin Nand
# combination; robots; software; biology; collaboration; software; engineers
#
#
# Continue; Jupyter; Insights; Carol Willing; director
#
# How do I configure a Cisco router for secure remote access using SSH?
# ---------------------------------------------------------------------
# configuration; steps; Cisco; router; Secure Shell; SSH; connections; terminal; VTY; How; Cisco; router; access
#
# How do I recover the password on a Cisco router without losing its configuration?
# ---------------------------------------------------------------------------------
# configuration register; router password; configurations.Continue; How; password; Cisco; router
#
# What is the OSI model?
# ----------------------
# networking concept; systems; OSI
#
#
# Four short links: 29 May 2017
# -----------------------------
# Correctness; Conversational Maxims; Learn Datalog; AlphaGo Retires; Empirical Study; Correctness; Formally Verified Distributed Systems; Paper; Day; verification
# group; bugs relates; assumptions; behaviour; components
# bugs; interface; layer
# Buffers; reads
# Google; Three; Secrets; Designing Perfect Conversations; secret; line; leads; James Giongola; lead; conversation design; voice direction
# chat; designers; advantage; rules; Cooperative Principle; concept; philosopher
# Grice; people; sorts; norms; Grice ’; s; Maxims
# maxims; hacks; anyone; key; bot; information
# Learn Datalog Today; Learn Datalog Today; tutorial; Datomic; dialect
# Datalog; database query language; roots
# Datalog; power
# Prolog; query language; Big Data
# info; Datalog
# AlphaGo; Retires; DeepMind; data; games; AI; playing; Go
# DeepMind; tool; AlphaGo
# Ke Jie; DeepMind; tool; Hassabis; players; opportunity; game; lens
#
# IBM; Deep Blue; team; software beat
# humans; software; feels; engineers; game
#
# Continue; links
#
# Intelligent Bits: 26 May 2017
# -----------------------------
# Sukiyaki; French; style; conversion tracking; pricing
# Deep; recipe transfer; — Many; results; ability; patterns; styles
# researchers; nets; recipes; styles
# Brick; mortar; bucks; Google; ad; campaigns; visits; sales; machine learning; wealth; user; data; geolocation; search history; web browsing; interactions; credit card transaction
#
# Uber; applies; machine; pricing
# Phew; alarm —; Contrary; outcry; dislocation; labor; think tank; innovation; productivity
# Continue; Intelligent; Bits
#
# Four short links: 26 May 2017
# -----------------------------
# Service Availability; Data Share; Eventual Consistency Explained; Deep Learning; Calculus; Service Availability; service; intersection
# service; aims; % availability; dependencies
# Google; rule; thumb; dependencies; example case; %; service; dependencies
#
# datproject; source crypto—guaranteed; data; share
# Data; Stored; consistency
# paper; Leslie Lamport; spells; everything
# OpenAI Baselines; source; implementations; algorithms
# papers; details; implementation; others
#
# Continue; links
#
# Running a word count application using Spark
# --------------------------------------------
# Apache Spark ’; Resilient Distributed Dataset; RDD; API.Continue; word count application
#
# Peeking into the black box: Lessons from the front lines of machine-learning product launches
# ---------------------------------------------------------------------------------------------
# Grace Huang; shares lessons; experiments.Continue; box; Lessons; lines; product
#
# Using AI to create new jobs
# ---------------------------
# Tim O ’ Reilly; transitions; speculates; possibilities; AI; choices; creations.Continue; AI
#
# Lessons from piloting the London Office of Data Analytics
# ---------------------------------------------------------
# Eddie Copeland; London Office; Data Analytics; barriers; sector; data; city scale.Continue; Lessons; London Office
#
# Enabling data science in the enterprise
# ---------------------------------------
# Tom Smith; UK; Office; National; Statistics; data; science; research.Continue; Enabling; data; science
#
# Is finance ready for AI?
# ------------------------
# Aida Mehonic; role; intelligent; world.Continue reading
#
# Accelerate analytics and AI innovations with Intel
# --------------------------------------------------
# Ziya Ma; challenges; machine learning; learning; scale; shares solutions; Intel; customers; partners.Continue; Accelerate; analytics; AI; innovations
#
# Data science and deep learning in retail
# ----------------------------------------
# O ’ Reilly Data Show Podcast; Jeremy Stanley; hiring; machine; engineers; data; products.In; episode; Data Show; Jeremy Stanley; VP; data; science; Instacart
# Stanley; Instacart; marketplace; stores; products; stores; shoppers; stores; customers; order
# objective; groceries; retailers; customers
# Instacart ’; s; goals; center; opportunities; challenges; data
# Continue; Data; science
#
# Travis Lowdermilk and Jessica Rich on building a customer-driven culture at Microsoft
# -------------------------------------------------------------------------------------
# O ’ Reilly Design Podcast; teams; customer; design; research; Microsoft.This; week; Travis Lowdermilk; UX; designer; Microsoft; Jessica Rich; UX; researcher; Microsoft; Lowdermilk; Rich; co-authors
# fast; approach; track; customer; ’; s voice.Continue; Travis Lowdermilk; Jessica Rich; culture
#
# JupyterLab: The evolution of the Jupyter web interface
# ------------------------------------------------------
# Project; Jupyter; co-founder; Brian Granger; JupyterLab; project; role; communities; role
# Brian Granger; professor; physics; Cal Poly San Luis Obispo; university; ’; s undergraduate; data
# area; research; data
# IPython Notebook; co-founders
# contributor; co-leader; JupyterLab; project; Jupyter Notebook; interface; level; building; blocks
# JupyterLab; feedback; notebook; users; design; features; computing; communities; role; notebooks; academia; data
# JupyterLab; “; evolution; Jupyter; web interface; Jupyter Notebook; number; building; blocks; computing; notebook; file browser; text editor; terminal
# JupyterLab; evolution; notebook; way; building
# user ’ s perspective; everything
# team; Jupyter; fronts; software; design
# individuals; Jupyter Steering Council; foundation; project; contributors; project
# team building; JupyterLab; PhosphorJS; force
# Fernando Perez; creator; IPython; co-founder; Jupyter; wilderness
# need; JupyterLab; Jupyter Notebook; users; data; science
# IPython Notebook; lot; time; users
# pain; points; Jupyter Notebook; others; challenges; code
# IBM; user experience survey; results
# feedback; key; factors
# users; notebook experience; core; characteristics; Jupyter
# notebook abstraction; JupyterLab—but
# improvements; notebook; UI/UX; JupyterLab; notebooks; fact; %; document format
# users; building; blocks
# usage pattern; scientists; Python; shell; notebook; service
#
# JupyterLab; pain; points
# example; JupyterLab; code console; exploration; Jupyter ’; output; text file editor; blocks; code; text file
# Third; collaboration; area
# groups; organizations; Jupyter; others
# notebooks; GitHub; Dropbox; email; ’
# step; collaboration; style; Google Drive
# JupyterLab; abstractions; collaboration; documents; notebooks; text
# postdocs; UC Berkeley; prototype; collaboration; JupyterLab; designers; Cal Poly
# lot; fun; right
# CoCalc; SageMathCloud; custom notebook; end; Jupyter
#
# core; abstractions; JupyterLab; times
# architecture; implementation; abstractions; features
# example; support; GeoJSON; CSV
# JupyterLab; extensions; handlers; users; file
# t; others; experience
# JupyterLab; user; GeoJSON; file; map; Leaflet; view; CSV
# views; document; models; user; files; text editor; versions
# abstractions; Markdown
# number; features; summer release; JupyterLab; theme switching; nbextensions; kernels; output
# team; features
# characteristic; JupyterLab; feature parity
# deliberate; choices; work; features; notebook; features; JupyterLab; software/API perspective; UI/UX
# UI/UX; side; number; issues; notebook; beginning; code; cells; user experience
# Users; things hundreds; thousands; times
# software/API perspective; APIs
# APIs; sense; UI/UX
#
# priority; users; organizations; transition; notebook
# transition; time; lot; support
# Beyond; collaboration; ’; t; release; area
# feature; work
# components; work; teaching
# side; Cal Poly ’; s undergraduate; Data Science; program; Statistics; CS
# instructors; program; notebook; JupyterHub; in-class; lectures; homework
# Computational; Physics; course
# courses; point; imagine; code+data
# research side; Jupyter; area
# terms; academia; code; data; papers; output
# Cal Poly; phrase; validation; ”; evidence; others
# Publications; journals; form
# source software; user; developer; communities
# credit; Cal Poly; department; tenure; work
# Today; data; remains; area
# Jupyter; source; projects
# Notebooks; utility; computer science; data; science
# Are; increase
# usage; Jupyter ’; usage; data
# years; news; organizations; data
# Amongst; others; FiveThirtyEight; LA Times; Pro Publica; surprise
# Jeremy Singer-Vine; team; BuzzFeedNews; way; bar; data
# GitHub; repository; dataset; analysis; Jupyter Notebook; news; articles
# news; organizations
# backlash; science; reality; U.S.; work; Jupyter
# Continue; JupyterLab; evolution; Jupyter
#
# Jason Laska and Michael Akilian on using AI to schedule meetings
# ----------------------------------------------------------------
# O ’ Reilly Bots Podcast; dynamics; problems.In; episode; O ’ Reilly Bots Podcast; Pete Skomoroch; Jason Laska; Michael Akilian; Clara Labs; creator; assistant—Clara—that; schedules meetings; interacts; language
# E-mail; venue
# e-mail; way; businesses
# conventions; reports; receipts; ripe
# Laska; machine learning; efforts; Clara Labs; Akilian; company; ’; co-founder; CTO; talk; reality; product; Clara ’
# People; aspects; work; ’; people; ”; Laska.Continue; Jason Laska; Michael Akilian; AI
#
# Four short links: 25 May 2017
# -----------------------------
# Crypto; vs.; Regulation; Crippling Genomic Research; Are Bots; Web Security Chaffinch; crypto system; response; attempt
# Chaffinch; system; messages
# cover traffic; authorities; information
# system; terms; threat; confidentiality; eavesdroppers; power; terms; interaction; U.K.; Regulation; Investigatory Powers; RIP; Act; laws
# Genomic Medical Era; DJ Patil; Precision Medicine Initiative; Americans; country; concern; data; couldn; ’; t; families; information; share; basis
# threat; data; way; research; fear; people; t
# people; diseases
# Are Bots; Look Around; Renee DiResta; finance; advent; high-frequency trading; world; trader; Jane Street; technology; information; flows; access; way; game; marketplace
# future; lot; finance
# Web Developer Security Checklist; checklist
# web; applications; years; list; issues
#
# Continue; links
#
# Real-time intelligence gives Uber the edge
# ------------------------------------------
# M. C. Srivas; Uber; data; architecture; problems; Uber; ride; intelligence; Uber
#
# Another one bytes the dust
# --------------------------
# music industry; example; Paul Brook; information; points; data; way; organization; decisions.Continue
#
# Machine learning is a moonshot for us all
# -----------------------------------------
# Darren Strange; part; play; times; computer science; Continue; Machine; learning
#
# The data subject first?
# -----------------------
# Aurélie Pols; picture; data; ecosystem; hones; right; portability.Continue; data
#
# What Kaggle has learned from almost a million data scientists
# -------------------------------------------------------------
# Anthony Goldbloom; shares lessons; performers; Kaggle; community; types; machine-learning; techniques; Kaggle; data
#
# Highlights from Strata Data Conference in London 2017
# -----------------------------------------------------
# Watch; highlights; business; data; engineering
# Strata Data Conference; London; data world; London
# links; highlights
# AI; jobs; Tim O ’ Reilly; transitions; speculates; possibilities; AI; choices
#
# science; interactions; Miriam Redi; machine learning; properties; images; videos; beauty; creativity
#
# Machine learning; moonshot; Darren Strange; part; play; times
# Machine; learning
# Kaggle; data; scientists; Anthony Goldbloom; shares lessons; performers; Kaggle; community; types; machine-learning
# Kaggle; data
# dust; music industry; example; Paul Brook; information; points; data; way; organization
#
#
# Aurélie Pols; picture; data; ecosystem; hones; right
#
# intelligence; Uber; edge; M. C. Srivas; Uber; data; architecture; problems; Uber; ride
# intelligence; Uber
# Lessons; London Office; Data Analytics Eddie Copeland; London Office; Data Analytics; barriers; sector; data
# Lessons; London Office
# Accelerate; analytics; AI; innovations; Intel Ziya Ma; challenges; machine learning; learning; scale; shares solutions; Intel; customers
# Accelerate; analytics; AI; innovations
# data; science; enterprise; Mike Olson; UK; Office; National; Statistics; data; science
# Enabling; data science
#
# Aida Mehonic; role; intelligent
# Is; finance ready
# box; Lessons; lines; product; launches; Grace Huang; shares lessons
# box; Lessons; lines; product
# Continue; Highlights; Strata Data Conference
#
# The science of visual interactions
# ----------------------------------
# Miriam Redi; machine learning; properties; images; videos; beauty; creativity; sentiment.Continue; science
#
# 12 qualities of effective design organizations
# ----------------------------------------------
# design team.In; things; NBA; basketball team; Golden State
# years; leadership; performance; owners; moves; player; Monta Ellis; Andrew Bogut; coach
# couple; years; acquisition; team; roster; Stephen Curry; Klay Thompson; Harrison Barnes; Draymond Green; Andre Iguodala
# games; time; years; round
# Internal; turmoil; coaching staff; Mark Jackson ’; approach; way; highway; —assistants
# playoffs; Mark Jackson; Steve Kerr; coaching staff; management style; disagreement; search
# leadership; roster; changes; Warriors; league; games; NBA
#
#
# roster; moves; Warriors; playoffs; time
# talent isn; ’
# lesson; team; management; leadership
# Design; teams; area; functions; engineering; marketing; design
# nascency; people; organization; design team; b; designers; t; part; teams; t; order
# design; teams; talent; role; chapter; t
# design team; ’; s output; result; skill; sophistication
# chapter; set; qualities; design
# team ’; performance; qualities clarifies opportunities
# qualities; groups; Foundation; Output; Management
# Foundation; core; concepts; team; ’; s behavior
# Foundation; energies; Output
# qualities; split; design; theme
# Output; Management
# Output; people; team; quality work; set
# Management; unsung; aspects
# team longevity; impact; operations
#
#
# qualities; design; organizations
#
#
#
# Understand; articulate
#
# Deliver; levels
#
#
# Treat; team; members; people
# Diversity; perspective
#
# Manage; operations; Foundation Often; rush; design team; place; work; components; values; principles
# team; objectives
# foundation; work; team
#
# Sense; Purpose Meaning; purpose; organizations; level
# Companies; mission; statements; orient
# Individuals; passions; behavior
# teams; sense; purpose; identity
# supports; design; teams; beacon; talent; purpose; A; rallying cry; team; members; work; signal; rest; organization; team; way; sense; purpose
# Charters; shapes; sizes; mission; statements; documents
# Start; brief
#
#
#
#
#
# complexity; offering; coherent; experience
# Empowered Leadership Successful; teams; design; teams
# Leaders; understanding; team; decisions; team; respect; team; ’
# team understanding; rest; organization
# design; ’; s nascency; function; design leadership
# design; teams; squad; designers; someone; designer; product management; engineering
# extent; teams; start; journey; part; company
# company; ’; t; wherewithal
# frustrating; organizations
# example; Silicon Valley; company; design; directors; peers; reporting; VP
# design; presence; actuality none; design; directors; head
# person; decisions; design team; t; potential
# design team; charge; destiny; leadership; autonomy
# leadership; phrase; “; leadership ”; people; design; design; leaders
# design; leaders; issues; quality; mistake; companies; role; design visionary; director; ideas; attention
# design organization; entity; care; nurturing; diplomacy
# skills; someone; designer; director; skills; manager
# design leader; ’; responsibilities; executives; path; design; manager; mentor; team builder; operator; team; space
# organizations; leader
# fact; quality; “ singular; leadership; ”; line; authority; design organization; set; leaders; peers
# team; leadership; two—one person
# examples; split
# Technology; organizations; CTO; software architect; VP; Engineering
#
# filmmaking; Director
# design; teams; Creative Director; VP; Design; roles; detail
# partnership model; leader; journey; initiatives; leader; portfolio planning; capacity; hiring; budgeting; operating plan.Autonomy; leadership; autonomy
# Leadership ’; responsibility; organization; role; design; ’; t conform
# freedom; methods; practice
# design; teams; capacity; leadership
# design; contributor; efforts; matters; No; ”; access; design; potential; leadership; rungs; CEO; executive
# C-suite; ”; politics; reality
# distance; others; design; ’
# Executive engagement; form; sponsorship; cover; reporting; structures; importance; design
# executive support; role; design
# Authentic User Empathy Essential; design; ’; s ability; understanding; contexts
# practices; market research; user testing; engagement; lives
# Nothing; people; homes; offices
# methods; analytics; surveys; data; things; t; findings; efforts; optimizations; point
# user research; field
# work; customer ’ s journey; breakdowns; people; things; siloed; departments
# benefit; observations; designers; users; turns; systems; impact; solutions
# benefit; executives; people; authority; design; results; research; data; e.g.; videos; people; frustration; situation; analyses
# executives; breakdowns; opportunity; design; service design; solutions
# Understand; Articulate; Create Value; bust; recession; cry heard; software design community; How; return; investment; ROI; ”; time; companies; design; cost; business; something
# Adaptive Path; question; research; report; “ Leveraging Business Value; How ROI Changes User Experience.; equation; x; design; value; report; research; ROI; valuation; methods; design competency
# valuation; methods; tools; design strategy; component; business strategy; ability; value; ” user; experience design; business lever; par; marketing; research; development
# result; techniques; experience investment; decisions; impact; design; teams
# design; ’; s success; report; value; design
# design organization; potential; members; language; value
# designers; cloak; creatives; way; business; impact
# Designers; work
# designers; practice; ’; s-sake; s; ’; t; company; ’; s
# Savvy; design; leaders; business value; input
# ’; “; ”; metrics; conversion; rates; times; ”; matters; company; ’; s brand; way; connections; company; design; efforts
# business; objectives; user empathy; means
# design; organizations; ways; business value; credibility; impact increases.Output; place; people
# qualities; design organization; ’; s capability
#
# Entire Journey “ Support; journey ”
# design team; access; aspects; customers
# change; rest; organization; design; design team; areas; practices; sales
# implication; design organization
# practice; companies; product; UX; design team
# legacy; mass manufacturing thinking; way; product
# services; world
# Marketing; ”; product ”; experiences; milestones
# marketing design; media; publications; broadcast; billboards; product design; thing; shelf; world; software; platform; marketing; product; experiences; realms; email; web
# efforts; media—users; t interact; products; billboard—but
# Companies; “ marketing ”; product ”; distinctions; way; opportunities; rise; growth; ”; product development; marketing function; users; part
# design organization; end; customer; ’; s journey; implication; arises; need; array; design; skills; totality
#
#
# design; service experience; Software Products Hardware; Products; Environments Marketing; Communications Interaction Design Information Architecture Visual Design Prototyping Industrial Design Wayfinding Interior Architecture Brand Identity Design Graphic Design Information Design Motion Graphics Packaging; Journey → Service Design Don ’; t; breadth; teams
# design organization; delivery; design; practices; people; contractors; agencies
# design; journey; sum; practices; design organization
# Facilitation; design; A; implication; arises; recognition
# world; journey; matter
# parts; knowledge
# Designers; skills; practice
# output; others; organization
# hospital setting; nurses; technicians; doctors
# call center; customer service; representatives
# point isn; ’; t; input; design organization; responsibility; refining; honing
# problems; solving; team
# Deliver; All Levels; Scale; team; range; skills; scale; “; picture; pixel
# scale; product; services; view; feet; foot; place design work; scale
#
#
# Design; work; people; effort; artifacts; product; service; experiences; levels; effort; percentages; staff breakdown—while; individuals; level
# percentages; effort; levels; levels; order; design
# design organization; levels; scale regardless
# organization; design function; implication; designer; ’; way; someone
# designers; bulk; level work; %; time; Surface; %; Structure; organization; %; time; Structure; %; time; Strategy; %; Big
# design; leaders; organization; model; set
# Peter; design; company; organization; efforts; product; managers; requirements; comps; research; impact
# immaturity; rest; organization—product; managers; engineers; design
# team; ’; s capability; Surface; level; mediocre; Structure; matters
# design; way
# drove; Peter ’; decision; designers; work; Structure; Strategy
# design; ’; s influence
# Standards; Quality A; design organization; quality
# tricky; ’; definition
# high-quality engineering ”; metrics; reduction; bugs; speed; performance; service; high-quality design ”; measures; preference
# solutions; performance; measures; conversion; rates; task completion
# assessment; quality; eyes
# design organization; quality; standards; team
#
# goal; subjectivity; equation; design critique; stance; preferences; “; shade; ”; desire; “; logo; ”; set; principles; guidelines; team; ’; definition; quality; examples; design work; quality
# design org; quality; standards; standards
# rest; organization; way
# People; design team don; ’; t; quality bar; design; teams; things; people
#
# Designers; couple; traits
#
# Designers; others; clients; colleagues
# thing; default; Yes. ”; revulsion; work
# something; wasn; ’; t; try; way; part; ’
#
# Teams; programs; hours
# design organization; crap; things; rest; organization; design
# Design; leaders; power; No.; ” Design; work; time
# schedules; rumination
# leaders; points; design practice; returns; effort
# design organization; quality; work
# design; organizations; process; proxy
#
# thinking; work; over-adherence; methodology
# process; approach; designers; functions; step-by-step process; project; rigidity
# Design; problems; design; teams; range; approaches
# “; design process ”; plan; process; assumption; dogma; crutch
# process; design leadership; effort; ways; challenges
# Delivery Over Perfection; world; speed; talk; quality
# delivery; perfection ”; quality. ”; ’; quote; Steve Jobs; development; Macintosh; artists; craftspeople; kind; impact; work
# Designers; trouble; delivery; part
# school; time; something
# design; practices; roots; media; something; s; world
# background; perfectionism
# software; services
# delivery; habit; event; idea; Launch
# delivery; excuse; stuff
# place; leadership; play; balance; quality; delivery; matter
# IBM; designers; something; software; recognition; designers; pursuit
# something; “; ”; team; ’; t; design; way; quality; assessment; use; people.Management; A; aspect; health; design team
# Design; leaders; managers; lack familiarity; interest; nuts; bolts
# management; practices; design team; hornet ’; nest; disillusionment; quality; team; ’; s output; jeopardy
#
# Teams; People; department name; “ Human; Resources; ”; companies; employees—not; people; units; role; company; ’
# Design; leadership; effort; organization; ’; s approach; team; members
# return; members; work
# characteristics; team environment; team; members
# Are; members
# byproduct; work; environments; employees; cogs; machine
# Job; titles; equivalence; interchangeability; anyone
# Discrete; levels; seniority
# Org; delimit access
# Actualized; design; teams; practices; team; members; individuals
# job; titles; people; title
# OK; everyone; people; strengths; weaknesses
# Seniority; levels; guidelines
# structures; communication; mentorship; anyone; ’; ability; share; ideas
# perspective; design organization
# Designers; professionals
# labels; levels; individuality; engagement; turn
#
# freak; flags; team; members
#
# work; environments; team; members; work; people; hours
# work; weeks; whammy; struggle; balance; designers; professionals
# production; hours; quality
# Productivity; decisions designers; team
# team; desire
# room; skills; building
# People; design crank; %
# Managers; members; craft; cross-train; skills
# budget; education; conferences; workshops
# Great; design; managers; direction; lots; don; ’; t tell; folks; tools; techniques
# development; skills; building; career; paths
# Diversity; Perspective; Background A; mistake; design; managers; team
# re; reason
# team; clones; problems; fashion; groupthink; exploration; solutions
# Key; design process; period; divergent thinking; practices
# divergence; work; diversity; perspectives
# problem; range
# years; schools; software design; people; range; founders; Adaptive Path; degrees; history; journalism; anthropology
# software design; schools; graduates; risk; processes; dogma; mindset; design
# programs; General Assembly; Tradecraft; people
# Avoid; hiring; set
# design; professionals; male/female; lines; product design; teams; lack; gender; diversity
# Peter; company; product design team; men; women
# Peter; team; ’; s worldview; expectations; users; degree; savvy
# company; ’
# design team shouldn; ’; base; research; empathy; ourselves; variety; perspectives; backgrounds; designers; times
#
# Race; diversity; challenges; design industry; years; authors
# problem; diversity; lack
# candidates; recruiting; interviewing; promotion
#
# Work; schools; universities; design; exciting; field; practice; communities
# Connect; organizations; Inneract Project; http; //www.inneractproject.org; Level Playing Field Institute; http; //www.lpfi.org; missions; opportunities
# recruiting; interviewing; practices; competencies; results; tools; assessment; analysis; candidates; ’; work
# Foster; Collaborative Environment; benefit; diverse; perspectives; environment; people; work; collaboration; output
# member; team; respect; member; openness
# Dismissiveness; insults; cattiness; behind-the-back; gossip
# team; feedback
# ’ s respect; order; team; ”; frank; critique; feedback; quality
# Greatness; tension; collision; perspectives; concept
# Design; teams; politeness; candor
# hierarchy; flow; ideas; design; people
# cliche; repeating—great
# Great; design; leaders
# leaders; work; others; others; critique; grace
#
# Great; design work; space—places; whiteboards; ideation; walls
# spaces; places; team
# engagement; team; spaces; people; team
#
# share-outs; preparation; time; productivity; spaces
# work; track
# spaces; offices; people; fashion; effort
# Thanks; host; tools; Basecamp; Slack; Trello; Mural; others; designers
# solutions; project room; effort
# Chapter; environments
# Manage; Operations; aspect; design organization; importance; operations; cue
# design; ’; t; pass
# designers; work; result
# Symptoms; process; communications; file management; Difficulty; parts; organization; Inappropriate; staffing; projects; programs; Lack; visibility; workstreams; efforts; measurement; symptoms; people; wheels; lot
# designers; practices; policies; work
# cases; process; deficiencies; areas; lack; strategy; vision; roadmap; work
# hiring; exacerbate; problems; section
# team; members; ability; work; work-about-the-work; amount; Agenda Twentieth-century; management; practices; Scientific Management; workforce; bureaucracy; employees
# view; labor; teams; individuals; output; economy; mass manufacturing
# companies; challenge; software; services
# Services; hinge; relationships; relationships
# company; relationships; employees; ones
# orientation; design team; nature; work; humanity; empathy; customer research; design; solutions
# Use; qualities; guidelines
# team; members; organization; quality; results; areas
# activity; responsibility; improvement; everyone; team; ’
# download; http
# levels; Strategy; Structure; Surface; Jesse James Garrett ’; Elements; User Experience
# communication; Adam Cutler; Design Practices Director
# Continue; qualities; design
#
# Kelly Shortridge on overcoming common missteps affecting security decision-making
# ---------------------------------------------------------------------------------
# O ’ Reilly Security Podcast; posture; decision-making; decision; trees; defenses; role; UX; security.In; episode; Kelly Shortridge; detection product manager
# biases; security; roles; decision; trees; security; practitioners; assumptions; defenses; security; UX; future.Continue; Kelly Shortridge; missteps
#
# 5 things to learn before learning React
# ---------------------------------------
# Level; skills; React.If; t; application; React
# React; library; lot; components; flow
# times; React; JavaScript
# year; apps; React; Redux; bootcamp part-time; people; React
# people; tutorials; blog; posts; JavaScript; ecosystem; list; things
# list below; concepts; skills; building; app; React; things
#
# Reliability with Kafka
# ----------------------
# questions; Gwen Shapira; Kafka; business agility.I; Gwen Shapira; system architect; Confluent; Kafka—why; organizations; benefits
#
# use; cases
# d; Apache Kafka; use; cases
# Continue; Reliability
#
# Four short links: 24 May 2017
# -----------------------------
# Travel Mode; Justice Data; Threat Dragon; Voice Editing; Travel Mode; Travel Mode; devices; Safe; Travel
# indicator; agents
# Measures; Justice; data; justice; systems; states; Gates; Zuckerberg
# Bach; “ Justice; America; counties; justice system.; ”; Wired; OWASP Threat Dragon; source threat; tool
# standalone desktop app; Windows; MacOS; Linux
# Tech Beacon; Detail; Adobe; Voice Editing Software; VoCo; optimization algorithm; voice recording; combinations; phonemes; word; words; user; ’
# phonemes; sequences
#
# Words; emphasis; intonation
# [; ]; case; word isn; ’; t; VoCo; users; versions
# system; editor; pitch; duration; users
# Continue; links
#
# Four short links: 23 May 2017
# -----------------------------
# TensorFlow Cookbook; Welcoming Newcomers; Patent Win; Face Classification TensorFlow Cookbook Code; code; Nick McClure
# Newcomers; Dan Meyer; Chrome; extension; tweeters; math; chats
#
# Supreme Court Smacks Down Venue Shopping; Patent Cases; huzzah; pricks; Eastern District
# %; patent; lawsuits
# %; patent; trolls; study; Stanford Law School
# Face Classification; face detection; emotion/gender classification; data sets; keras; CNN; model
# Continue; links
#
# Jupyter Digest: 22 May 2017
# ---------------------------
# TensorFlow; cookbook; materials; source; notebooks; Python
#
# McClure; @; nfmcclure; companion; materials; book; Tensorflow Machine Learning Cookbook; Packt
#
# reader; Allen Downey
# series; stats; programming
# source; articles
#
#
# Robert Johansson; rjohansson; GitHub; series; notebooks
# Are; Fortran; C
# credit; author; Numerical Python
#
# organization; Python; stack; software engineering
# series; courses; world; topics; Python; Git; R; command line
#
# Continue; Jupyter Digest
#
# Four short links: 22 May 2017
# -----------------------------
# Meta Tutorial; Network Game; Indigenous VR; Facebook Moderation; Interactive Tutorial; Tutorials; details
# @; redblobgames; Netsim; game; schoolers
# @; errorinn; Indigenous Australia; VR; SMH; idea; game; user; Oculus Rift; reality headset; Aboriginal; campus; elders; people
# Facebook Files; Guardian; copies; Facebook
# guides; situations; crop
# documents; Facebook; people; language; frustration online ”
# “; issue; ’; person; threats; lack; empathy; communication; devices
# lot; analysis; guidelines; circumstances; edge-cases
# challenge; Facebook; behaviour; illusion; Facebook; fact; friends
# Continue; links
#
# Intelligent Bits: 19 May 2017
# -----------------------------
# AutoML; AI; photo editing; AI; product studio; Apple
# AutoML; Google Brain; team; reinforcement; techniques
# photo; hits; AI; photo editing
# Alyosha Efros ’; research group; Berkeley; charge; CycleGAN; work; colorization
# Turtles — Phil Libin; Evernote CEO; General Catalyst; studio; founders
# Apple; data; —; Structuring; use; dark; data; challenge; intelligence
# Apple; Lattice; need; door; startup; market
# Continue; Intelligent; Bits
#
# Four short links: 19 May 2017
# -----------------------------
# Algorithmic Fallibility; AI Sketches; Traffic Obfuscation; Engineer-Manager Pendulum Algorithmic Fallibility; Economic Organization; algorithms; benefits; answer; costs
# article; scenarios; tools
# Google Releases Sketches; Sketch-RNN; model; vector; drawings
# Comes; drawings; training
# Bedlam; Google Chrome; extension; web traffic/DNS; requests; web traffic
# Engineer-Manager Pendulum; Charity Majors; frontline eng; managers; world; ones; years; work; time
# contributors; ones; time
# Continue; links
#
# Activating human intrusion detection systems
# --------------------------------------------
# blue team; security culture program.Continue; Activating; intrusion detection
#
# Exploring progressive web apps in the real world
# ------------------------------------------------
# companies; experiences; apps.Continue; Exploring; web apps
#
# How to write a sound hypothesis when conducting user research
# -------------------------------------------------------------
# Cindy Alvarez; components; hypothesis; shares examples; hypotheses.Continue; How; sound hypothesis
#
# How AI is used to infer human emotion
# -------------------------------------
# Rana; Kaliouby; techniques; possibilities; emotion; AI; today.Rana el; Kaliouby; co-founder; CEO; Affectiva; emotion measurement technology company; MIT
# Rana; talk; science; applications; field; intelligence; Artificial Intelligence Conference; New York City
# Rana; techniques; possibilities; emotion; AI
#
# emotion; AI
# Emotion; AI; idea; devices; emotions
# variety; changes; expressions; gestures; physiology
# relationship; technology
# technology; people; technology; intelligence
# range; applications; Siri; phone; robots; applications
# AI; analysis
# scientists; people; emotions; conversation; %; meaning; message
# Twitter; example
# %; tone; voice—how; %; expressions
# Technology; state; example; expressions; emotion; AI
# way; emotion
#
# expressions; speech; expressions
# data; machines
# Affectiva; variety; computer vision; machine learning; approaches
# technology; computer vision; approaches; relies; machine; techniques; learn; examples
# rules; person; expression; attention; building intelligent
# partnerships; globe; database; people; cars; media
# portion; data; team; Facial Action Coding System
# job; video; repository; label; training; data
# approaches; learning; machine learning; learning; idea; modality; data set; data set; video; expression
#
# start; ad content
# Fortune; companies; consumers; responses
# problem; content; customers
# Pepsi; ad; example; AI; ad
# Think; incentive; order; campaign; PR
# technology; readout; viewers; journey; ads; tv show
#
#
# devices—Amazon; ’; Alexa; Google Home—but; ve; need; emotion; AI; manifesting; robotics; Internet; Things
# idea; connect; devices
# phase; markets
# Affectiva; research project; MIT
# company; value; data; number
# Affectiva ’; emotion database
# face; videos; total; hours; data
# data; ages; ethnicities; variety; contexts; people; couches
# wealth; data; data; set; gender; differences
# findings; study; gender; differences; expressions
# paper; example; women; men; men; expressions; anger
# data; business; insights; emotions; ads; world
# example; pet care; baby; ads; U.S.; cereal
#
# Are; skills; computers
# Experience; machine learning; computer vision
# degree; psychology; basics; psych; science; emotion; neuroscience; humans
# lot; science
# use case; emotion; AI
# use case; health; applications
# company; Brain Power; use; cases
# technology; Google Glass; children; emotion recognition; understanding; area; need; children; adults
# use case; applications; health; well-being
# world; self—featuring fitness; data; wearables; fitness; health
# product; concepts; users; health; well-being; clock
# Continue; How AI
#
# Paris Buttfield-Addison on what’s new in Swift programming
# ----------------------------------------------------------
# O ’ Reilly Programming Podcast; language; games; microservices.In; episode; O ’ Reilly Programming Podcast; Swift; Paris Buttfield-Addison; co-founder; Secret Lab; development studio; games; apps
# co-author; Learning Swift; presenter; Learning Path Getting; Swift; iPad; video; Ultimate Swift Programming.Continue; Paris Buttfield-Addison; ’; Swift
#
# Four short links: 18 May 2017
# -----------------------------
# Fact-Checkers; Simpler Java; JSON Feed; Mathematics; How Fact-checkers Check; performance; fact-checkers; Politfact; Tampa Bay Times; Fact Checker; Washington Post; interrater reliability; method
# fact-checkers; statement; agreement
# statements; outlets; claims; outlets; ratings; Cohen ’; κ; agreement rate
# results; difficulties; elites; statements; ability; fact-checking
# Marginal Revolution; Kotlin; take
# language; multiplatform; applications; %; Java
# Steve Yegge; rundown; language
# JSON Feed; tilt
# Atom; COBOL Object Notation
#
# Mathematics; PDF; MIT; book; art; guessing
# sections; Dimensions; Easy; cases; Lumping; Pictorial; proofs; part
# Continue; links
#
# Using Docker in production
# --------------------------
# questions; Laura Frank; orchestration; security; Laura Frank; Docker Captain; director; engineering; Codeship; evolution; Docker; ecosystem; orchestration
#
# Docker; ecosystem; couple
#
# Docker; tool
# result; bit; evolution; stages; Docker
# years; Docker; bit; pain; ’; developer; tools
# documentation; “ docker; ”; commands
# Docker; bit; container; implementation detail; engineer; ’
# Orchestration; tools; Docker; Swarm Mode; Kubernetes; Mesosphere; services
# focus; applications; workings; container; Docker; level.Continue; Docker
#
# How do I build an API?
# ----------------------
# web; application programming; interfaces
# Continue; How
#
# How do I use an API?
# --------------------
# types; application programming; interfaces; APIs; How
#
# What is an API?
# ---------------
# basics; application programming; interfaces; APIs; purpose; concepts
#
#
# How to do client-side form validation with Elm
# ----------------------------------------------
# Elm ’; typing; compiler error; validation; user; data; hints; tasks; developer
#
# time; user; service; profile; user; feedback; fields; validation; error
# Form; validators; field; set; error
#
#
# Terms; service; to.Continue; How; form validation
#
# The stages of enterprise IoT adoption
# -------------------------------------
# Teresa Tung; business case; Internet; Things.Continue; stages; enterprise; IoT
#
# Four short links: 17 May 2017
# -----------------------------
# Apps; Cloud Economics; Computational Theory; Imitation Learning How Etsy Ships Apps; summary; push process
# vessel; status; schedule; communications; deploy; tools; app
# ’; track; changes; release; messages; emails; people; events; state; schedule
# Usage; Patterns; Economics; Cloud; Adrian Colyer; providers; pricing; models
# summary; data; variation; demand volatility; cloud; datacenters; moment; pricing model
# CPU; utilization; rates; VMs; variations; usage
# applications; models; serverless; response; demands; pricing; models
# price; bands; peak; times; advance; majority; efficiency
#
# Stephen Wolfram; article; NKoS
# Imitation Learning; robots; demonstrations; task; situations; task
# paper; framework; capability
# OpenAI; Continue; links
#
# Augmenting industrial reality
# -----------------------------
# Integration; tools; vision; systems; developments; enterprise; AR; point; things; Reality; everything
# Facebook; building; Building; AR—they ’; camera; systems architects; imaging
# Companies; Chevrolet; examples; realtime; AR—in; cars
# Economist; space
#
#
# Pokemon GO; spotlight
#
# AR; leap
# space; AR
# manufacturing; industry—enterprise.Continue; Augmenting
#
# Four short links: 16 May 2017
# -----------------------------
# Flash Organizations; Collaboration Data Set; De-Anonymizing Mobile Data; Economics; Flash; Organizations; Complex; Work; Crowds; Organizations; system; contributions; crowd; ’; division; labor; roles; movie; crews; disaster response; teams; roles; coordination; workers; structures; model; version control; adaptation; work; division
# deployment; organizations; goals; reach; product design; software development
# Media Manipulation; Disinformation Online; PDF; research; Data; Society; questions
#
#
#
#
#
# BoingBoing; Trajectory Recovery; Ash; Adrian Colyer
# data set; chance; information; individuals; data; users; %; %; data sets; data; tens; thousands; hundreds; thousands
# context; location; data; discovery mechanism; reliance; characteristics; individuals; things; regularity; —i.e.; patterns; data; relating; individuals; patterns
# Economia; Festival; Economy; Economists; Money; Art; curators; Wiepko Oosterhuis; Olga Mink; economics
# Play; input; disciplines; science fiction
#
# idea; wage machine; crank; cent euro coin; seconds; ’; €8.96; hour; wage; Netherlands
#
#
#
# go; fun; installation
# Continue; links
#
# Architecting actionable insights
# --------------------------------
# Bas Geerdink; details; technology stack; account forecasting; ING; Spark; communications.Continue; Architecting
#
# The business advantages of embedding analytics into applications
# ----------------------------------------------------------------
# Access; data; time; workers; insights; amounts; information.Imagine; product manager; analytics; software; site
# instinct; solution; part
# team; resources; chore; team work; product fast
#
# mind; ’; dive; world; analytics
# rise; organization; Organizations; value; volumes
# employees; decisions; companies
# Employees; applications; sense; data
#
# hunger; data; analytics; expectations; workers
# Business; users; dashboards; reports; part
#
# Combine; complexity; size; variation; data sets; software; developers; challenges; users; customers
# Modern; data platforms; time; speed; availability; multitudes
# data set; others; business
# challenge; insight; data; stores; increase; volume; velocity; variety; data; billions; rows; data
# NoSQL; databases; Cassandra; HBase; MongoDB; data; frameworks; Hadoop; Spark; engines; Impala; Hive; stream processing; tools; Storm; Kafka; frameworks; ElasticSearch
# providers; fray; datastores; Amazon ’; s; Redshift; Google ’; BigQuery; Spanner; Microsoft ’
# analytics; product; resources
# scenario; target; business; users; data sources
# homegrown; legacy; analytics; solution; data; stores; don; ’; t meet today; ’; s
# analytics; scratch; budget; plan
# Enter; analytics; analytics; use; reporting; capabilities; visualizations; software; business
# technology; world; data; analysis; visualizations; business intelligence; developers
# goal; analytics; experience
# insights; user; ’; fingertips; user; standalone
# ways; analytics; requirements; Figure; goal; business; users; data; decisions
# Figure; continuum; analytics options runs; solutions; custom
# method; analytics; experience; amount; time; resources
# rebranding; options; time-to-market; solutions; app; t
# Lightweight; options; time-to-market; user experience; apps; iFrame; product; managers; iFrames
# Deeply; analytics; API/SDK-level; integration; effort; time-to-market
# option; visualizations; data; source; integrations
#
#
# Source; Zoomdata
# options; options; analytics
# solutions; Jaspersoft; Logi Analytics; Pentaho
# comparison; order
# O ’ Reilly; publication; Delivering Embedded; Analytics; Modern Applications; authors; chart
# Criterion; Easy
#
#
#
# Connects; set
# Extensible—add; custom
# Extensible—add; custom visualization
#
#
# Support; blending; data; sources
# Requirements; analytics solutions; Done; right; analytics; part; product
# analytics solutions; product cycle; cost; terms; royalties; licensing; ROI; way; variety
# analytics; solution
# Performance; data; exploration; business analyst; ’; creativity; waits
# Performance; volumes; data
# analytics; application; users; customers; face; application; look; feel; interface
# post; collaboration; O'Reilly
#
# Continue; business; advantages; analytics
#
# How can I deploy a multi-container application with Docker Compose?
# -------------------------------------------------------------------
# Docker; multi-container; applications; unit; seamless software development.Continue; application
#
# How do I package my Java application as a Docker image using Gradle?
# --------------------------------------------------------------------
# Gradle; build tool; Java; developers; Java; application; Docker; image; Docker; container.Continue; How; Java; application; Docker; image
#
# How do I create Docker images and run containers using Maven?
# -------------------------------------------------------------
# Apache Maven; project management; comprehension tool; Java; application; Docker; image; Docker; container.Continue; How; Docker; images; containers
#
# Get introduced to the new Java® 9 Platform Module System (JPMS) with Paul Deitel
# --------------------------------------------------------------------------------
# online training; JPMS; tool; Paul Deitel; Java; software-engineering technology; inception; Java. ” Paul Deitel; CEO; Deitel; Associates; Inc.; co-author; Java®; Programmers; Oracle Java Champion; online introduction; Java Platform Module System
# Deitel ’; online training; Safari; O ’ Reilly ’
# Modularity—the; result; Project Jigsaw—benefits; developers; levels; manage; complexity; productivity; construction; maintenance; evolution; software; software
# learn; Introduction; Modularity; Java®; Platform Module System; online training; motivation
# Review; key; JPMS
# Modularize; code
# Create; module; declarations; dependencies; packages; module; modules
#
# Use; services; system; components
# Indicate; module; service; service implementation
# jdeps; module; ’; s
# Understand; modules; code
# NetBeans; IDE; module graphs; JDK
# module resolver; action
# Use; jlink; runtimes; example; Internet; Things; IoT
#
# Visit Safari; course outline; prerequisites; Introduction; Modularity; Java®
# Java; modularity; developers; lives; JSR; Java Platform Module System; goals; Java SE Platform; configuration—You; dependencies; modules; manner; compile time
# system; dependencies; module resolver; subset; modules
# encapsulation—The; packages; module; modules; module; exports
# module; packages; module; ’; s
# Java Platform—Previously; Java Platform; consisting; number; packages
#
#
# runtimes; modules; apps; devices
# example; device; GUIs; runtime; GUI; modules; runtime; ’
# Greater; platform integrity—Before; Java; application; developers; APIs; platform
#
# code; Java; issue; deprecation
# JVM; optimization; techniques
# JSR; techniques; advance; types
# benefits; modularity; classpath hell; modularity; developers; classpath; libraries; use; compilation
# developers; classpath; problems; extent; term; “; classpath hell
# modularity; developers; classpath; module path; majority
# Better; system designs—You; modularity
# O'Reilly; online training; online training; courses; December; O'Reilly; people; courses; Docker; Up; Running; Designing; Voice; UI; Python; Basics; High-Performance TensorFlow; Production; Design Thinking; Practice
# Continue; Get; Java®; Platform Module System; JPMS
#
# Jupyter Digest: 15 May 2017
# ---------------------------
# TSFRESH; days; algorithms; JupyterHub; science
#
# TSFRESH; time series feature extraction; hypothesis
# layman; terms; things
# folder; Jupyter; examples; work; one; data; stairs
#
#
# Tomáš Bouda; @; GitHub; list; examples; host; algorithms
# title; Day; huffman codes.ipynb; lights
#
# JupyterHub; science; Experiences; Jupyter
# Jupyter; scale; org; session; JupyterCon; Aug; NYC
#
# Richard Zhang; PhD; candidate; UC Berkeley; notebook; technique
#
# Continue; Jupyter Digest

# %% [markdown]
# ## Example 10. Visualizing interactions between entities with HTML output

# %%
import os
import json
import nltk
from IPython.display import IFrame
from IPython.core.display import display

BLOG_DATA = "resources/ch05-webpages/feed.json"

HTML_TEMPLATE = """<html>
    <head>
        <title>%s</title>
        <meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>
    </head>
    <body>%s</body>
</html>"""

blog_data = json.loads(open(BLOG_DATA).read())

for post in blog_data:

    post.update(extract_interactions(post['content']))

    # Display output as markup with entities presented in bold text

    post['markup'] = []

    for sentence_idx in range(len(post['sentences'])):

        s = post['sentences'][sentence_idx]
        for (term, _) in post['entity_interactions'][sentence_idx]:
            s = s.replace(term, '<strong>%s</strong>' % (term, ))

        post['markup'] += [s] 
            
    filename = post['title'].replace("?", "") + '.entity_interactions.html'
    f = open(os.path.join('resources', 'ch05-webpages', filename), 'w')
    html = HTML_TEMPLATE % (post['title'] + ' Interactions', 
                            ' '.join(post['markup']),)
    f.write(html.encode('utf-8'))
    f.close()

    print "Data written to", f.name
    
    # Display any of these files with an inline frame. This displays the
    # last file processed by using the last value of f.name...
    
    print "Displaying %s:" % f.name
    display(IFrame('files/%s' % f.name, '100%', '600px'))
# Out:
# Data written to resources/ch05-webpages/Four short links: 30 May 2017.entity_interactions.html
# Displaying resources/ch05-webpages/Four short links: 30 May 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Four short links: 30 May 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Jupyter Digest: 30 May 2017.entity_interactions.html
# Displaying resources/ch05-webpages/Jupyter Digest: 30 May 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Jupyter Digest: 30 May 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Jupyter Insights: Carol Willing, director of the Python Software Foundation.entity_interactions.html
# Displaying resources/ch05-webpages/Jupyter Insights: Carol Willing, director of the Python Software Foundation.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Jupyter Insights: Carol Willing, director of the Python Software Foundation.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/How do I configure a Cisco router for secure remote access using SSH.entity_interactions.html
# Displaying resources/ch05-webpages/How do I configure a Cisco router for secure remote access using SSH.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/How do I configure a Cisco router for secure remote access using SSH.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/How do I recover the password on a Cisco router without losing its configuration.entity_interactions.html
# Displaying resources/ch05-webpages/How do I recover the password on a Cisco router without losing its configuration.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/How do I recover the password on a Cisco router without losing its configuration.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/What is the OSI model.entity_interactions.html
# Displaying resources/ch05-webpages/What is the OSI model.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/What is the OSI model.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Four short links: 29 May 2017.entity_interactions.html
# Displaying resources/ch05-webpages/Four short links: 29 May 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Four short links: 29 May 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Intelligent Bits: 26 May 2017.entity_interactions.html
# Displaying resources/ch05-webpages/Intelligent Bits: 26 May 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Intelligent Bits: 26 May 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Four short links: 26 May 2017.entity_interactions.html
# Displaying resources/ch05-webpages/Four short links: 26 May 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Four short links: 26 May 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Running a word count application using Spark.entity_interactions.html
# Displaying resources/ch05-webpages/Running a word count application using Spark.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Running a word count application using Spark.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Peeking into the black box: Lessons from the front lines of machine-learning product launches.entity_interactions.html
# Displaying resources/ch05-webpages/Peeking into the black box: Lessons from the front lines of machine-learning product launches.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Peeking into the black box: Lessons from the front lines of machine-learning product launches.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Using AI to create new jobs.entity_interactions.html
# Displaying resources/ch05-webpages/Using AI to create new jobs.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Using AI to create new jobs.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Lessons from piloting the London Office of Data Analytics.entity_interactions.html
# Displaying resources/ch05-webpages/Lessons from piloting the London Office of Data Analytics.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Lessons from piloting the London Office of Data Analytics.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Enabling data science in the enterprise.entity_interactions.html
# Displaying resources/ch05-webpages/Enabling data science in the enterprise.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Enabling data science in the enterprise.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Is finance ready for AI.entity_interactions.html
# Displaying resources/ch05-webpages/Is finance ready for AI.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Is finance ready for AI.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Accelerate analytics and AI innovations with Intel.entity_interactions.html
# Displaying resources/ch05-webpages/Accelerate analytics and AI innovations with Intel.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Accelerate analytics and AI innovations with Intel.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Data science and deep learning in retail.entity_interactions.html
# Displaying resources/ch05-webpages/Data science and deep learning in retail.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Data science and deep learning in retail.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Travis Lowdermilk and Jessica Rich on building a customer-driven culture at Microsoft.entity_interactions.html
# Displaying resources/ch05-webpages/Travis Lowdermilk and Jessica Rich on building a customer-driven culture at Microsoft.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Travis Lowdermilk and Jessica Rich on building a customer-driven culture at Microsoft.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/JupyterLab: The evolution of the Jupyter web interface.entity_interactions.html
# Displaying resources/ch05-webpages/JupyterLab: The evolution of the Jupyter web interface.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/JupyterLab: The evolution of the Jupyter web interface.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Jason Laska and Michael Akilian on using AI to schedule meetings.entity_interactions.html
# Displaying resources/ch05-webpages/Jason Laska and Michael Akilian on using AI to schedule meetings.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Jason Laska and Michael Akilian on using AI to schedule meetings.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Four short links: 25 May 2017.entity_interactions.html
# Displaying resources/ch05-webpages/Four short links: 25 May 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Four short links: 25 May 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Real-time intelligence gives Uber the edge.entity_interactions.html
# Displaying resources/ch05-webpages/Real-time intelligence gives Uber the edge.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Real-time intelligence gives Uber the edge.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Another one bytes the dust.entity_interactions.html
# Displaying resources/ch05-webpages/Another one bytes the dust.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Another one bytes the dust.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Machine learning is a moonshot for us all.entity_interactions.html
# Displaying resources/ch05-webpages/Machine learning is a moonshot for us all.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Machine learning is a moonshot for us all.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/The data subject first.entity_interactions.html
# Displaying resources/ch05-webpages/The data subject first.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/The data subject first.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/What Kaggle has learned from almost a million data scientists.entity_interactions.html
# Displaying resources/ch05-webpages/What Kaggle has learned from almost a million data scientists.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/What Kaggle has learned from almost a million data scientists.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Highlights from Strata Data Conference in London 2017.entity_interactions.html
# Displaying resources/ch05-webpages/Highlights from Strata Data Conference in London 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Highlights from Strata Data Conference in London 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/The science of visual interactions.entity_interactions.html
# Displaying resources/ch05-webpages/The science of visual interactions.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/The science of visual interactions.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/12 qualities of effective design organizations.entity_interactions.html
# Displaying resources/ch05-webpages/12 qualities of effective design organizations.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/12 qualities of effective design organizations.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Kelly Shortridge on overcoming common missteps affecting security decision-making.entity_interactions.html
# Displaying resources/ch05-webpages/Kelly Shortridge on overcoming common missteps affecting security decision-making.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Kelly Shortridge on overcoming common missteps affecting security decision-making.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/5 things to learn before learning React.entity_interactions.html
# Displaying resources/ch05-webpages/5 things to learn before learning React.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/5 things to learn before learning React.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Reliability with Kafka.entity_interactions.html
# Displaying resources/ch05-webpages/Reliability with Kafka.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Reliability with Kafka.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Four short links: 24 May 2017.entity_interactions.html
# Displaying resources/ch05-webpages/Four short links: 24 May 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Four short links: 24 May 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Four short links: 23 May 2017.entity_interactions.html
# Displaying resources/ch05-webpages/Four short links: 23 May 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Four short links: 23 May 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Jupyter Digest: 22 May 2017.entity_interactions.html
# Displaying resources/ch05-webpages/Jupyter Digest: 22 May 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Jupyter Digest: 22 May 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Four short links: 22 May 2017.entity_interactions.html
# Displaying resources/ch05-webpages/Four short links: 22 May 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Four short links: 22 May 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Intelligent Bits: 19 May 2017.entity_interactions.html
# Displaying resources/ch05-webpages/Intelligent Bits: 19 May 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Intelligent Bits: 19 May 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Four short links: 19 May 2017.entity_interactions.html
# Displaying resources/ch05-webpages/Four short links: 19 May 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Four short links: 19 May 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Activating human intrusion detection systems.entity_interactions.html
# Displaying resources/ch05-webpages/Activating human intrusion detection systems.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Activating human intrusion detection systems.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Exploring progressive web apps in the real world.entity_interactions.html
# Displaying resources/ch05-webpages/Exploring progressive web apps in the real world.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Exploring progressive web apps in the real world.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/How to write a sound hypothesis when conducting user research.entity_interactions.html
# Displaying resources/ch05-webpages/How to write a sound hypothesis when conducting user research.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/How to write a sound hypothesis when conducting user research.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/How AI is used to infer human emotion.entity_interactions.html
# Displaying resources/ch05-webpages/How AI is used to infer human emotion.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/How AI is used to infer human emotion.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Paris Buttfield-Addison on what’s new in Swift programming.entity_interactions.html
# Displaying resources/ch05-webpages/Paris Buttfield-Addison on what’s new in Swift programming.entity_interactions.html:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# /Users/santteegt/anaconda/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# /Users/santteegt/anaconda/lib/python2.7/site-packages/IPython/lib/display.pyc in _repr_html_(self)
#     230                                   width=self.width,
#     231                                   height=self.height,
# --> 232                                   params=params)
#     233
#     234 class YouTubeVideo(IFrame):
#
# UnicodeEncodeError: 'ascii' codec can't encode character u'\u2019' in position 61: ordinal not in range(128)
# Data written to resources/ch05-webpages/Four short links: 18 May 2017.entity_interactions.html
# Displaying resources/ch05-webpages/Four short links: 18 May 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Four short links: 18 May 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Using Docker in production.entity_interactions.html
# Displaying resources/ch05-webpages/Using Docker in production.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Using Docker in production.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/How do I build an API.entity_interactions.html
# Displaying resources/ch05-webpages/How do I build an API.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/How do I build an API.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/How do I use an API.entity_interactions.html
# Displaying resources/ch05-webpages/How do I use an API.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/How do I use an API.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/What is an API.entity_interactions.html
# Displaying resources/ch05-webpages/What is an API.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/What is an API.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/How to do client-side form validation with Elm.entity_interactions.html
# Displaying resources/ch05-webpages/How to do client-side form validation with Elm.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/How to do client-side form validation with Elm.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/The stages of enterprise IoT adoption.entity_interactions.html
# Displaying resources/ch05-webpages/The stages of enterprise IoT adoption.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/The stages of enterprise IoT adoption.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Four short links: 17 May 2017.entity_interactions.html
# Displaying resources/ch05-webpages/Four short links: 17 May 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Four short links: 17 May 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Augmenting industrial reality.entity_interactions.html
# Displaying resources/ch05-webpages/Augmenting industrial reality.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Augmenting industrial reality.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Four short links: 16 May 2017.entity_interactions.html
# Displaying resources/ch05-webpages/Four short links: 16 May 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Four short links: 16 May 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Architecting actionable insights.entity_interactions.html
# Displaying resources/ch05-webpages/Architecting actionable insights.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Architecting actionable insights.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/The business advantages of embedding analytics into applications.entity_interactions.html
# Displaying resources/ch05-webpages/The business advantages of embedding analytics into applications.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/The business advantages of embedding analytics into applications.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/How can I deploy a multi-container application with Docker Compose.entity_interactions.html
# Displaying resources/ch05-webpages/How can I deploy a multi-container application with Docker Compose.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/How can I deploy a multi-container application with Docker Compose.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/How do I package my Java application as a Docker image using Gradle.entity_interactions.html
# Displaying resources/ch05-webpages/How do I package my Java application as a Docker image using Gradle.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/How do I package my Java application as a Docker image using Gradle.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/How do I create Docker images and run containers using Maven.entity_interactions.html
# Displaying resources/ch05-webpages/How do I create Docker images and run containers using Maven.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/How do I create Docker images and run containers using Maven.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to resources/ch05-webpages/Get introduced to the new Java® 9 Platform Module System (JPMS) with Paul Deitel.entity_interactions.html
# Displaying resources/ch05-webpages/Get introduced to the new Java® 9 Platform Module System (JPMS) with Paul Deitel.entity_interactions.html:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# /Users/santteegt/anaconda/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# /Users/santteegt/anaconda/lib/python2.7/site-packages/IPython/lib/display.pyc in _repr_html_(self)
#     230                                   width=self.width,
#     231                                   height=self.height,
# --> 232                                   params=params)
#     233
#     234 class YouTubeVideo(IFrame):
#
# UnicodeEncodeError: 'ascii' codec can't encode character u'\xae' in position 60: ordinal not in range(128)
# Data written to resources/ch05-webpages/Jupyter Digest: 15 May 2017.entity_interactions.html
# Displaying resources/ch05-webpages/Jupyter Digest: 15 May 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch05-webpages/Jupyter Digest: 15 May 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
