# %% [markdown]
# # Mining the Social Web, 2nd Edition
#
# ## Chapter 4: Mining Google+: Computing Document Similarity, Extracting Collocations, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs).
#
# ## Fixes & improvements
#
# Reviewed by [santteegt](https://santteegt.github.io)
#
# This notebook has been fully reviewed and partially fixed on May 2017 in order to make it work with the current version of libraries and APIs.
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# ## InstallationRequirements
#
# You can install the following libraries directly from the anaconda navigator:
#
# * google-api-python-client
# * nltk
# * beautifulsoup4

# %% [markdown]
# ## Example 1. Searching for a person with the Google+ API

# %%
import httplib2
import json
import apiclient.discovery # pip install google-api-python-client

# XXX: Enter any person's name
Q = "Tim O'Reilly"

# XXX: Enter in your API key from  https://code.google.com/apis/console
API_KEY = 'AIzaSyATAzU6cKajEJx6iyzlVJ-3DHalS0CVf9Y'

service = apiclient.discovery.build('plus', 'v1', http=httplib2.Http(), 
                                    developerKey=API_KEY)

people_feed = service.people().search(query=Q).execute()

print json.dumps(people_feed['items'], indent=1)
# Out:
# [
#  {
#   "kind": "plus#person",
#   "displayName": "Tim O'Reilly",
#   "url": "https://plus.google.com/107033731246200681024",
#   "image": {
#    "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#   },
#   "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/tjedXFyeIkzudZzRey5EJb8iZIk\"",
#   "id": "107033731246200681024",
#   "objectType": "person"
#  },
#  {
#   "kind": "plus#person",
#   "displayName": "Tim O'Reilly",
#   "url": "https://plus.google.com/108869213167055456475",
#   "image": {
#    "url": "https://lh4.googleusercontent.com/-K_U9Tbas8kE/AAAAAAAAAAI/AAAAAAAACYs/QThoMgwUxak/photo.jpg?sz=50"
#   },
#   "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/bMltloEYgECFQYgmmtJJ3R6E-44\"",
#   "id": "108869213167055456475",
#   "objectType": "person"
#  },
#  {
#   "kind": "plus#person",
#   "displayName": "TIM O'REILLY",
#   "url": "https://plus.google.com/110160587587635791009",
#   "image": {
#    "url": "https://lh4.googleusercontent.com/-gWq9vr_JEnc/AAAAAAAAAAI/AAAAAAAAADI/zwCXKP4QeiU/photo.jpg?sz=50"
#   },
#   "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/ofg-30rIv-rKw7XTBBnDA1i3I_Y\"",
#   "id": "110160587587635791009",
#   "objectType": "person"
#  },
#  {
#   "kind": "plus#person",
#   "displayName": "Tim O'Reilly",
#   "url": "https://plus.google.com/106492472890341598734",
#   "image": {
#    "url": "https://lh3.googleusercontent.com/-S5DUz4QdL4k/AAAAAAAAAAI/AAAAAAAAAcc/iS9VLgbCTJw/photo.jpg?sz=50"
#   },
#   "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/DVTuV3GDJ0h4UlM5bybS_d26Fdo\"",
#   "id": "106492472890341598734",
#   "objectType": "person"
#  },
#  {
#   "kind": "plus#person",
#   "displayName": "Tim O'Reilly",
#   "url": "https://plus.google.com/111152572505390475891",
#   "image": {
#    "url": "https://lh6.googleusercontent.com/-_VkHCqX9n5k/AAAAAAAAAAI/AAAAAAAAABE/EHbj9yl--M8/photo.jpg?sz=50"
#   },
#   "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/AoU1nEaSxcSI4jze47t6mbStauQ\"",
#   "id": "111152572505390475891",
#   "objectType": "person"
#  },
#  {
#   "kind": "plus#person",
#   "displayName": "TIM O'REILLY",
#   "url": "https://plus.google.com/112630513029834463088",
#   "image": {
#    "url": "https://lh3.googleusercontent.com/-dOC3TnU5LJk/AAAAAAAAAAI/AAAAAAAAC4o/7EpI7CgLzHs/photo.jpg?sz=50"
#   },
#   "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/osRTximpWuG3PPGTlycl2U3PfdA\"",
#   "id": "112630513029834463088",
#   "objectType": "person"
#  },
#  {
#   "kind": "plus#person",
#   "displayName": "Tim O'Reilly",
#   "url": "https://plus.google.com/112971313488103174611",
#   "image": {
#    "url": "https://lh4.googleusercontent.com/-DHPPpI53zYs/AAAAAAAAAAI/AAAAAAAAAA0/pMnv4IOHinM/photo.jpg?sz=50"
#   },
#   "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/-tQMA-kdju1h40Q9yqHvt_XGcI8\"",
#   "id": "112971313488103174611",
#   "objectType": "person"
#  },
#  {
#   "kind": "plus#person",
#   "displayName": "Timothy O'Reilly",
#   "url": "https://plus.google.com/102994447097932477991",
#   "image": {
#    "url": "https://lh6.googleusercontent.com/-AN65SwKBkAA/AAAAAAAAAAI/AAAAAAAAAFI/oYk5S6oRSRM/photo.jpg?sz=50"
#   },
#   "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/ZGOPPF5KIorb7COpKZ97WBd0bNc\"",
#   "id": "102994447097932477991",
#   "objectType": "person"
#  },
#  {
#   "kind": "plus#person",
#   "displayName": "Timothy O'Reilly",
#   "url": "https://plus.google.com/107786179585502589799",
#   "image": {
#    "url": "https://lh6.googleusercontent.com/-VyqOCKcFBVg/AAAAAAAAAAI/AAAAAAAADeA/R5E5uh-ZSpI/photo.jpg?sz=50"
#   },
#   "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc

#   "objectType": "person"
#  },
#  {
#   "kind": "plus#person",
#   "displayName": "Tim O'Reilly",
#   "url": "https://plus.google.com/113295367959648050025",
#   "image": {
#    "url": "https://lh3.googleusercontent.com/-flFWmbCGOZ4/AAAAAAAAAAI/AAAAAAAAAAA/Iqu547hSq2Q/photo.jpg?sz=50"
#   },
#   "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/9nCX0F7hQfgN33A-uGW-N5UNIwU\"",
#   "id": "113295367959648050025",
#   "objectType": "person"
#  },
#  {
#   "kind": "plus#person",
#   "displayName": "Tim O'Reilly",
#   "url": "https://plus.google.com/113473507155799625326",
#   "image": {
#    "url": "https://lh3.googleusercontent.com/-RWz2tbTaCkw/AAAAAAAAAAI/AAAAAAAAAAA/ivf8bS46UeY/photo.jpg?sz=50"
#   },
#   "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/SsXdUqKuJcOZqQDATYCyx-6knqA\"",
#   "id": "113473507155799625326",
#   "objectType": "person"
#  },
#  {
#   "kind": "plus#person",
#   "displayName": "Tim O'Reilly",
#   "url": "https://plus.google.com/109808102315687957548",
#   "image": {
#    "url": "https://lh6.googleusercontent.com/-H0Mep-vaAgU/AAAAAAAAAAI/AAAAAAAAAL8/2blzXvpMPR0/photo.jpg?sz=50"
#   },
#   "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/3AfUcHV6iuUBi3nxYG84U65Z5sY\"",
#   "id": "109808102315687957548",
#   "objectType": "person"
#  },
#  {
#   "kind": "plus#person",
#   "displayName": "Tim O'Reilly",
#   "url": "https://plus.google.com/114172069562252200235",
#   "image": {
#    "url": "https://lh5.googleusercontent.com/-3xPm1RmotzY/AAAAAAAAAAI/AAAAAAAAAC0/_Ue0ROpAMJk/photo.jpg?sz=50"
#   },
#   "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/mgTUB4vuFDnN35OV-TfovLuk42c\"",
#   "id": "114172069562252200235",
#   "objectType": "person"
#  }
# ]

# %% [markdown]
# ## Example 2. Displaying Google+ avatars in IPython Notebook provides a quick way to disambiguate the search results and discover the person you are looking for

# %%
from IPython.core.display import HTML

html = []

for p in people_feed['items']:
    html += ['<p><img src="%s" /> %s: %s</p>' % \
             (p['image']['url'], p['id'], p['displayName'])]

HTML(''.join(html))
# Out:
# <p><img src="https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50" /> 107033731246200681024: Tim O'Reilly</p><p><img src="https://lh4.googleusercontent.com/-K_U9Tbas8kE/AAAAAAAAAAI/AAAAAAAACYs/QThoMgwUxak/photo.jpg?sz=50" /> 108869213167055456475: Tim O'Reilly</p><p><img src="https://lh4.googleusercontent.com/-gWq9vr_JEnc/AAAAAAAAAAI/AAAAAAAAADI/zwCXKP4QeiU/photo.jpg?sz=50" /> 110160587587635791009: TIM O'REILLY</p><p><img src="https://lh3.googleusercontent.com/-S5DUz4QdL4k/AAAAAAAAAAI/AAAAAAAAAcc/iS9VLgbCTJw/photo.jpg?sz=50" /> 106492472890341598734: Tim O'Reilly</p><p><img src="https://lh6.googleusercontent.com/-_VkHCqX9n5k/AAAAAAAAAAI/AAAAAAAAABE/EHbj9yl--M8/photo.jpg?sz=50" /> 111152572505390475891: Tim O'Reilly</p><p><img src="https://lh3.googleusercontent.com/-dOC3TnU5LJk/AAAAAAAAAAI/AAAAAAAAC4o/7EpI7CgLzHs/photo.jpg?sz=50" /> 112630513029834463088: TIM O'REILLY</p><p><img src="https://lh4.googleusercontent.com/-DHPPpI53zYs/AAAAAAAAAAI/AAAAAAAAAA0/pMnv4IOHinM/photo.jpg?sz=50" /> 112971313488103174611: Tim O'Reilly</p><p><img src="https://lh6.googleusercontent.com/-AN65SwKBkAA/AAAAAAAAAAI/AAAAAAAAAFI/oYk5S6oRSRM/photo.jpg?sz=50" /> 102994447097932477991: Timothy O'Reilly</p><p><img src="https://lh6.googleusercontent.com/-VyqOCKc
# ## Example 3. Fetching recent activities for a particular Google+ user

# %%
import httplib2
import json
import apiclient.discovery

USER_ID = '107033731246200681024' # Tim O'Reilly

# XXX: Re-enter your API_KEY from  https://code.google.com/apis/console
# if not currently set
# API_KEY = ''

service = apiclient.discovery.build('plus', 'v1', http=httplib2.Http(), 
                                    developerKey=API_KEY)

activity_feed = service.activities().list(
  userId=USER_ID,
  collection='public',
  maxResults='100' # Max allowed per API
).execute()

print json.dumps(activity_feed, indent=1)
# Out:
# {
#  "nextPageToken": "ADSJ_i2ai-hdfJKpbjAUGoNzdJly0ewsFczwxuplHJE6lW17MuNFoiVohWZEhvntAfFJTYiBuWWbeJxL8wJSJGpqFPgVmhUL_zoJWx5gjHxR4F4PUg",
#  "kind": "plus#activityFeed",
#  "title": "Google+ List of Activities for Collection PUBLIC",
#  "items": [
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "If there is only one article about the NBA finals that you read, make it this one. And if you have no...",
#    "url": "https://plus.google.com/+TimOReilly/posts/BzfRWCoFfFH",
#    "object": {
#     "resharers": {
#      "totalItems": 1,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z132ennwdurpfhre123gcxizetybvpydh/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "'I'm ready': The text that started an NBA dynasty",
#       "fullImage": {
#        "url": "https://cdn-s3.si.com/s3fs-public/styles/inline_gallery_desktop/public/2017/06/13/kevin-durant-draymond-green-nba-finals.jpg?itok=F8sgXFLK",
#        "type": "image/jpeg"
#       },
#       "url": "https://www.si.com/nba/2017/06/13/golden-state-warriors-kevin-durant-nba-championship-draymond-green-text",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/H6qZlU0jiSFQHfuMM51LZ4-MwI1ZvDZSVBMgrzh5uLnqp7aBUyf73aDcIEtvjv58U4hUAuKBGvwMfBefLFkj0xVAK85JE29FL68llmB2N89mlQZtPu0-dpyGMGnS1coz9-t-f06iV1MEYUTXxMzq9Tu8K80iF8DPq5M9LBjR9HTuZwUONS8QYh3myX8oDr4XcMBx3Hp38pgrAdA=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "For all practical purposes, the Warriors captured the 2017 title the night they surrendered the 2016 crown. It all started with a text message to Kevi",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/BzfRWCoFfFH",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "If there is only one article about the NBA finals that you read, make it this one. And if you have no interest in the NBA, read it anyway. It is a testament to the intelligence, work ethic, strategic focus, and teamwork that make a champion. There are lessons here for everyone. \ufeff",
#     "plusoners": {
#      "totalItems": 41,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z132ennwdurpfhre123gcxizetybvpydh/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 2,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z132ennwdurpfhre123gcxizetybvpydh/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2017-06-14T19:42:43.018Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/ePYpkjLYFc8PUEoGwGIG0uc6Stg\"",
#    "published": "2017-06-14T19:42:43.018Z",
#    "id": "z132ennwdurpfhre123gcxizetybvpydh"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "This made me laugh out loud. One thing Trump has been good for is the rise of colorful commentary! \"...",
#    "url": "https://plus.google.com/+TimOReilly/posts/1Xj34NHobjv",
#    "object": {
#     "resharers": {
#      "totalItems": 2,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12cy3dgimvbv35c323gcxizetybvpydh/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "Opinion | Is Putin Getting What He Wanted With Trump?",
#       "fullImage": {
#        "url": "https://static01.nyt.com/images/2017/06/11/opinion/sunday/11kotkin/11kotkin-facebookJumbo.jpg",
#        "type": "image/jpeg"
#       },
#       "url": "https://www.nytimes.com/2017/06/10/opinion/sunday/is-putin-getting-what-he-wanted-with-trump.html",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/GeB1F1MODz6-NXgYQtXDMsfSpVEir7qBW4Sgy630iPk402zqj0gLz8oMYvQh5nKbwFzru7gccWmDeBuoNme9-4fmg0PtX0dZoQv49LzjZJXy-ZSR285b-hBXKNHqr3hdqSyRGHQ09mDxUMwPaQ=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "In the wake of Comey\u2019s testimony, they weren\u2019t quite throwing back vodka shots in the Kremlin.",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/1Xj34NHobjv",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "This made me laugh out loud. One thing Trump has been good for is the rise of colorful commentary! &quot;An investigation into Trumpworld for collusion...could morph into the equivalent of looking for bacteria on a pile of dung. Large parts of the overpriced real estate sector involve money laundering, with Russian, Chinese, Arab and even Iranian money.&quot; The article has many good insights, not as colorful, but equally sharp. \ufeff",
#     "plusoners": {
#      "totalItems": 35,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12cy3dgimvbv35c323gcxizetybvpydh/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 9,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12cy3dgimvbv35c323gcxizetybvpydh/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2017-06-11T21:23:42.788Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/4Us3Yto0I97XbiGFci7m6xN-J7k\"",
#    "published": "2017-06-11T21:23:42.788Z",
#    "id": "z12cy3dgimvbv35c323gcxizetybvpydh"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "America\u2019s class privilege runs much deeper than the \u201c1%\". We need to get rid of cherished middle class...",
#    "url": "https://plus.google.com/+TimOReilly/posts/3Asc6A4FS9Q",
#    "object": {
#     "resharers": {
#      "totalItems": 10,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12pypqz3nqmidz0g23gcxizetybvpydh/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "Opinion | Stop Pretending You\u2019re Not Rich",
#       "fullImage": {
#        "url": "https://static01.nyt.com/images/2017/06/12/opinion/sunday/11reevesWEB/11reevesWEB-facebookJumbo.jpg",
#        "type": "image/jpeg"
#       },
#       "url": "https://www.nytimes.com/2017/06/10/opinion/sunday/stop-pretending-youre-not-rich.html",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/bDem19YEfkxFTbJ9bvV15sFCjy6vXv9mrUNV_aL8QswRZTr-vsSATLgtbrYU71Xa2TWGpph_XCFNsOIo70Z2Ah1i_2gOOZ_ShKj7hSI6phBg_ZKy80lxX04A6obp_QRICSMW8jv6nUbIcR0yIT4rlg-xKQ=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "Forget the 1 percent for a moment. It\u2019s the top fifth that rules.",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/3Asc6A4FS9Q",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "America\u2019s class privilege runs much deeper than the \u201c1%&quot;. We need to get rid of cherished middle class programs for a fairer deal. An interesting perspective from a Brit on how America is in denial about the way that it makes sure the well off stay that way. Well worth reading.<br />\ufeff",
#     "plusoners": {
#      "totalItems": 69,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12pypqz3nqmidz0g23gcxizetybvpydh/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 23,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12pypqz3nqmidz0g23gcxizetybvpydh/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2017-06-11T21:10:12.033Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/5dqW6HznJHsgEcSX3Us126vkEmk\"",
#    "published": "2017-06-11T21:10:12.033Z",
#    "id": "z12pypqz3nqmidz0g23gcxizetybvpydh"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "This is what you get when you believe that \u201cgovernment should just get out of the way\u201d and let industry...",
#    "url": "https://plus.google.com/+TimOReilly/posts/CuT9HBNnxmL",
#    "object": {
#     "resharers": {
#      "totalItems": 14,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13jsts53sr2jh5eb23gcxizetybvpydh/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "The U.S. ranks 28th in the world in mobile internet speeds",
#       "fullImage": {
#        "url": "https://cdn0.vox-cdn.com/thumbor/sNka6Av6d62WU_Vmbnpz9GBBz9g=/0x1:1200x629/fit-in/1200x630/cdn3.vox-cdn.com/uploads/chorus_asset/file/8646063/akamai_mobile_share_01.png",
#        "type": "image/jpeg"
#       },
#       "url": "https://www.recode.net/2017/6/7/15747486/united-states-developed-world-mobile-internet-speeds-akamai",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/aZarTKzSLoWvKQL1zd0f7YfxAc28B-fJOSMcWqV0-k9WbOG2BuT1IQZBDu32Fdtcw3yxO_Zxe8XKm21Zv8IiZ1qoN2XH_ae0w7KvCcHBiQLvu2JczdNXRqNelDey52WYweOeD3N9h42zV5L4gLWU3TQtjNAIe1h6_BMj0RMwxhMlmrN1DLSHcAoVAx0CjaZsXA6nMeMMiTfWzPqN3ZwAVTJrLRhd8CklUH5GxJ43fyhEizWtSx-Y-M8=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "We have slower mobile internet than Greece. Greece!",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/CuT9HBNnxmL",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "This is what you get when you believe that \u201cgovernment should just get out of the way\u201d and let industry do its thing. When will get over the failed idea that good government is an obstacle to progress? We do best when government, business, and all of society work together towards shared goals. \ufeff",
#     "plusoners": {
#      "totalItems": 111,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13jsts53sr2jh5eb23gcxizetybvpydh/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 25,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13jsts53sr2jh5eb23gcxizetybvpydh/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2017-06-08T18:26:23.875Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/vh3DT5qJlRaU6CnIAXIAYBg6YMg\"",
#    "published": "2017-06-08T18:26:23.875Z",
#    "id": "z13jsts53sr2jh5eb23gcxizetybvpydh"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "I wish I\u2019d written this! It's the best explanation I've seen of how to think through the possible impact...",
#    "url": "https://plus.google.com/+TimOReilly/posts/bAWnG1eL7h1",
#    "object": {
#     "resharers": {
#      "totalItems": 5,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13si50jmnq3vjcag04chl3pvxfbszirt5o/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "Not even wrong - ways to dismiss technology",
#       "fullImage": {
#        "url": "http://static1.squarespace.com/static/50363cf324ac8e905e7df861/5925cfc7b3db2b44126ad7e9/5925cfc73e00be1fff4d7a3a/1495650250250/1904_Flyer_Flight_16Nov.jpg?format=1000w",
#        "type": "image/jpeg"
#       },
#       "url": "http://ben-evans.com/benedictevans/2017/5/24/not-even-wrong-ways-to-dismiss-technology",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/AYhZfs4vbeHhJCTXf-nRyBDOGMzyOeee9Xn5sTMbaRCQUzcnTnQ1YFnJJFJUqZgQUtPriWOTbqAXXnCfH4A70WVAbC2yvMC5W_D22xCXydxClDwaw2qE3Z7YbY2HIx1CoB-92KymCcvJVJw5W2M2Ddsq556k_eLMBiOHfwecmJkM_rN6mXAuLDIE1k2KUAcRSRgRFwMZ9tIBtolkC90cvqjySYqFKNosg28qBut_6ZAj0VtY38MiAg=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "How do we get beyond 'that's a toy!' and 'but everything looked like a \r\ntoy!', and try actually to understand whether a new technology might \r\nmatter? What are valid lines of reasoning, and what statements are 'not \r\neven wrong'?",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/bAWnG1eL7h1",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "I wish I\u2019d written this! It&#39;s the best explanation I&#39;ve seen of how to think through the possible impact of inventions. (Although I disagree with Ben about the impact of voice interfaces. They don&#39;t have to be able to do <b>everything</b> to be transformative.)  <a href=\"http://ben-evans.com/benedictevans/2017/5/24/not-even-wrong-ways-to-dismiss-technology\" class=\"ot-anchor\">http://ben-evans.com/benedictevans/2017/5/24/not-even-wrong-ways-to-dismiss-technology</a>\ufeff",
#     "plusoners": {
#      "totalItems": 81,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13si50jmnq3vjcag04chl3pvxfbszirt5o/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 6,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13si50jmnq3vjcag04chl3pvxfbszirt5o/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2017-06-04T14:13:55.443Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/7Ia2gaiepuRX47L3UUUy8gSPg-M\"",
#    "published": "2017-06-04T14:13:55.443Z",
#    "id": "z13si50jmnq3vjcag04chl3pvxfbszirt5o"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "Bryce Roberts is doing an amazing job cutting through the hype and making clear the distinction between...",
#    "url": "https://plus.google.com/+TimOReilly/posts/C4tRaJzV3tt",
#    "object": {
#     "resharers": {
#      "totalItems": 0,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13gubvarmbotd5e223gcxizetybvpydh/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "Real Businesses \u2013 Bryce Roberts \u2013 Medium",
#       "fullImage": {
#        "url": "https://cdn-images-1.medium.com/max/1200/1*29VmomVc1Xr1ngif78GJiA.png",
#        "type": "image/jpeg"
#       },
#       "url": "https://medium.com/@bryce/real-businesses-b21f44c99b6a",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/tYRoM9g7_PL-CT68kwQUNAO7Kffjz-VidcLL75qusUvfvLrkck1q-s9ovXt8cBzoYybw3nd-AEO1GS4nMPL7Jm3oke89aHHtYYLUwqq5nILhIgwa1g=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "There I was, minding my own business on Sunday afternoon, when someone decides to rope Indie.vc (and by default, me), into the work hard\u2026",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/C4tRaJzV3tt",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "Bryce Roberts is doing an amazing job cutting through the hype and making clear the distinction between lifestyle businesses, venture-backed businesses done right, and customer-driven businesses in the &quot;real economy&quot; of goods and services. This is a must-read for anyone considering launching a business.<br /><br />&quot;If your pitch deck has an &#39;exit strategy&#39; slide you are pitching a lifestyle business.... Real businesses make products and sell them for a profit. They focus on customers, revenue and profitability not investors, valuations and the next fundable milestone. Real businesses prioritize their customer\u2019s needs over their customer\u2019s eyeballs. They have a functioning business model, not a believable financial model. Real businesses want to stay in business, not run for the exit. They create their own source of funding and don\u2019t have to ask anyone for permission to exist. We believe real businesses make really great investments.&quot; \ufeff",
#     "plusoners": {
#      "totalItems": 44,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13gubvarmbotd5e223gcxizetybvpydh/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 1,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13gubvarmbotd5e223gcxizetybvpydh/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2017-06-02T21:04:16.254Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/mo0B5cycsq4q4wsZOCfHTm9DM6U\"",
#    "published": "2017-06-02T21:04:16.254Z",
#    "id": "z13gubvarmbotd5e223gcxizetybvpydh"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "I had wondered what was the underlying truth being distorted in Trump's claims. This NYT article does...",
#    "url": "https://plus.google.com/+TimOReilly/posts/R1anp6tsnDp",
#    "object": {
#     "resharers": {
#      "totalItems": 8,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12huj2wjqzkztlgj04chl3pvxfbszirt5o/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "Trump Says NATO Allies Don\u2019t Pay Their Share. Is That True? - The New York Times",
#       "fullImage": {
#        "url": "https://static01.nyt.com/images/2017/05/27/world/27nato/27nato-facebookJumbo.jpg",
#        "type": "image/jpeg"
#       },
#       "url": "https://www.nytimes.com/2017/05/26/world/europe/nato-trump-spending.html?_r=0",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/hlJXNAIZeFdAZV26EA-vU2s21GgPvy5gKkBb8hkQJZajBD6pjkoIk-Xm777ZbE7P3u12dhroGSayMi03LfQQs7aSYV01D5-Owv0Kcu9aHaYkxu7Rf-RWq4_Fa-rJliuR=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "When the president suggests that many allies \u201cowe massive amounts of money\u201d to the alliance, he has a point, but he mischaracterizes the way it works.",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/R1anp6tsnDp",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "I had wondered what was the underlying truth being distorted in Trump&#39;s claims. This NYT article does a good job of explaining fairly the truth about NATO&#39;s funding. \ufeff",
#     "plusoners": {
#      "totalItems": 118,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12huj2wjqzkztlgj04chl3pvxfbszirt5o/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 79,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12huj2wjqzkztlgj04chl3pvxfbszirt5o/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2017-05-29T14:39:28.881Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/XYFzUGZNvVNGcLwx3sU_5cvfz50\"",
#    "published": "2017-05-29T14:39:28.881Z",
#    "id": "z12huj2wjqzkztlgj04chl3pvxfbszirt5o"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "I'm really glad to see blame being put where it belongs: \"When an unlucky passenger was violently dragged...",
#    "url": "https://plus.google.com/+TimOReilly/posts/2sgxm7F3Eaz",
#    "object": {
#     "resharers": {
#      "totalItems": 4,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13vufsrtwbpsjakf23gcxizetybvpydh/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "Route to Air Travel Discomfort Starts on Wall Street",
#       "fullImage": {
#        "url": "https://static01.nyt.com/images/2017/05/28/business/28MARGINS-alpha/28MARGINS-alpha-facebookJumbo.jpg",
#        "type": "image/jpeg"
#       },
#       "url": "https://www.nytimes.com/2017/05/28/business/corporate-profit-margins-airlines.html",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/NFYOtQGV0bVSMSCrE7b4wpGsTsH4p76xYG9bCFYN7HjEsf2Z0YcE5DpLB97PO2E0Cmw5KzjBqisG9JnYDNN43QuM8Asbjef9z4FOKS_Gf-opZvj3x9kW_NCRDb1WA6XJqGcKMazmURMc4yxqTHTewNkrGkY6=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "Investors\u2019 relentless emphasis on the bottom line is fueling consumer frustration, and even episodes of air rage.",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/2sgxm7F3Eaz",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "I&#39;m really glad to see blame being put where it belongs: &quot;When an unlucky passenger was violently dragged off a full United Airlines flight in Chicago in April, setting off a public-relations nightmare for the company, the blame naturally fell on the cabin crew, the police and eventually airline executives. But ultimately, the episode was set in motion elsewhere \u2014 on Wall Street.&quot;<br />\ufeff",
#     "plusoners": {
#      "totalItems": 61,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13vufsrtwbpsjakf23gcxizetybvpydh/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 13,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13vufsrtwbpsjakf23gcxizetybvpydh/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2017-05-29T00:32:13.238Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/mWsmxlGBOcvqpxFSM7uK6sbSNgE\"",
#    "published": "2017-05-29T00:32:13.238Z",
#    "id": "z13vufsrtwbpsjakf23gcxizetybvpydh"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "Earlier this week, while I was in the UK, I was interviewed by @TPPodcast_ about tech, politics, and...",
#    "url": "https://plus.google.com/+TimOReilly/posts/dL6JcVdZrRB",
#    "object": {
#     "resharers": {
#      "totalItems": 0,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13jedfynzzwunait04chl3pvxfbszirt5o/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "Tim O'Reilly and the WTF Economy | TALKING POLITICS on acast",
#       "fullImage": {
#        "url": "https://imagecdn.acast.com/talkingpolitics/timoreillyandthewtfeconomy/image.jpg?w=400&h=400",
#        "type": "image/jpeg"
#       },
#       "url": "https://www.acast.com/talkingpolitics/timoreillyandthewtfeconomy?autoplay",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/zhha19vvCCWgnxohkBM-tdmmwCv_f6n9bRXIAeCaTleMsf-8BzpwKeIAnI3I0Ih2DnzWM28ocOIuloqJhB-q4R3oarErdQ18P08_0cxS4PX4-2gV-kkzkPUP4ZRyTXTTK5MG_f3D2TKZ8SM=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "We speak to Silicon Valley publisher, entrepreneur and guru Tim O'Reilly about what technology means for the future of politics and society.  A short conversation about the biggest questions: How do we get from a world of jobs to a world of meaningful work?  How can politics keep up with technological innovation?  How can we re-set our basic social arrangements without a war?  Recorded at the Computer Labs in Cambridge.",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/dL6JcVdZrRB",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "Earlier this week, while I was in the UK, I was interviewed by @TPPodcast_ about tech, politics, and the economy. I talk about why corporate efficiency - doing the same thing with fewer people to improve corporate profits - is a dead end. Great companies use the increased productivity brought by technology to DO MORE. Amazon is a great example of efficiency done right. I also talk about the equivalent of &quot;fake news&quot; in financial markets and the startup world. \ufeff",
#     "plusoners": {
#      "totalItems": 19,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13jedfynzzwunait04chl3pvxfbszirt5o/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 1,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13jedfynzzwunait04chl3pvxfbszirt5o/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2017-05-27T13:07:59.236Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/TgWj6Q5Hv0z6yO2WM5JfUAReMjo\"",
#    "published": "2017-05-27T13:07:59.236Z",
#    "id": "z13jedfynzzwunait04chl3pvxfbszirt5o"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "I'm totally stoked to hear that computational biologist and open science advocate (UC Berkeley professor...",
#    "url": "https://plus.google.com/+TimOReilly/posts/WVHsuWw3KfX",
#    "object": {
#     "resharers": {
#      "totalItems": 11,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12ddlyrrsvtyzdhk04chl3pvxfbszirt5o/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "Q&A: Michael Eisen bids to be first fly biologist in the U.S. Senate | Science | AAAS",
#       "fullImage": {
#        "url": "http://www.sciencemag.org/sites/default/files/styles/article_main_large/public/images/Michael%20Eisen%20horizontal.jpg?itok=tKzVylhW",
#        "type": "image/jpeg"
#       },
#       "url": "http://www.sciencemag.org/news/2017/01/qa-michael-eisen-wants-be-first-evolutionary-biologist-us-senate",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/HueduP882fmCKT1QET5P4H38364PZnHHXXt4Rqv5UE4EnDEto41TmP6NzcsVB5tgE72WpCMQXhA8iQ2Vni89wyfZMcjMHLStQDnkXG2aXbeWG1p9yi_JZYtHt_WaZ6OWngVIkLnrEbDyENsXPRmPhyim85WVqNKK-eANwzCphXa7AT-6mLBo7fYODcCArmOAlLm2_6U=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "California academic will make 2018 run",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/WVHsuWw3KfX",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "I&#39;m totally stoked to hear that computational biologist and open science advocate (UC Berkeley professor and co-founder of Public Library of Science) Michael Eisen is running for the US Senate, now tweeting as @SenatorPhD, with the tag line: \u201cLiberty, Equality, Reality\u201d. We could use some of that.\ufeff",
#     "plusoners": {
#      "totalItems": 68,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12ddlyrrsvtyzdhk04chl3pvxfbszirt5o/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 2,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12ddlyrrsvtyzdhk04chl3pvxfbszirt5o/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2017-05-27T12:08:40.259Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/TErYYlJRD1xmOHretU3LBJ6vznQ\"",
#    "published": "2017-05-27T12:08:40.259Z",
#    "id": "z12ddlyrrsvtyzdhk04chl3pvxfbszirt5o"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "This is a good summary of one of those fresh ideas that will change the way you see the world and think...",
#    "url": "https://plus.google.com/+TimOReilly/posts/JqYFPTGiRZm",
#    "object": {
#     "resharers": {
#      "totalItems": 13,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13md3bzszvzj1ofe23gcxizetybvpydh/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "A Grand New Theory of Life's Evolution on Earth",
#       "fullImage": {
#        "url": "https://cdn.theatlantic.com/assets/media/img/mt/2017/05/GettyImages_544180638/facebook.jpg?1495205025",
#        "type": "image/jpeg"
#       },
#       "url": "https://www.theatlantic.com/science/archive/2017/05/a-grand-unified-theory-for-life-on-earth/525648/",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/dZ5MITpIsrIJYqvyfOhSfsH4P9LiYQgWxXEFNUG4RVxENxwptQP47qPiUuJcnGXALhfXNUZrUztc3mSm8y45JVLHVBn4fD9p1UBz5-hu3WxnTnZRAuHRgIwl8qOCGShSOmwJdgVUqn6PRvDtcXsVoL9A7epx=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "A series of energy revolutions\u2014some natural, some technological\u2014built upon one another to give us our rich, diverse biosphere.",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/JqYFPTGiRZm",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "This is a good summary of one of those fresh ideas that will change the way you see the world and think about the future. The ending is particularly provocative. \ufeff",
#     "plusoners": {
#      "totalItems": 65,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13md3bzszvzj1ofe23gcxizetybvpydh/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 12,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13md3bzszvzj1ofe23gcxizetybvpydh/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2017-05-20T08:52:25.273Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/pCmqRa--DkurzTlQA4tDv-R-neM\"",
#    "published": "2017-05-20T08:52:25.273Z",
#    "id": "z13md3bzszvzj1ofe23gcxizetybvpydh"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "This is really great news. \"In the Occidental vote, the world\u2019s largest asset manager, BlackRock, for...",
#    "url": "https://plus.google.com/+TimOReilly/posts/LtXQBVb29tt",
#    "object": {
#     "resharers": {
#      "totalItems": 5,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12oy3lgulzvifwvq23gcxizetybvpydh/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "BlackRock tips shareholder vote to press oil giant on climate risk",
#       "fullImage": {
#        "url": "https://cdn-images-1.medium.com/max/1200/1*YBZ6W4M8PxLXytfD8IWSzw.jpeg",
#        "type": "image/jpeg"
#       },
#       "url": "https://medium.com/impactalpha/blackrock-tips-shareholder-vote-to-press-oil-giant-on-climate-risk-f0fc5831bca3",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/m3i7xtzJoqX5PjwuBHE0Th6eeFZItb2T2zhVbqgl0yaV8wcjVYLwE-L7KMG3LkNzGrgY6t5udEqiiK09VUImC8eShLzhXUu0DXX-LYYzyx4L-6Wn7yg=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "Shareholders are moving in the opposite direction as Washington",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/LtXQBVb29tt",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "This is really great news. &quot;In the Occidental vote, the world\u2019s largest asset manager, BlackRock, for the first time bucked management to vote in favor of a climate-risk resolution.... Even more striking, shareholder support is moving in the opposite direction from Washington policy.&quot; \ufeff",
#     "plusoners": {
#      "totalItems": 43,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12oy3lgulzvifwvq23gcxizetybvpydh/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 0,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12oy3lgulzvifwvq23gcxizetybvpydh/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2017-05-19T15:32:30.365Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/E1ELCpgoYClNvXU_GDJf3oONbWk\"",
#    "published": "2017-05-19T15:32:30.365Z",
#    "id": "z12oy3lgulzvifwvq23gcxizetybvpydh"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "Why do we treat assessments as \u201cgrades\u201d? I'm proud that our team at +O'Reilly is providing self-assessment...",
#    "url": "https://plus.google.com/+TimOReilly/posts/JSBCuf5kZ5x",
#    "object": {
#     "resharers": {
#      "totalItems": 2,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13fsn5rpufbx1bfc23gcxizetybvpydh/people/resharers"
#     },
#     "attachments": [
#      {
#       "url": "https://www.oreilly.com/ideas/why-self-assessments-improve-learning",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/Nm86vWf3BO33Lsa7q2sKI3ReOWrkUsFDWSrWwB29mJOXtqwTPvKRaIxLAPFtIO_NmtzmxWapLWh6Y3lcnivtGVysL9McuXn57vRPn5RPUCbxqvmCk20zxhk0_SSpmd2J1NTQafpw14iWPI8aFCWqb0XlhslULyA3RrgMnkTVWZI=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "fullImage": {
#        "url": "https://d3tdunqjn7n0wj.cloudfront.net/1400x933/oreilly-news-assessment-crop-303194c9c7077ea3b3b3ef45fc202057.jpg",
#        "type": "image/jpeg"
#       },
#       "displayName": "Why self assessments improve learning - O'Reilly Media",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/JSBCuf5kZ5x",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "Why do we treat assessments as \u201cgrades\u201d? I&#39;m proud that our team at <span class=\"proflinkWrapper\"><span class=\"proflinkPrefix\">+</span><a class=\"proflink\" href=\"https://plus.google.com/108442503368488643007\" oid=\"108442503368488643007\">O&#39;Reilly</a></span> is providing <b>self</b>-assessment! I&#39;ve always wanted this - tools to help people understand how to learn better, rather than for someone else to rate them. Thanks <span class=\"proflinkWrapper\"><span class=\"proflinkPrefix\">+</span><a class=\"proflink\" href=\"https://plus.google.com/104997627846308762856\" oid=\"104997627846308762856\">Paco Nathan</a></span> for leading this effort! \ufeff",
#     "plusoners": {
#      "totalItems": 31,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13fsn5rpufbx1bfc23gcxizetybvpydh/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 5,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13fsn5rpufbx1bfc23gcxizetybvpydh/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2017-05-12T17:34:03.071Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/6rDYeTGGuvYgdriwF-5gxnPf6w8\"",
#    "published": "2017-05-12T17:34:03.071Z",
#    "id": "z13fsn5rpufbx1bfc23gcxizetybvpydh"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "I'm so impressed with what Reid Hoffman and June Cohen have done with the #MastersOfScale podcast, so...",
#    "url": "https://plus.google.com/+TimOReilly/posts/gMN2aQUBKLR",
#    "object": {
#     "resharers": {
#      "totalItems": 1,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13bfdt5cuekj3cjf04chl3pvxfbszirt5o/people/resharers"
#     },
#     "attachments": [
#      {
#       "url": "https://www.linkedin.com/pulse/some-businesses-bleed-black-tim-o-reilly?published=t",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/k7vs1_eLa2Udp1djc9lwcdotd9GjzQo_GFz_u1Q2yoC-85z-jRmqRAlTBwEouf2M8t2o6S1JJ3I0AZQ2T11dIAnLYqKLtLNzj4AzdXB_yapeP0Mt7vParrqaprUzRD2-T7R8-CJ-LqiftcnNU4NVb1K3k0sFtosHuygeIJO--TojIOFDz2qdo-93uA=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "fullImage": {
#        "url": "https://media.licdn.com/mpr/mpr/shrinknp_400_400/AAEAAQAAAAAAAAmNAAAAJDRlM2JlZjk2LTYyMTktNGVlMC04NTUyLTk4MzA5NTBjNTNiMw.jpg",
#        "type": "image/jpeg"
#       },
#       "displayName": "Some Businesses Bleed Black  | LinkedIn",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/gMN2aQUBKLR",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "I&#39;m so impressed with what Reid Hoffman and June Cohen have done with the <a rel=\"nofollow\" class=\"ot-hashtag\" href=\"https://plus.google.com/s/%23MastersOfScale\">#MastersOfScale</a> podcast, so I jumped at June&#39;s offer to write a response to the second episode. I completely love what they have done. I&#39;m astonished at the richness of the storytelling and the production.  It&#39;s the This American Life of the tech world. So even though I point out a gap in Reid&#39;s argument about why you should always take more money from investors than you think you need, I can&#39;t hope to compete by providing a response that is only in print. <br /><br />Still, I hope that you&#39;ll listen to the original, read about my own experiences as a bootstrapped entrepreneur, and think about the wide range of opportunities to make your business better. There is so much to learn, and Reid&#39;s podcast is perfectly designed to teach you. Each episode is focused on one key lesson, which is illustrated through the stories of real entrepreneurs.\ufeff",
#     "plusoners": {
#      "totalItems": 9,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13bfdt5cuekj3cjf04chl3pvxfbszirt5o/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 1,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13bfdt5cuekj3cjf04chl3pvxfbszirt5o/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2017-05-11T22:48:47.540Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/XYuYazoiXxf5IpsPCoEsGwuA2fk\"",
#    "published": "2017-05-11T22:48:47.540Z",
#    "id": "z13bfdt5cuekj3cjf04chl3pvxfbszirt5o"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "I love new sources of trend data about technology adoption. We've used variations of this for years ...",
#    "url": "https://plus.google.com/+TimOReilly/posts/FetXVRJeJFv",
#    "object": {
#     "resharers": {
#      "totalItems": 2,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12iwveh5zqvwnner23gcxizetybvpydh/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "Introducing Stack Overflow Trends - Stack Overflow Blog",
#       "fullImage": {
#        "url": "https://zgab33vy595fw5zq-zippykid.netdna-ssl.com/wp-content/uploads/2017/05/languages-2-1024x621.png",
#        "type": "image/jpeg"
#       },
#       "url": "https://stackoverflow.blog/2017/05/09/introducing-stack-overflow-trends/",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/65xYGsVfXLE8NOdxOLzX6GuwzTRNR33D32exmnJr4WsHblDjR7Lu6tZus6Vkx4rEFpuxSvgO8HMLfxt3JIbtTX3_6v0CFuC6YzVIiZdUdXYHlMN1D6oX02-Q-eL4aOHmFgSiSI2dWI0NLgF2069HAWIMG3c=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "On a typical day, developers ask over 8,000 questions on Stack Overflow about programming problems they run into in their work. Which technologies are they asking about, and how has that changed over time?",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/FetXVRJeJFv",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "I love new sources of trend data about technology adoption. We&#39;ve used variations of this for years at O&#39;Reilly, with data from job postings, book sales, website popularity, downloads from archive sites, mailing list postings, github data, and more. But here&#39;s some great data now available from Stack Overflow \ufeff",
#     "plusoners": {
#      "totalItems": 23,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12iwveh5zqvwnner23gcxizetybvpydh/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 2,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12iwveh5zqvwnner23gcxizetybvpydh/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2017-05-10T22:17:36.047Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/1kf6xPL23F8Se_CoF0Sxyftc8to\"",
#    "published": "2017-05-10T22:17:36.047Z",
#    "id": "z12iwveh5zqvwnner23gcxizetybvpydh"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "So happy to see Code for America alum company Remix getting so much traction and a new round of funding...",
#    "url": "https://plus.google.com/+TimOReilly/posts/NiY4cuwdjZr",
#    "object": {
#     "resharers": {
#      "totalItems": 0,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12gzdzh1mzkgbuo104chl3pvxfbszirt5o/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "Remix Helps Transit Agencies Create New Routes - WSJ",
#       "fullImage": {
#        "url": "https://si.wsj.net/public/resources/images/BN-TI633_Remix_TOP_20170508141918.jpg",
#        "type": "image/jpeg"
#       },
#       "url": "https://www.wsj.com/articles/remix-helps-transit-agencies-create-new-routes-1494329401?utm_content=buffer3828a&utm_medium=social&utm_source=twitter.com&utm_campaign=buffer",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/gw1H3LCkKPa9eiz9w8J3nDhLQyftJwAZC9qSmSc_aosZftuBy8v3PeK5MCWXVRH79qd-rVgVuqmLv9Gk6E6ruOT8pzHBxs0BnoDdBcnp2QlFBPMbrtYbXMCEVmrTJVtL=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "Remix has raised $10 million in Series A financing led by Sequoia Capital to help public transportation planners quickly create or change their transit routes.",
#       "objectType": "article"
#      }
#     ],
# ...
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "Cyber Monday 2015",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/ZzxXrnzbTVd",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "Safari is O&#39;Reilly&#39;s subscription access program - thousands of hours of video (including full video from many O&#39;Reilly conferences) and tens of thousands of books from O&#39;Reilly and many other publishers. \u00a0Check out our cyber-Monday offer: $199/year for complete access.\ufeff",
#     "plusoners": {
#      "totalItems": 23,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13mf5zbspfospdi504chl3pvxfbszirt5o/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 2,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13mf5zbspfospdi504chl3pvxfbszirt5o/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-11-30T17:31:50.709Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/a-qANnSFCU4JLY4fNRj3_fYL8vc\"",
#    "published": "2015-11-30T17:31:50.709Z",
#    "id": "z13mf5zbspfospdi504chl3pvxfbszirt5o"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "John Oliver: \"There was only one time in American history when the fear of refugees wiping everyone ...",
#    "url": "https://plus.google.com/+TimOReilly/posts/RVdwAVegYsu",
#    "object": {
#     "resharers": {
#      "totalItems": 42,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12adhrjdriid1i4m04chl3pvxfbszirt5o/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "John Oliver makes the complete, unvarnished case for accepting Syrian refugees",
#       "fullImage": {
#        "url": "http://api.theweek.com/sites/default/files/styles/tw_image_6_4/public/Screen%20Shot%202015-11-23%20at%203.29.52%20AM.jpg?itok=QUzXn5XI",
#        "type": "image/jpeg"
#       },
#       "url": "http://theweek.com/speedreads/590431/john-oliver-makes-complete-unvarnished-case-accepting-syrian-refugees",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/8lTbwkQJzTiOkR60zV12FeQOtdIogsjS6UIhWNy-9HT5XdzM2cqqK2H4n8tJxazQUmWKfdtYL2F0XHeMsyfROroByRsuBbBfVsCJy08uaXIp7llFav7QApQNYtiZJS6bGz-SwK3SfzkFwTD1Y1z4yL67l-r-EMnIuMxg6UANOXdEZ-7_UiaaS2g3K0yffxWcqS32WpcC6Q=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "John Oliver has the perfect (or really, perfectly terrible) response when your elderly relatives start sniping at you during Thanksgiving dinner. \"When your grandmother is complaining about your new piercing, saying your generation is terrible, simply reply, 'Okay, Nana, but at least we didn't send Jews back to Europe in 1939.' Then break off a turkey leg, drop it like a microphone, and you've just won the dinner.\" Oliver is talking specifically ...",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/RVdwAVegYsu",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "John Oliver: &quot;There was only one time in American history when the fear of refugees wiping everyone out did actually come true...&quot;\u201c...and we\u2019ll be celebrating it on Thursday.\u201d<br /><br />That&#39;s maybe the best line, but there&#39;s lots of substance here too. Well worth watching.\ufeff",
#     "plusoners": {
#      "totalItems": 226,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12adhrjdriid1i4m04chl3pvxfbszirt5o/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 27,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12adhrjdriid1i4m04chl3pvxfbszirt5o/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-11-23T20:01:59.500Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/16CgzkKM1jE_e50JBr0olhJL_NM\"",
#    "published": "2015-11-23T20:01:59.500Z",
#    "id": "z12adhrjdriid1i4m04chl3pvxfbszirt5o"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "Video learning paths have been a huge hit on oreilly.com. They are available on @safari too.",
#    "url": "https://plus.google.com/+TimOReilly/posts/S7sE9MLq5hw",
#    "object": {
#     "resharers": {
#      "totalItems": 2,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z123ffbj2x21t55oq04chl3pvxfbszirt5o/people/resharers"
#     },
#     "attachments": [
#      {
#       "content": "Safari",
#       "url": "http://www.safaribooksonline.com/list/oreilly-learning-paths",
#       "displayName": "List: O'Reilly Learning Paths: Safari",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/S7sE9MLq5hw",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "Video learning paths have been a huge hit on <a href=\"http://oreilly.com\" class=\"ot-anchor\">oreilly.com</a>. They are available on @safari too.\ufeff",
#     "plusoners": {
#      "totalItems": 18,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z123ffbj2x21t55oq04chl3pvxfbszirt5o/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 0,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z123ffbj2x21t55oq04chl3pvxfbszirt5o/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-11-19T15:24:44.415Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/Q5YSgwjlE86FntU_-tdZplZYJTg\"",
#    "published": "2015-11-19T15:24:44.415Z",
#    "id": "z123ffbj2x21t55oq04chl3pvxfbszirt5o"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "Here are the 2016 @codeforamerica Fellowship partner cities. Can\u2019t wait to see the impact of these projects...",
#    "url": "https://plus.google.com/+TimOReilly/posts/MwkbTgqo51J",
#    "object": {
#     "resharers": {
#      "totalItems": 2,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12swnsynm2ih5avx23gcxizetybvpydh/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "The 2016 CfA Fellowship | Code for America",
#       "fullImage": {
#        "url": "http://codeforamerica.org//media/images/cities/cities_header.jpg",
#        "type": "image/jpeg"
#       },
#       "url": "https://www.codeforamerica.org/governments/2016-announcement",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/_j91BS8IvO-MGmH2EB_tesHvkusKUiT3qh1iRkhzl9FrQf7u5tdVOM3VtYPexhmem4fDZnahgNGwkYZmaomsnxsuMd4dG7ilXezqIKtqBAE=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "Code for America is working towards a government by the people, for the people, that works in the 21st century. We are a 501(c)3 non-profit that helps residents and governments harness technology to solve community problems.",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/MwkbTgqo51J",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "Here are the 2016 @codeforamerica Fellowship partner cities. Can\u2019t wait to see the impact of these projects!\ufeff",
#     "plusoners": {
#      "totalItems": 30,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12swnsynm2ih5avx23gcxizetybvpydh/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 1,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12swnsynm2ih5avx23gcxizetybvpydh/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-11-18T00:31:17.114Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/VstJYaPV-8r2E0hT0PL_8woAgEc\"",
#    "published": "2015-11-18T00:31:17.114Z",
#    "id": "z12swnsynm2ih5avx23gcxizetybvpydh"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "Absolutely brilliant piece about complexity, public policy, and business From #NextEconomy speaker Esko...",
#    "url": "https://plus.google.com/+TimOReilly/posts/VjsAqUeGVA4",
#    "object": {
#     "resharers": {
#      "totalItems": 34,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z122utgjct3ijbu5f04chl3pvxfbszirt5o/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "Complexity \u2014 What\u2019s The Future of Work?",
#       "fullImage": {
#        "url": "https://cdn-images-1.medium.com/max/800/1*YQHbt5QcIk8JGazBQFjA3Q.jpeg",
#        "type": "image/jpeg"
#       },
#       "url": "http://bit.ly/1MAL9VW",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/Su6SzV-hTJfjLJ05AUK3pVtqlyYTk7ucfZuk9JIqTGAWMquvhpyg1wFhbrZxS8TRHZL-gwZyd4yKtm8RvK69-20tXdpoy6l-oGDv9NCOPXSSlZETjw=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "We often think that what materializes in the world is chosen by some individuals, the leaders. If good things happen and\u2026",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/VjsAqUeGVA4",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "Absolutely brilliant piece about complexity, public policy, and business From <a rel=\"nofollow\" class=\"ot-hashtag\" href=\"https://plus.google.com/s/%23NextEconomy\">#NextEconomy</a> speaker Esko Kilpi. He is such a fresh business thinker. Every time I read his stuff, I come away looking at the world differently.\ufeff",
#     "plusoners": {
#      "totalItems": 83,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z122utgjct3ijbu5f04chl3pvxfbszirt5o/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 5,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z122utgjct3ijbu5f04chl3pvxfbszirt5o/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-11-11T16:57:37.665Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/nqluQno_tRcUkHFaEwS1C_pjyC4\"",
#    "published": "2015-11-11T16:57:37.665Z",
#    "id": "z122utgjct3ijbu5f04chl3pvxfbszirt5o"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "Portable benefits tied to the worker, not the company, are key to rethinking the social safety net for...",
#    "url": "https://plus.google.com/+TimOReilly/posts/TJMVfMWgeX4",
#    "object": {
#     "resharers": {
#      "totalItems": 5,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13pzrpivoyhibbgx04chl3pvxfbszirt5o/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "Common ground for independent workers",
#       "fullImage": {
#        "url": "https://cdn-images-1.medium.com/max/800/1*dmbNkD5D-u45r44go_cf0g.png",
#        "type": "image/jpeg"
#       },
#       "url": "https://medium.com/@principles/common-ground-for-independent-workers-83f3fbcf548f",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/wLrITb5EIxZ-KCpuTm0C9kAfkUQ6S682Y94Vvo9nMuKhfTN3YrfZc2neUECc648SU5lw-rFYLKNqDXuxIJhy8RYpb6AwivrwprpAGevZ6FLfhQWQ=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "Principles for delivering a stable and flexible safety net for all types of work",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/TJMVfMWgeX4",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "Portable benefits tied to the worker, not the company, are key to rethinking the social safety net for the <a rel=\"nofollow\" class=\"ot-hashtag\" href=\"https://plus.google.com/s/%23NextEconomy\">#NextEconomy</a> I&#39;m proud to be a signatory to this open letter calling for this key policy innovation. One thing I&#39;d add is that this could have an impact on traditional W2 workers as well, making it easier for them to work for multiple employers. <a href=\"https://medium.com/@principles/common-ground-for-independent-workers-83f3fbcf548f\" class=\"ot-anchor\">https://medium.com/@principles/common-ground-for-independent-workers-83f3fbcf548f</a>\ufeff",
#     "plusoners": {
#      "totalItems": 50,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13pzrpivoyhibbgx04chl3pvxfbszirt5o/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 4,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13pzrpivoyhibbgx04chl3pvxfbszirt5o/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-11-10T16:11:03.567Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/km-rpHTR8FWA4bu4KLqhbvUFxMU\"",
#    "published": "2015-11-10T16:11:03.567Z",
#    "id": "z13pzrpivoyhibbgx04chl3pvxfbszirt5o"
#   }
#  ],
#  "updated": "2017-06-14T19:42:43.018Z",
#  "etag": "\"Sh4n9u6EtD24TM0RmWv7jTXojqc/nIBxBgrsjy9xpxkH-ooUSgtk2yk\""
# }

# %% [markdown]
# ## Example 4. Cleaning HTML in Google+ content by stripping out HTML tags and converting HTML entities back to plain-text representations

# %%
from nltk import clean_html
from bs4 import BeautifulSoup

# clean_html removes tags and
# BeautifulStoneSoup converts HTML entities

def cleanHtml(html):
    if html == "": return ""

    soup = BeautifulSoup(html).get_text()
  
    return soup

#   return BeautifulStoneSoup(clean_html(html), "xml",
#           convertEntities=BeautifulStoneSoup.HTML_ENTITIES).contents[0]

print activity_feed['items'][3]['object']['content']
print
print cleanHtml(activity_feed['items'][3]['object']['content'])
# Out:
# This is what you get when you believe that “government should just get out of the way” and let industry do its thing. When will get over the failed idea that good government is an obstacle to progress? We do best when government, business, and all of society work together towards shared goals. ﻿
#
# This is what you get when you believe that “government should just get out of the way” and let industry do its thing. When will get over the failed idea that good government is an obstacle to progress? We do best when government, business, and all of society work together towards shared goals. ﻿
# /Users/santteegt/anaconda/lib/python2.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file /Users/santteegt/anaconda/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %% [markdown]
# ## Example 5. Looping over multiple pages of Google+ activities and distilling clean text from notes

# %%
import os
# import httplib2
# import json
# import apiclient.discovery
# from BeautifulSoup import BeautifulStoneSoup
# from nltk import clean_html

USER_ID = '107033731246200681024' # Tim O'Reilly

# XXX: Re-enter your API_KEY from  https://code.google.com/apis/console 
# if not currently set
# API_KEY = '' 

MAX_RESULTS = 200 # Will require multiple requests

# def cleanHtml(html):
#   if html == "": return ""

#   return BeautifulStoneSoup(clean_html(html),
#           convertEntities=BeautifulStoneSoup.HTML_ENTITIES).contents[0]

service = apiclient.discovery.build('plus', 'v1', http=httplib2.Http(), 
                                    developerKey=API_KEY)

activity_feed = service.activities().list(userId=USER_ID, 
                                          collection='public',
                                          maxResults='100' # Max allowed per request
                                         )

activity_results = []

while activity_feed != None and len(activity_results) < MAX_RESULTS:

    activities = activity_feed.execute()

    if 'items' in activities:

        for activity in activities['items']:

            if activity['object']['objectType'] == 'note' and activity['object']['content'] != '':

                activity['title'] = cleanHtml(activity['title'])
                activity['object']['content'] = cleanHtml(activity['object']['content'])
                activity_results += [activity]

    # list_next requires the previous request and response objects
    activity_feed = service.activities().list_next(activity_feed, activities)

# Write the output to a file for convenience

f = open(os.path.join('resources', 'ch04-googleplus', USER_ID + '.json'), 'w')
f.write(json.dumps(activity_results, indent=1))
f.close()

print str(len(activity_results)), "activities written to", f.name
# Out:
# 272 activities written to resources/ch04-googleplus/107033731246200681024.json

# %% [markdown]
# ## Example 6. Sample data structures used in illustrations for the rest of this chapter

# %%
corpus = { 
 'a' : "Mr. Green killed Colonel Mustard in the study with the candlestick. \
Mr. Green is not a very nice fellow.",
 'b' : "Professor Plum has a green plant in his study.",
 'c' : "Miss Scarlett watered Professor Plum's green plant while he was away \
from his office last week."
}
terms = {
 'a' : [ i.lower() for i in corpus['a'].split() ],
 'b' : [ i.lower() for i in corpus['b'].split() ],
 'c' : [ i.lower() for i in corpus['c'].split() ]
 }

# %% [markdown]
# ## Example 7. Running TF-IDF on sample data

# %%
from math import log

# XXX: Enter in a query term from the corpus variable
QUERY_TERMS = ['mr', 'green']

def tf(term, doc, normalize=True):
    doc = doc.lower().split()
    if normalize:
        return doc.count(term.lower()) / float(len(doc))
    else:
        return doc.count(term.lower()) / 1.0


def idf(term, corpus):
    num_texts_with_term = len([True for text in corpus if term.lower()
                              in text.lower().split()])

    # tf-idf calc involves multiplying against a tf value less than 0, so it's
    # necessary to return a value greater than 1 for consistent scoring. 
    # (Multiplying two values less than 1 returns a value less than each of 
    # them.)

    try:
        return 1.0 + log(float(len(corpus)) / num_texts_with_term)
    except ZeroDivisionError:
        return 1.0


def tf_idf(term, doc, corpus):
    return tf(term, doc) * idf(term, corpus)


corpus = \
    {'a': 'Mr. Green killed Colonel Mustard in the study with the candlestick. \
Mr. Green is not a very nice fellow.',
     'b': 'Professor Plum has a green plant in his study.',
     'c': "Miss Scarlett watered Professor Plum's green plant while he was away \
from his office last week."}

for (k, v) in sorted(corpus.items()):
    print k, ':', v
print
    
# Score queries by calculating cumulative tf_idf score for each term in query

query_scores = {'a': 0, 'b': 0, 'c': 0}
for term in [t.lower() for t in QUERY_TERMS]:
    for doc in sorted(corpus):
        print 'TF(%s): %s' % (doc, term), tf(term, corpus[doc])
    print 'IDF: %s' % (term, ), idf(term, corpus.values())
    print

    for doc in sorted(corpus):
        score = tf_idf(term, corpus[doc], corpus.values())
        print 'TF-IDF(%s): %s' % (doc, term), score
        query_scores[doc] += score
    print

print "Overall TF-IDF scores for query '%s'" % (' '.join(QUERY_TERMS), )
for (doc, score) in sorted(query_scores.items()):
    print doc, score
# Out:
# a : Mr. Green killed Colonel Mustard in the study with the candlestick. Mr. Green is not a very nice fellow.
# b : Professor Plum has a green plant in his study.
# c : Miss Scarlett watered Professor Plum's green plant while he was away from his office last week.
#
# TF(a): green 0.105263157895
# TF(b): green 0.111111111111
# TF(c): green 0.0625
# IDF: green 1.0
#
# TF-IDF(a): green 0.105263157895
# TF-IDF(b): green 0.111111111111
# TF-IDF(c): green 0.0625
#
# Overall TF-IDF scores for query 'green'
# a 0.105263157895
# b 0.111111111111
# c 0.0625

# %% [markdown]
# ## Example 8. Exploring Google+ data with NLTK

# %%
# Explore some of NLTK's functionality by exploring the data. 
# Here are some suggestions for an interactive interpreter session.

import nltk

# Download ancillary nltk packages if not already installed
nltk.download('stopwords')

all_content = " ".join([ a['object']['content'] for a in activity_results ])

# Approximate bytes of text
print len(all_content)

tokens = all_content.split()
text = nltk.Text(tokens)

# Examples of the appearance of the word "open"
print('CONCORDANCE OF WORD OPEN')
text.concordance("open")

# Frequent collocations in the text (usually meaningful phrases)
print('COLLOCATIONS')
text.collocations()

# Frequency analysis for words of interest
fdist = text.vocab()
print('open: %d | source: %d | web: %d | 2.0: %d' % (fdist["open"], fdist["source"], fdist["web"], fdist["2.0"]))

# Number of words in the text
len(tokens)

# Number of unique words in the text

unique_words = len(fdist.keys())

print('Unique words: %d' % unique_words)

# Common words that aren't stopwords
common_words = [w for w in fdist.keys()[:100] \
   if w.lower() not in nltk.corpus.stopwords.words('english')]

print(common_words)

# Long words that aren't URLs
long_words = [w for w in fdist.keys() if len(w) > 15 and not w.startswith("http")]

print(long_words)

# Number of URLs
total_urls = len([w for w in fdist.keys() if w.startswith("http")])

print('Total URLs %d' % total_urls)

# Enumerate the frequency distribution
for rank, word in enumerate(sorted(fdist.items(), key=lambda x: x[1], reverse=True)): 
    print rank, word
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/santteegt/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 107171
# CONCORDANCE OF WORD OPEN
# Displaying 15 of 15 matches:
# ear that computational biologist and open science advocate (UC Berkeley profes
# : magazine slogan say, "If you can't open it, you don't own it." ﻿ Predictive
#  I'm proud to be a signatory to this open letter calling for this key policy i
# st, I've focused a lot on areas like open source software and the implications
# opic at greater length in my article Open Data and Algorithmic Regulation: htt
# cessful participatory projects, from open source software to wikis to social m
# ere isn't one (except that it's only open to US students - sorry. If anyone ha
# new contract that conformed with the open data mandate. If it were consistent
# If it were consistent with the Obama open data guidance, that RFP would requir
# ut of step with the administration’s open data policy.The founder of Hipcamp,
# is is a really important piece about open data and platforms.﻿ Work on sh-t th
# .﻿ An excellent demonstration of why Open Access lowers the barriers to knowle
# r is to fix the errors, not to blame open data for showing them, and give publ
# nd solution provider. The government open data movement is a big step in this
#  of Education on the design of their open data APIs, now is your chance. Detai
# COLLOCATIONS
# Silicon Valley; open data; Common Core; Next:Economy Summit; +Jennifer
# Pahlka; New York; Cabo Pulmo; O'Reilly Media; on-demand economy,; Bay
# Mini; East Bay; White House; San Francisco; granite workers; Maker
# Faire; Mini Maker; Real businesses; Well worth; healthcare.gov rescue;
# Barre Historical
# open: 13 | source: 5 | web: 2 | 2.0: 0
# Unique words: 5769
# [u'four', u'looking', u'Neuralink,', u'basic,', u'illegally', u'advice,', u'befoul', u'politician', u'bringing', u'writing.', u'scholar', u'Maras.\ufeff', u'straight', u'Rachel', u'(except', u'1997.', u'second', u'empathyJake', u'errors', u'cooking', u'self-assessment!', u'report,', u'sales,', u'Hamilton', u'(Minute', u'Neville', u"Apple's", u'fun', u'Habits', u'cult', u'conversational', u'kids', u'reports', u'deniers.', u'\u201cgovernment', u'brought', u'Basic', u'"The', u'explainer', u'oreilly.com.', u'spoke', u'Indeed,', u'music', u'strike', u'Necessary', u'successful', u'brings', u'high-wage', u'hurt', u'motorists.\ufeff', u'90', u'circumstances', u'culture."', u'interaction', u'laughter,', u'example', u'catch.', u'La', u'currency', u'adoption.', u'want', u'around.', u'LA', u'travel', u'hot', u'Cooperative', u'beauty', u'wrong', u'types', u'below).I', u'baggage', u'Fabulous', u'keeps', u'democratic', u'feedback', u'dreamed', u'govern', u'vary', u'today.', u'bootstrapped', u'IFTTT.', u'fit', u'fix', u'Othermachines', u'hidden', u'easier', u'schools', u'pay."\ufeff', u'represents', u'renditions', u'"punch', u'API', u'employers.', u'debug', u'mature.']
# [u'self-assessment!', u'sustainability.\ufeff', u'(https://medium.com/the-wtf-economy/the-wtf-economy-a3bd5f52ef00)', u'statistics:"Typically,', u'#LeanInTogether\ufeff', u'results."Consider,', u'transformative.)', u'significantly."It', u'outcome"Real-time', u'Healthcare.govDraw', u'Ireland.Incidentally,', u'outcome?"(http://beyondtransparency.org/chapters/part-5/open-data-and-algorithmic-regulation/).\ufeff', u'#FutureCrimesConvo,', u'opens:"Something\u2019s', u'quasi-governmental', u'Palestinians:"This', u'life-threatening', u'entrepreneurship', u'national-authority', u'here:http://www.eventbrite.com/e/libbyraiser-tickets-11878702519\ufeff', u'Foundation.http://www.wsj.com/articles/sean-parker-philanthropy-for-hackers-1435345787\ufeff', u'post.)http://www.pressheretv.com/tim-oreilly/\ufeff', u'available:http://ebmakerfaire2014.eventbrite.com\ufeff', u'underrepresented', u'non-transferable', u'algorithmically,', u'innovation-resistant', u'condition."Lovely.And', u'www.futurecrimes.com\ufeff', u'(https://medium.com/the-wtf-economy/networks-and-the-nature-of-the-firm-28790b6afdcc).', u'nyti.ms/1UbkG1J\ufeff', u'achieved"Algorithms', u'producers....Like', u'Brothers...."Their', u'stream-processing', u'(drnkwines.com),', u'#OReillySecurity', u'\u201cattend-listen-embarrass\u201d', u'you!https://www.crowdpac.com/campaigns/100604\ufeff', u'knowledge-sharing', u'codeforamerica.org.', u'implementation."Last', u'forward-thinking', u'administration\u2019s', u'(http://conferences.oreilly.com/next-economy)\ufeff', u'achieved"Contrast', u'#makesecurityeasy', u"Thursday.\u201dThat's", u'doing.Individually,', u'opens:"Regulation', u"backwards.Here's", u'public-relations', u'IndependenceThis', u'October.http://www.inc.com/magazine/201606/sheila-marikar/lola-paul-english-uber.html\ufeff', u'philanthropists,', u'Super-interesting.', u'level-headedness.\ufeff', u'jasonmking@fs.fed.us', u'collusion...could', u'profitability.\u201d\ufeff', u'Republican-controlled', u'Makers/Exhibitors/Performers,', u'everyone"Adjustments', u'implementation."', u'customizability.', u'(http://conferences.oreilly.com/nextcon/money-fintech-us)\ufeff', u'humansofnewyork.com', u'software...."Get', u'interoperability', u'Regulations?Evgeny', u'Michener)quoteinvestigator.com/2010/08/27/master/Thanks']
# Total URLs 31
# 0 (u'the', 871)
# 1 (u'to', 546)
# 2 (u'of', 464)
# 3 (u'and', 429)
# 4 (u'a', 379)
# 5 (u'in', 273)
# 6 (u'is', 251)
# 7 (u'for', 217)
# 8 (u'that', 197)
# 9 (u'I', 185)
# 10 (u'on', 161)
# 11 (u'about', 132)
# 12 (u'with', 121)
# 13 (u'it', 115)
# 14 (u'at', 106)
# 15 (u'are', 103)
# 16 (u'this', 97)
# 17 (u'you', 97)
# 18 (u'from', 88)
# 19 (u'as', 87)
# 20 (u'be', 86)
# 21 (u'have', 76)
# 22 (u'an', 73)
# 23 (u'by', 73)
# 24 (u'we', 72)
# 25 (u'my', 71)
# 26 (u'what', 70)
# 27 (u'how', 65)
# 28 (u'they', 62)
# 29 (u'but', 62)
# 30 (u'was', 59)
# 31 (u'not', 56)
# 32 (u'\ufeff', 54)
# 33 (u'This', 54)
# 34 (u'their', 53)
# 35 (u'The', 52)
# 36 (u'so', 48)
# 37 (u'can', 47)
# 38 (u'do', 46)
# 39 (u'new', 46)
# 40 (u'out', 46)
# 41 (u'his', 46)
# 42 (u'has', 45)
# 43 (u'like', 45)
# 44 (u'than', 43)
# 45 (u'who', 43)
# 46 (u'more', 39)
# 47 (u'or', 38)
# 48 (u'one', 36)
# 49 (u'should', 36)
# 50 (u'good', 36)
# 51 (u'data', 35)
# 52 (u'if', 35)
# 53 (u'make', 35)
# 54 (u'will', 35)
# 55 (u'up', 34)
# 56 (u'work', 34)
# 57 (u'people', 33)
# 58 (u'just', 33)
# 59 (u'-', 33)
# 60 (u'see', 31)
# 61 (u'when', 31)
# 62 (u'all', 31)
# 63 (u'get', 30)
# 64 (u'our', 30)
# 65 (u'them', 29)
# 66 (u'way', 28)
# 67 (u'your', 28)
# 68 (u"I'm", 28)
# 69 (u'us', 27)
# 70 (u'government', 27)
# 71 (u'he', 27)
# 72 (u'piece', 27)
# 73 (u'We', 27)
# 74 (u'me', 26)
# 75 (u'It', 26)
# 76 (u'which', 26)
# 77 (u'love', 25)
# 78 (u'some', 25)
# 79 (u'And', 25)
# 80 (u'time', 24)
# 81 (u'also', 24)
# 82 (u'now', 24)
# 83 (u'If', 24)
# 84 (u'why', 24)
# 85 (u'better', 23)
# 86 (u'think', 23)
# 87 (u'been', 23)
# 88 (u'many', 22)
# 89 (u'its', 22)
# 90 (u'into', 22)
# 91 (u'great', 22)
# 92 (u'But', 22)
# 93 (u'had', 20)
# 94 (u'only', 20)
# 95 (u'no', 20)
# 96 (u"It's", 20)
# 97 (u'there', 20)
# 98 (u'best', 19)
# 99 (u"I've", 19)
# 100 (u'very', 19)
# 101 (u'help', 19)
# 102 (u"O'Reilly", 19)
# 103 (u'other', 19)
# 104 (u'much', 18)
# 105 (u'business', 18)
# 106 (u'So', 18)
# 107 (u'need', 18)
# 108 (u'last', 18)
# 109 (u'A', 17)
# 110 (u'read', 17)
# 111 (u'even', 17)
# 112 (u'first', 17)
# 113 (u'most', 17)
# 114 (u'over', 17)
# 115 (u"don't", 17)
# 116 (u'want', 16)
# 117 (u'technology', 16)
# 118 (u'Google', 16)
# 119 (u'those', 16)
# 120 (u'\u2014', 16)
# 121 (u'They', 15)
# 122 (u'it.', 15)
# 123 (u'US', 15)
# 124 (u'article', 15)
# 125 (u'money', 15)
# 126 (u'would', 15)
# 127 (u'any', 15)
# 128 (u'My', 14)
# 129 (u'going', 14)
# 130 (u'don\u2019t', 14)
# 131 (u'am', 14)
# 132 (u'really', 14)
# 133 (u'makes', 14)
# 134 (u'give', 14)
# 135 (u'said', 14)
# 136 (u'through', 14)
# 137 (u'him', 14)
# 138 (u'open', 13)
# 139 (u'future', 13)
# 140 (u'lot', 13)
# 141 (u'companies', 13)
# 142 (u'talk', 13)
# 143 (u'then', 13)
# 144 (u'same', 13)
# 145 (u'big', 13)
# 146 (u'know', 13)
# 147 (u'own', 13)
# 148 (u'world', 12)
# 149 (u'past', 12)
# 150 (u'could', 12)
# 151 (u'put', 12)
# 152 (u'As', 12)
# 153 (u'America', 12)
# 154 (u'find', 12)
# 155 (u'between', 12)
# 156 (u"it's", 12)
# 157 (u'always', 12)
# 158 (u'long', 12)
# 159 (u'use', 12)
# 160 (u'something', 12)
# 161 (u'looking', 11)
# 162 (u'Code', 11)
# 163 (u'right', 11)
# 164 (u'working', 11)
# 165 (u'company', 11)
# 166 (u'set', 11)
# 167 (u'video', 11)
# 168 (u'doing', 11)
# 169 (u'post', 11)
# 170 (u'down', 11)
# 171 (u'thinking', 11)
# 172 (u'Next:Economy', 11)
# 173 (u'amazing', 11)
# 174 (u'little', 11)
# 175 (u'may', 11)
# 176 (u'pay', 11)
# 177 (u'important', 11)
# 178 (u'What', 11)
# 179 (u'idea', 11)
# 180 (u'services', 11)
# 181 (u'keep', 11)
# 182 (u'two', 11)
# 183 (u'come', 11)
# 184 (u'job', 11)
# 185 (u'rather', 11)
# 186 (u'book', 11)
# 187 (u'because', 11)
# 188 (u'where', 10)
# 189 (u'does', 10)
# 190 (u'real', 10)
# 191 (u'event', 10)
# 192 (u'look', 10)
# 193 (u'while', 10)
# 194 (u'key', 10)
# 195 (u'did', 10)
# 196 (u'public', 10)
# 197 (u'part', 10)
# 198 (u'often', 10)
# 199 (u'too', 10)
# 200 (u'regulate', 10)
# 201 (u'able', 10)
# 202 (u'He', 10)
# 203 (u'In', 10)
# 204 (u'story', 10)
# 205 (u'never', 9)
# 206 (u'take', 9)
# 207 (u'being', 9)
# 208 (u'her', 9)
# 209 (u'Safari', 9)
# 210 (u'full', 9)
# 211 (u'worth', 9)
# 212 (u'these', 9)
# 213 (u'making', 9)
# 214 (u'anyone', 9)
# 215 (u'were', 9)
# 216 (u'Not', 9)
# 217 (u'businesses', 9)
# 218 (u'Maker', 9)
# 219 (u'bit', 9)
# 220 (u'Silicon', 9)
# 221 (u'sure', 9)
# 222 (u'explains', 9)
# 223 (u'Oakland', 9)
# 224 (u'whether', 9)
# 225 (u'here', 8)
# 226 (u'tech', 8)
# 227 (u'things', 8)
# 228 (u'million', 8)
# 229 (u'How', 8)
# 230 (u'it,', 8)
# 231 (u'latest', 8)
# 232 (u'fascinating', 8)
# 233 (u'interview', 8)
# 234 (u'another', 8)
# 235 (u'Just', 8)
# 236 (u'change', 8)
# 237 (u'still', 8)
# 238 (u'wonderful', 8)
# 239 (u'An', 8)
# 240 (u"you're", 8)
# 241 (u'policy', 8)
# 242 (u'before', 8)
# 243 (u'thing', 8)
# 244 (u'done', 8)
# 245 (u'build', 8)
# 246 (u'point', 8)
# 247 (u'Here', 8)
# 248 (u'free', 8)
# 249 (u'took', 8)
# 250 (u'learn', 8)
# 251 (u'ideas', 8)
# 252 (u'kind', 8)
# 253 (u'political', 8)
# 254 (u'made', 8)
# 255 (u'Summit', 7)
# 256 (u'easy', 7)
# 257 (u'role', 7)
# 258 (u'team', 7)
# 259 (u'years', 7)
# 260 (u'say', 7)
# 261 (u'available', 7)
# 262 (u'healthcare.gov', 7)
# 263 (u'next', 7)
# 264 (u'San', 7)
# 265 (u'books', 7)
# 266 (u'labor', 7)
# 267 (u'less', 7)
# 268 (u'software', 7)
# 269 (u'away', 7)
# 270 (u'live', 7)
# 271 (u'Valley', 7)
# 272 (u'start', 7)
# 273 (u'building', 7)
# 274 (u"I'd", 7)
# 275 (u'actually', 7)
# 276 (u'used', 7)
# 277 (u'economic', 7)
# 278 (u'based', 7)
# 279 (u'she', 7)
# 280 (u'human', 7)
# 281 (u'run', 7)
# 282 (u'living', 7)
# 283 (u'reading', 7)
# 284 (u'New', 7)
# 285 (u'search', 7)
# 286 (u'American', 7)
# 287 (u'hard', 7)
# 288 (u'Libby', 7)
# 289 (u'understand', 7)
# 290 (u'work.', 7)
# 291 (u'every', 7)
# 292 (u'end', 7)
# 293 (u'got', 7)
# 294 (u'already', 7)
# 295 (u'news', 7)
# 296 (u'someone', 7)
# 297 (u'wrote', 7)
# 298 (u'workers', 7)
# 299 (u'few', 7)
# 300 (u'whole', 7)
# 301 (u'getting', 7)
# 302 (u'wrong', 6)
# 303 (u"today's", 6)
# 304 (u'them,', 6)
# 305 (u'country', 6)
# 306 (u'corporate', 6)
# 307 (u'offer', 6)
# 308 (u'current', 6)
# 309 (u'city', 6)
# 310 (u'jobs', 6)
# 311 (u'around', 6)
# 312 (u'found', 6)
# 313 (u'For', 6)
# 314 (u'couple', 6)
# 315 (u'try', 6)
# 316 (u'One', 6)
# 317 (u'off', 6)
# 318 (u'told', 6)
# 319 (u'towards', 6)
# 320 (u'space', 6)
# 321 (u'There', 6)
# 322 (u'ways', 6)
# 323 (u'Pahlka', 6)
# 324 (u'(and', 6)
# 325 (u'trying', 6)
# 326 (u'go', 6)
# 327 (u'Now', 6)
# 328 (u'completely', 6)
# 329 (u'You', 6)
# 330 (u'education', 6)
# 331 (u'ever', 6)
# 332 (u'data,', 6)
# 333 (u'thoughts', 6)
# 334 (u'must', 6)
# 335 (u'step', 6)
# 336 (u'coming', 6)
# 337 (u'response', 6)
# 338 (u'particularly', 6)
# 339 (u'spent', 6)
# 340 (u'work,', 6)
# 341 (u'top', 6)
# 342 (u'approach', 6)
# 343 (u'teachers', 6)
# 344 (u'check', 6)
# 345 (u'focus', 6)
# 346 (u'White', 6)
# 347 (u'state', 6)
# 348 (u'model', 6)
# 349 (u'United', 6)
# 350 (u'might', 6)
# 351 (u"doesn't", 6)
# 352 (u'"The', 5)
# 353 (u'fix', 5)
# 354 (u'financial', 5)
# 355 (u'life', 5)
# 356 (u'old', 5)
# 357 (u'support', 5)
# 358 (u'such', 5)
# 359 (u'vote', 5)
# 360 (u'outside', 5)
# 361 (u'via', 5)
# 362 (u'research', 5)
# 363 (u'impact', 5)
# 364 (u'recent', 5)
# 365 (u'essay', 5)
# 366 (u'results', 5)
# 367 (u'send', 5)
# 368 (u'that,', 5)
# 369 (u'Apple', 5)
# 370 (u'regulatory', 5)
# 371 (u'system', 5)
# 372 (u'bring', 5)
# 373 (u'it\u2019s', 5)
# 374 (u'site', 5)
# 375 (u'become', 5)
# 376 (u'after', 5)
# 377 (u'runs', 5)
# 378 (u'Make', 5)
# 379 (u'hope', 5)
# 380 (u'market', 5)
# 381 (u'economy', 5)
# 382 (u'year', 5)
# 383 (u'friend', 5)
# 384 (u'truly', 5)
# 385 (u'rules', 5)
# 386 (u'using', 5)
# 387 (u'you.', 5)
# 388 (u'learned', 5)
# 389 (u'history', 5)
# 390 (u'years,', 5)
# 391 (u'California', 5)
# 392 (u'game', 5)
# 393 (u'similar', 5)
# 394 (u'focused', 5)
# 395 (u'group', 5)
# 396 (u'well', 5)
# 397 (u'"We', 5)
# 398 (u'cells', 5)
# 399 (u'tell', 5)
# 400 (u'went', 5)
# 401 (u'seen', 5)
# 402 (u"there's", 5)
# 403 (u'three', 5)
# 404 (u'programs', 5)
# 405 (u'Roberts', 5)
# 406 (u'digital', 5)
# 407 (u'Bill', 5)
# 408 (u'here:', 5)
# 409 (u'When', 5)
# 410 (u'interesting', 5)
# 411 (u'running', 5)
# 412 (u'students', 5)
# 413 (u'children', 5)
# 414 (u'hour', 5)
# 415 (u'Bay', 5)
# 416 (u'everyone', 5)
# 417 (u'built', 5)
# 418 (u'Common', 5)
# 419 (u'spend', 5)
# 420 (u'source', 5)
# 421 (u'back', 5)
# 422 (u'David', 5)
# 423 (u"I'll", 5)
# 424 (u'math', 5)
# 425 (u'deep', 5)
# 426 (u'phone', 5)
# 427 (u'excellent', 5)
# 428 (u'algorithms', 5)
# 429 (u'each', 5)
# 430 (u'talking', 5)
# 431 (u'though', 5)
# 432 (u'conference', 5)
# 433 (u'cool', 5)
# 434 (u'huge', 5)
# 435 (u'RFP', 5)
# 436 (u'Data', 5)
# 437 (u'without', 5)
# 438 (u'follow', 5)
# 439 (u'short', 5)
# 440 (u'nothing', 5)
# 441 (u'analysis', 5)
# 442 (u'called', 5)
# 443 (u'once', 5)
# 444 (u'Department', 5)
# 445 (u'heard', 5)
# 446 (u'six', 5)
# 447 (u'kinds', 5)
# 448 (u'Future', 5)
# 449 (u'example', 4)
# 450 (u'travel', 4)
# 451 (u'needed', 4)
# 452 (u'project', 4)
# 453 (u'lessons', 4)
# 454 (u'John', 4)
# 455 (u'wish', 4)
# 456 (u'dollars', 4)
# 457 (u'inside', 4)
# 458 (u'proud', 4)
# 459 (u'understanding', 4)
# 460 (u'along', 4)
# 461 (u'brilliant', 4)
# 462 (u'training', 4)
# 463 (u'federal', 4)
# 464 (u'line', 4)
# 465 (u'That', 4)
# 466 (u'wants', 4)
# 467 (u'policies', 4)
# 468 (u'buying', 4)
# 469 (u'behavioral', 4)
# 470 (u'small', 4)
# 471 (u'hours', 4)
# 472 (u'social', 4)
# 473 (u'Mikey', 4)
# 474 (u'science', 4)
# 475 (u'fundamental', 4)
# 476 (u'Michael', 4)
# 477 (u'failed', 4)
# 478 (u'politics,', 4)
# 479 (u'tools', 4)
# 480 (u'society', 4)
# 481 (u'stuff', 4)
# 482 (u'Alexa', 4)
# 483 (u'Jen', 4)
# 484 (u'provide', 4)
# 485 (u'economy,', 4)
# 486 (u'bank', 4)
# 487 (u'quoted', 4)
# 488 (u'together', 4)
# 489 (u'teacher', 4)
# 490 (u'calling', 4)
# 491 (u'card', 4)
# 492 (u'care', 4)
# 493 (u'Medium.', 4)
# 494 (u'comes', 4)
# 495 (u'learning', 4)
# 496 (u'media', 4)
# 497 (u'Government', 4)
# 498 (u'+Jennifer', 4)
# 499 (u'family', 4)
# 500 (u'ask', 4)
# 501 (u'takes', 4)
# 502 (u'since', 4)
# 503 (u'reason', 4)
# 504 (u'both', 4)
# 505 (u'showing', 4)
# 506 (u'regulation,', 4)
# 507 (u'politicians', 4)
# 508 (u'commercial', 4)
# 509 (u'Why', 4)
# 510 (u'powerful', 4)
# 511 (u'management', 4)
# 512 (u'man', 4)
# 513 (u'below.', 4)
# 514 (u'written', 4)
# 515 (u'problem', 4)
# 516 (u'speaker', 4)
# 517 (u'home', 4)
# 518 (u'UK', 4)
# 519 (u'stories', 4)
# 520 (u'rescue', 4)
# 521 (u"aren't", 4)
# 522 (u'weeks', 4)
# 523 (u'starts', 4)
# 524 (u'basic', 4)
# 525 (u'deeper', 4)
# 526 (u'opportunity', 4)
# 527 (u'form', 4)
# 528 (u'failure', 4)
# 529 (u'happening', 4)
# 530 (u'government,', 4)
# 531 (u'21st', 4)
# 532 (u"Here's", 4)
# 533 (u'wallet', 4)
# 534 (u'designed', 4)
# 535 (u'10', 4)
# 536 (u'nearly', 4)
# 537 (u'behind', 4)
# 538 (u'I\u2019m', 4)
# 539 (u'different', 4)
# 540 (u'speech', 4)
# 541 (u'movement', 4)
# 542 (u'Core', 4)
# 543 (u'share', 4)
# 544 (u'needs', 4)
# 545 (u'more,', 4)
# 546 (u'energy', 4)
# 547 (u'least', 4)
# 548 (u'believe', 4)
# 549 (u'supposed', 4)
# 550 (u'moment', 4)
# 551 (u'shape', 4)
# 552 (u'wage', 4)
# 553 (u'contacts', 4)
# 554 (u'goods', 4)
# 555 (u'single', 4)
# 556 (u'explaining', 4)
# 557 (u'entire', 4)
# 558 (u'giving', 4)
# 559 (u'line.', 4)
# 560 (u'From', 4)
# 561 (u'them.\ufeff', 4)
# 562 (u'attend', 4)
# 886 (u'conversational', 2)
# 887 (u'reports', 2)
# 888 (u'brought', 2)
# 889 (u'Basic', 2)
# 890 (u'until', 2)
# 891 (u'successful', 2)
# 892 (u'hurt', 2)
# 893 (u'90', 2)
# 894 (u'easier', 2)
# 895 (u'schools', 2)
# 896 (u'for-profit', 2)
# 897 (u'University', 2)
# 898 (u'Work', 2)
# 899 (u'Please', 2)
# 900 (u'170', 2)
# 901 (u'master', 2)
# 902 (u'sure,', 2)
# 903 (u'Beautiful', 2)
# 904 (u'blossom.', 2)
# 905 (u'unintended', 2)
# 906 (u'policies.', 2)
# 907 (u'episode', 2)
# 908 (u'them.', 2)
# 909 (u'result', 2)
# 910 (u'Rise', 2)
# 911 (u'nature', 2)
# 912 (u'carbon', 2)
# 913 (u'Capital', 2)
# 914 (u'fairly', 2)
# 915 (u'thing.', 2)
# 916 (u'+Mikey', 2)
# 917 (u'possible', 2)
# 918 (u'System', 2)
# 919 (u'citizens', 2)
# 920 (u'raised', 2)
# 921 (u'happy', 2)
# 922 (u'passenger', 2)
# 923 (u'model,', 2)
# 924 (u'workers,', 2)
# 925 (u'microbes', 2)
# 926 (u'below.\ufeff', 2)
# 927 (u'choice', 2)
# 928 (u'minute', 2)
# 929 (u'Francis', 2)
# 930 (u'wood', 2)
# 931 (u'opposed', 2)
# 932 (u'following', 2)
# 933 (u'Our', 2)
# 934 (u'educational', 2)
# 935 (u'allowed', 2)
# 936 (u'optimal', 2)
# 937 (u'improving', 2)
# 938 (u'record,', 2)
# 939 (u'year.', 2)
# 940 (u'internet', 2)
# 941 (u'quite', 2)
# 942 (u'+Paul', 2)
# 943 (u'spoken', 2)
# 944 (u'@OReillyMedia', 2)
# 945 (u'draft', 2)
# 946 (u'on.', 2)
# 947 (u'turned', 2)
# 948 (u'saw', 2)
# 949 (u'drive', 2)
# 950 (u'prime', 2)
# 951 (u'customer\u2019s', 2)
# 952 (u"can't", 2)
# 953 (u'internet,', 2)
# 954 (u'Eisen', 2)
# 955 (u'Instead,', 2)
# 956 (u'Brandon', 2)
# 957 (u'industry', 2)
# 958 (u'act', 2)
# 959 (u'image', 2)
# 960 (u'complete', 2)
# 961 (u'principles', 2)
# 962 (u'certain', 2)
# 963 (u'vendors', 2)
# 964 (u"city's", 2)
# 965 (u'welfare', 2)
# 966 (u'online.', 2)
# 967 (u'Conference', 2)
# 968 (u'information', 2)
# 969 (u'plans', 2)
# 970 (u'plane', 2)
# 971 (u'paper', 2)
# 972 (u'URL', 2)
# 973 (u'great,', 2)
# 974 (u'Thanks', 2)
# 975 (u'measurement', 2)
# 976 (u'Historical', 2)
# 977 (u'major', 2)
# 978 (u'number', 2)
# 979 (u'essays', 2)
# 980 (u'relationship', 2)
# 981 (u'indie.vc', 2)
# 982 (u'sell', 2)
# 983 (u'sometimes', 2)
# 984 (u'expressed', 2)
# 985 (u'pickup', 2)
# 986 (u'subject', 2)
# 987 (u'interface', 2)
# 988 (u'publishing', 2)
# 989 (u'Trail', 2)
# 990 (u'Algorithmic', 2)
# 991 (u'On', 2)
# 992 (u'Of', 2)
# 993 (u'Andy', 2)
# 994 (u'computational', 2)
# 995 (u'elsewhere', 2)
# 996 (u'link', 2)
# 997 (u'Jeff', 2)
# 998 (u'defines', 2)
# 999 (u'codes', 2)
# 1000 (u'code', 2)
# 1001 (u'concerned', 2)
# 1002 (u'young', 2)
# 1003 (u'magic', 2)
# 1004 (u'experiencing', 2)
# 1005 (u'Alan', 2)
# 1006 (u'led', 2)
# 1007 (u'poverty', 2)
# 1008 (u'engage', 2)
# 1009 (u'Library', 2)
# 1010 (u'high', 2)
# 1011 (u'stand', 2)
# 1012 (u'Ryan', 2)
# 1013 (u'Uber', 2)
# 1014 (u'important!', 2)
# 1015 (u'2016', 2)
# 1016 (u'Very', 2)
# 1017 (u'unprepared', 2)
# 1018 (u'Review', 2)
# 1019 (u'owned', 2)
# 1020 (u'partnership', 2)
# 1021 (u'segment', 2)
# 1022 (u'painting', 2)
# 1023 (u'Thursday.', 2)
# 1024 (u'edition', 2)
# 1025 (u'end,', 2)
# 1026 (u'end.', 2)
# 1027 (u'figured', 2)
# 1028 (u'Get', 2)
# 1029 (u'terrorism', 2)
# 1030 (u'command', 2)
# 1031 (u'moments', 2)
# 1032 (u'web', 2)
# 1033 (u'five', 2)
# 1034 (u'(rather', 2)
# 1035 (u'lifestyle', 2)
# 1036 (u'Wallace', 2)
# 1037 (u'place.', 2)
# 1038 (u'delivery', 2)
# 1039 (u'wife', 2)
# 1040 (u'again!', 2)
# 1041 (u'rule', 2)
# 1042 (u'NYT', 2)
# 1043 (u'voter', 2)
# 1044 (u'hilarious', 2)
# 1045 (u'machines', 2)
# 1046 (u'daughter', 2)
# 1047 (u'employees', 2)
# 1048 (u"world's", 2)
# 1049 (u'speakers,', 2)
# 1050 (u'Dylan', 2)
# 1051 (u'innovative', 2)
# 1052 (u'tomorrow,', 2)
# 1053 (u"What's", 2)
# 1054 (u'logo', 2)
# 1055 (u"people's", 2)
# 1056 (u'Palestinian', 2)
# 1057 (u'name', 2)
# 1058 (u'wasted', 2)
# 1059 (u'hike', 2)
# 1060 (u'notion', 2)
# 1061 (u'received', 2)
# 1062 (u'climate', 2)
# 1063 (u'[link]', 2)
# 1064 (u'(including', 2)
# 1065 (u'speak', 2)
# 1066 (u'Hillary', 2)
# 1067 (u'families', 2)
# 1068 (u'voice', 2)
# 1069 (u'independent', 2)
# 1070 (u'quotes', 2)
# 1071 (u'spread', 2)
# 1072 (u'designers', 2)
# 1073 (u'night', 2)
# 1074 (u'security', 2)
# 1075 (u'born', 2)
# 1076 (u'asking', 2)
# 1077 (u'Let', 2)
# 1078 (u'sunrise\ufeff', 2)
# 1079 (u'delighted', 2)
# 1080 (u'inequality.', 2)
# 1081 (u'evidence', 2)
# 1082 (u'topped', 2)
# 1083 (u'reality', 2)
# 1084 (u'test', 2)
# 1085 (u'brothers', 2)
# 1086 (u'Tech', 2)
# 1087 (u'Parker', 2)
# 1088 (u'revolution', 2)
# 1089 (u'discover', 2)
# 1090 (u'cost', 2)
# 1091 (u'usually', 2)
# 1092 (u'hiking', 2)
# 1093 (u'car', 2)
# 1094 (u"didn't", 2)
# 1095 (u'topic', 2)
# 1096 (u'ended', 2)
# 1097 (u'Yuval', 2)
# 1098 (u'forms', 2)
# 1099 (u'introduce', 2)
# 1100 (u'fired', 2)
# 1101 (u'Even', 2)
# 1102 (u'investors', 2)
# 1103 (u'Democrats', 2)
# 1104 (u'begin', 2)
# 1105 (u'Janeway', 2)
# 1106 (u'keynote', 2)
# 1107 (u'elected', 2)
# 1108 (u'fascinated', 2)
# 1109 (u'cares', 2)
# 1110 (u'care,', 2)
# 1111 (u'attributed', 2)
# 1112 (u'document', 2)
# 1113 (u'charges', 2)
# 1114 (u'AI,', 2)
# 1115 (u'struck', 2)
# 1116 (u'Mark', 2)
# 1117 (u'conservative', 2)
# 1118 (u'central', 2)
# 1119 (u'Congrats', 2)
# 1120 (u'prepare', 2)
# 1121 (u'fraud', 2)
# 1122 (u'Great', 2)
# 1123 (u'month', 2)
# 1124 (u'thoughtful', 2)
# 1125 (u'darkness', 2)
# 1126 (u'@pahlkadot', 2)
# 1127 (u'amount', 2)
# 1128 (u'goals.', 2)
# 1129 (u'banks', 2)
# 1130 (u'governments', 2)
# 1131 (u'terrible', 2)
# 1132 (u'minutes,', 2)
# 1133 (u'dug', 2)
# 1134 (u'hundred', 2)
# 1135 (u'+Bryce', 2)
# 1136 (u'grew', 2)
# 1137 (u'vision,', 2)
# 1138 (u'\u201cCopyright', 2)
# 1139 (u'experienced', 2)
# 1140 (u'flight.', 2)
# 1141 (u'hype', 2)
# 1142 (u'ISPs', 2)
# 1143 (u'Park', 2)
# 1144 (u'Part', 2)
# 1145 (u'Steve', 2)
# 1146 (u'Graham', 2)
# 1147 (u'mission', 2)
# 1148 (u'Most', 2)
# 1149 (u'describes', 2)
# 1150 (u'else', 2)
# 1151 (u'disruptive', 2)
# 1152 (u'ought', 2)
# 1153 (u'agile,', 2)
# 1154 (u'checking', 2)
# 1155 (u'read,', 2)
# 1156 (u'user', 2)
# 1157 (u'Berkeley', 2)
# 1158 (u'describing', 2)
# 1159 (u'Nassau,', 2)
# 1160 (u'society.\u201d', 2)
# 1161 (u'TV', 2)
# 1162 (u'AI', 2)
# 1163 (u'telling', 2)
# 1164 (u'more.', 2)
# 1165 (u'Pope', 2)
# 1166 (u'click', 2)
# 1167 (u'Bricin', 2)
# 1168 (u'manage', 2)
# 1169 (u'started', 2)
# 1170 (u'+Code', 2)
# 1171 (u'interfaces,', 2)
# 1172 (u'Lovely', 2)
# 1173 (u'12-13', 2)
# 1174 (u'While', 2)
# 1175 (u'happen.', 2)
# 1176 (u'Interior', 2)
# 1177 (u'Times.', 2)
# 1178 (u'special', 2)
# 1179 (u'"In', 2)
# 1180 (u'time,', 2)
# 1181 (u'precisely', 2)
# 1182 (u'be,', 2)
# 1183 (u'+Liza', 2)
# 1184 (u'Wow.', 2)
# 1185 (u'partners', 2)
# 1186 (u'fuel', 2)
# 1187 (u'officials', 2)
# 1188 (u'mind.', 2)
# 1189 (u'tens', 2)
# 1190 (u'(though', 2)
# 1191 (u'importance', 2)
# 1192 (u'sense,', 2)
# 1193 (u'slowly', 2)
# 1194 (u"That's", 2)
# 1195 (u'parts', 2)
# 1196 (u'homework', 2)
# 1197 (u'refugees', 2)
# 1198 (u'page', 2)
# 1199 (u'inaccurate', 2)
# 1200 (u'Up', 2)
# 1201 (u'UN', 2)
# 1202 (u'equally', 2)
# 1203 (u'times,', 2)
# 1204 (u'highest', 2)
# 1205 (u'small,', 2)
# 1206 (u'+Jon', 2)
# 1207 (u'better,', 2)
# 1208 (u'protest', 2)
# 1209 (u'whose', 2)
# 1210 (u'connects', 2)
# 1211 (u'reforms', 2)
# 1212 (u'affect', 2)
# 1213 (u'skills', 2)
# 1214 (u'solution', 2)
# 1215 (u'force', 2)
# 1216 (u'likely', 2)
# 1217 (u'active', 2)
# 1218 (u"Nick's", 2)
# 1219 (u'credit', 2)
# 1220 (u'complicated', 2)
# 1221 (u'have-nots', 2)
# 1222 (u'war,', 2)
# 1223 (u'army', 2)
# 1224 (u'governing,', 2)
# 1225 (u'disruption', 2)
# 1226 (u'room', 2)
# 1227 (u'programming', 2)
# 1228 (u'All', 2)
# 1229 (u'deck', 2)
# 1230 (u',', 2)
# 1231 (u'week,', 2)
# 1232 (u'content', 2)
# 1233 (u'Planet', 2)
# 1234 (u'persuade', 2)
# 1235 (u'mind', 2)
# 1236 (u'seem', 2)
# 1237 (u'day.\ufeff', 2)
# 1238 (u'ending', 2)
# 1239 (u'practices.', 2)
# 1240 (u'stop', 2)
# 1241 (u'bad', 2)
# 1242 (u'architecture', 2)
# 1243 (u'against', 2)
# 1244 (u'distinction', 2)
# 1245 (u'Syrian', 2)
# 1246 (u'now,', 2)
# 1247 (u'now.', 2)
# 1248 (u'website', 2)
# 1249 (u'Enforce', 2)
# 1250 (u'over.', 2)
# 1251 (u'President', 2)
# 1252 (u'failing', 2)
# 1253 (u'News', 2)
# 1254 (u'ago,', 2)
# 1255 (u'ARPA-E', 2)
# 1256 (u'deal', 2)
# 1257 (u'dead', 2)
# 1258 (u'subscription.', 2)
# 1259 (u'super', 2)
# 1260 (u'participation.', 2)
# 1261 (u'education,', 2)
# 1262 (u'initial', 2)
# 1263 (u'NBC', 2)
# 1264 (u'idealized', 2)
# 1265 (u'covers', 2)
# 1266 (u'sale', 2)
# 1267 (u'generally', 2)
# 1268 (u'Andrew', 2)
# 1269 (u'fell', 2)
# 1270 (u'Bakery,', 2)
# 1271 (u'transfers', 2)
# 1272 (u'profits', 2)
# 1273 (u'die', 2)
# 1274 (u'conversation.\ufeff', 2)
# 1275 (u'here.', 2)
# 1276 (u'Technology', 2)
# 1277 (u'Summit.', 2)
# 1278 (u'Kurdistan', 2)
# 1279 (u'till', 2)
# 1280 (u'police', 2)
# 1281 (u'WTF', 2)
# 1282 (u'mail', 2)
# 1283 (u'lunch', 2)
# 1284 (u'Giancarlo', 2)
# 1285 (u'summary', 2)
# 1286 (u'Maureen', 2)
# 1287 (u'fast', 2)
# 1288 (u'Amazon.', 2)
# 1289 (u'eyes', 2)
# 1290 (u'in.\ufeff', 2)
# 1291 (u"here's", 2)
# 1292 (u"Oakland's", 2)
# 1293 (u'theatre', 2)
# 1294 (u'shot', 2)
# 1295 (u'Barre', 2)
# 1296 (u'Right', 2)
# 1297 (u'morning', 2)
# 1298 (u'wonder', 2)
# 1299 (u'across', 2)
# 1300 (u'infrastructure', 2)
# 1301 (u'tacit', 2)
# 1302 (u'Each', 2)
# 1303 (u'among', 2)
# 1304 (u'unusual', 2)
# 1305 (u'innovation.', 2)
# 1306 (u'margin', 2)
# 1307 (u'(who', 2)
# 1308 (u'pile', 2)
# 1309 (u'images', 2)
# 1310 (u'broken', 2)
# 1311 (u'morning.', 2)
# 1312 (u'Obama', 2)
# 1313 (u'Society', 2)
# 1314 (u'videos', 2)
# 1315 (u"Reid's", 2)
# 1316 (u'field', 2)
# 1317 (u'itself.', 2)
# 1318 (u'starting', 2)
# 1319 (u'dollar', 2)
# 1320 (u'cooperative', 2)
# 1321 (u'Walmart,', 2)
# 1322 (u'own.', 2)
# 1323 (u'airport', 2)
# 1324 (u'published', 2)
# 1325 (u'America,', 2)
# 1326 (u'achieving', 2)
# 1327 (u'particular', 2)
# 1328 (u'responsibility', 2)
# 1329 (u'funding', 2)
# 1330 (u'benefits', 2)
# 1331 (u'smaller', 2)
# 1332 (u'mountain', 2)
# 1333 (u'costs', 2)
# 1334 (u'extremely', 2)
# 1335 (u'reflections', 2)
# 1336 (u'fine', 2)
# 1337 (u'common', 2)
# 1338 (u'forthcoming', 2)
# 1339 (u'restaurant', 2)
# 1340 (u'foreign', 2)
# 1341 (u'simply', 2)
# 1342 (u'raise', 2)
# 1343 (u'gap', 2)
# 1344 (u'Francisco.', 2)
# 1345 (u'NBA,', 2)
# 1346 (u'purpose', 2)
# 1347 (u'matter,', 2)
# 1348 (u'extremist', 2)
# 1349 (u'example,', 2)
# 1350 (u'Bob', 2)
# 1351 (u'framed', 2)
# 1352 (u'Excellent', 2)
# 1353 (u'forward', 2)
# 1354 (u'exploration', 2)
# 1355 (u'Student', 2)
# 1356 (u'work.\ufeff', 2)
# 1357 (u'overlooking', 2)
# 1358 (u'helps', 2)
# 1359 (u'markets.', 2)
# 1360 (u'Griffith', 2)
# 1361 (u'access', 2)
# 1362 (u'body', 2)
# 1363 (u'others', 2)
# 1364 (u'honor', 2)
# 1365 (u'\u2026', 2)
# 1366 (u'$1,000', 2)
# 1367 (u'upcoming', 2)
# 1368 (u'train', 2)
# 1369 (u'subscription', 2)
# 1370 (u'obvious', 2)
# 1371 (u'says.', 2)
# 1372 (u'profile', 2)
# 1373 (u'ABC', 2)
# 1374 (u'collection', 2)
# 1375 (u'lines', 2)
# 1376 (u'"illegal', 2)
# 1377 (u'greater', 2)
# 1378 (u'Universal', 2)
# 1379 (u'apparently', 2)
# 1380 (u'Without', 2)
# 1381 (u'\u2013', 2)
# 1382 (u'freely', 2)
# 1383 (u'taking', 2)
# 1384 (u'relevant', 2)
# 1385 (u'article,', 2)
# 1386 (u'helped', 2)
# 1387 (u'productivity', 2)
# 1388 (u"James'", 2)
# 1389 (u'Ride', 2)
# 1390 (u'articles', 2)
# 1391 (u'haves', 2)
# 1392 (u'profound', 2)
# 1393 (u'works', 2)
# 1394 (u'proper', 2)
# 1395 (u'happens', 2)
# 1396 (u'Oakland.', 2)
# 1397 (u'intimations', 2)
# 1398 (u'introduced', 2)
# 1399 (u'Mayor', 2)
# 1400 (u'Two', 2)
# 1401 (u'reading.\ufeff', 2)
# 1402 (u'Wall', 2)
# 1403 (u'ecosystem', 2)
# 1404 (u'proceeds', 2)
# 1405 (u'Howtoons', 2)
# 1406 (u'direct', 2)
# 1407 (u'fabulous', 2)
# 1408 (u'hundreds', 2)
# 1409 (u'changed', 2)
# 1410 (u'House,', 2)
# 1411 (u'ultimate', 2)
# 1412 (u'history,', 2)
# 1413 (u'history.', 2)
# 1414 (u'Noah', 2)
# 1415 (u'driving', 2)
# 1416 (u'day.', 2)
# 1417 (u'wanted', 2)
# 1418 (u'too,', 2)
# 1419 (u'Search', 2)
# 1420 (u'States,', 2)
# 1421 (u'earth', 2)
# 1422 (u'Valley.', 2)
# 1423 (u'companies,', 2)
# 1424 (u'watch', 2)
# 1425 (u'despite', 2)
# 1426 (u'adding', 2)
# 1427 (u'money."', 2)
# 1428 (u'technological', 2)
# 1429 (u'judge', 2)
# 1430 (u'50', 2)
# 1431 (u'offices', 2)
# 1432 (u'election', 2)
# 1433 (u'Chris', 2)
# 1434 (u'algorithmic', 2)
# 1435 (u'dinner', 2)
# 1436 (u'civic', 2)
# 1437 (u'civil', 2)
# 1438 (u'difference,', 2)
# 1439 (u'Sunday.', 2)
# 1440 (u'transform', 2)
# 1441 (u'Congratulations', 2)
# 1442 (u'tech,', 2)
# 1443 (u'post:', 2)
# 1444 (u'advantage', 2)
# 1445 (u'posts', 2)
# 1446 (u'quick', 2)
# 1447 (u'trend', 2)
# 1448 (u'Crimes', 2)
# 1449 (u'today', 2)
# 1450 (u'local', 2)
# 1451 (u'figure', 2)
# 1452 (u'newsletter,', 2)
# 1453 (u'comfort', 2)
# 1454 (u'dollars.', 2)
# 1455 (u'offers', 2)
# 1456 (u'conversations', 2)
# 1457 (u'term', 2)
# 1458 (u'That\u2019s', 2)
# 1459 (u'sunrise', 2)
# 1460 (u"shouldn't", 2)
# 1461 (u'Sign', 2)
# 1462 (u'place', 2)
# 1463 (u'Welfare', 2)
# 1464 (u'million,', 2)
# 1465 (u'copy', 2)
# 1466 (u'wide', 2)
# 1467 (u'require', 2)
# 1468 (u'visitors', 2)
# 1469 (u'+Mike', 2)
# 1470 (u'explicitly', 2)
# 1471 (u'managing', 2)
# 1472 (u'way.', 2)
# 1473 (u"We've", 2)
# 1474 (u'Really?', 2)
# 1475 (u'case', 2)
# 1476 (u'cast', 2)
# 1477 (u'Open', 2)
# 1478 (u'person.', 2)
# 1479 (u'author', 2)
# 1480 (u'week', 2)
# 1481 (u'IT', 2)
# 1482 (u'changing', 2)
# 1483 (u'possible.', 2)
# 1484 (u"we've", 2)
# 1485 (u'possible,', 2)
# 1486 (u'blog', 2)
# 1487 (u'donations', 2)
# 1488 (u'overheated', 2)
# 1489 (u'legal', 2)
# 1490 (u'provides', 2)
# 1491 (u'welcome', 2)
# 1492 (u'you\u2019ll', 2)
# 1493 (u'rising', 2)
# 1494 (u'treat', 2)
# 1495 (u'promote', 2)
# 1496 (u'diversity', 2)
# 1497 (u'Press:Here', 2)
# 1498 (u'5', 2)
# 1499 (u'separate', 2)
# 1500 (u'Maciej', 2)
# 1501 (u'includes', 2)
# 1502 (u'included', 2)
# 1503 (u'calls', 2)
# 1504 (u'websites', 2)
# 1505 (u'lack', 2)
# 1506 (u'remarkable', 2)
# 1507 (u'song', 2)
# 1508 (u'bubbles', 2)
# 1509 (u'list', 2)
# 1510 (u'direction.', 2)
# 1511 (u'rate', 2)
# 1512 (u"Trump's", 2)
# 1513 (u'tragedy', 2)
# 1514 (u'Absolutely', 2)
# 1515 (u'permanently', 2)
# 1516 (u'goal', 2)
# 1517 (u'jugyokenkyu,', 2)
# 1518 (u'Sean', 2)
# 1519 (u'(See', 2)
# 1520 (u'party', 2)
# 1521 (u'communities', 2)
# 1522 (u'level', 2)
# 1523 (u'generation', 2)
# 1524 (u'health', 2)
# 1525 (u'Bryce', 2)
# 1526 (u'People', 2)
# 1527 (u'interviews', 2)
# 1528 (u'from.', 2)
# 1529 (u'traditional', 2)
# 1530 (u'night,', 2)
# 1531 (u'bottom,', 2)
# 1532 (u'Bluetooth', 2)
# 1533 (u'achieved', 2)
# 1534 (u'recently', 2)
# 1535 (u'creating', 2)
# 1536 (u'attention', 2)
# 1537 (u"Google's", 2)
# 1538 (u'competent', 2)
# 1539 (u'context', 2)
# 1540 (u'regulated', 2)
# 1541 (u'there.', 2)
# 1542 (u'demand', 2)
# 1543 (u'disappointing', 2)
# 1544 (u'rid', 2)
# 1545 (u'9', 2)
# 1546 (u'higher', 2)
# 1547 (u'hotels,', 2)
# 1548 (u'people,', 2)
# 1549 (u'chickens', 2)
# 1550 (u'worker,', 2)
# 1551 (u'innovation', 2)
# 1552 (u'payments', 2)
# 1553 (u'Times', 2)
# 1554 (u'entrepreneurs', 2)
# 1555 (u'impressed', 2)
# 1556 (u'question', 2)
# 1557 (u"we're", 2)
# 1558 (u'Amazon,', 2)
# 1559 (u'analyze', 2)
# 1560 (u'problem.', 2)
# 1561 (u'problem,', 2)
# 1562 (u'nice', 2)
# 1563 (u'users', 2)
# 1564 (u'helping', 2)
# 1565 (u'crisis.', 2)
# 1566 (u'NY', 2)
# 1567 (u'shameful.', 2)
# 1568 (u'waiting', 2)
# 1569 (u'large,', 2)
# 1570 (u'capital', 2)
# 1571 (u'leaving', 2)
# 1572 (u'stream', 2)
# 1573 (u'women', 2)
# 1574 (u'abuse', 2)
# 1575 (u'Oakland.\ufeff', 2)
# 1576 (u'looks', 2)
# 1577 (u'practice', 2)
# 1578 (u'Can', 2)
# 1579 (u'ebooks', 2)
# 1580 (u'autopilot', 2)
# 2034 (u'skied', 1)
# 2035 (u'Advice', 1)
# 2036 (u'(I', 1)
# 2037 (u'Market.', 1)
# 2038 (u'process,', 1)
# 2039 (u'dark', 1)
# 2040 (u'Aunt', 1)
# 2041 (u'sorry.', 1)
# 2042 (u'#FutureCrimesConvo,', 1)
# 2043 (u'satisfaction', 1)
# 2044 (u'Department),', 1)
# 2045 (u'Backchannel', 1)
# 2046 (u'+Allen', 1)
# 2047 (u'museums,', 1)
# 2048 (u'superintendent', 1)
# 2049 (u"couldn't", 1)
# 2050 (u'Uber.', 1)
# 2051 (u'members.', 1)
# 2052 (u'Sloan', 1)
# 2053 (u'Sorkin', 1)
# 2054 (u'scholarships', 1)
# 2055 (u'noon', 1)
# 2056 (u'Projects', 1)
# 2057 (u'think.', 1)
# 2058 (u'think,', 1)
# 2059 (u'scientific', 1)
# 2060 (u'zest', 1)
# 2061 (u'leadership', 1)
# 2062 (u'Alfie', 1)
# 2063 (u'side', 1)
# 2064 (u'wikis', 1)
# 2065 (u'parties', 1)
# 2066 (u'accumulated', 1)
# 2067 (u'event.)', 1)
# 2068 (u'(1)', 1)
# 2069 (u'obvious.', 1)
# 2070 (u'recommends', 1)
# 2071 (u'services,', 1)
# 2072 (u'headset,', 1)
# 2073 (u'services.', 1)
# 2074 (u'economy.This', 1)
# 2075 (u'opens:"Something\u2019s', 1)
# 2076 (u'regimes', 1)
# 2077 (u'detailed', 1)
# 2078 (u'technocratic', 1)
# 2079 (u'Hon', 1)
# 2080 (u'Airlines', 1)
# 2081 (u'claims.', 1)
# 2082 (u'Atlantic', 1)
# 2083 (u'Kurdish', 1)
# 2084 (u'training.\ufeff', 1)
# 2085 (u'vocabulary', 1)
# 2086 (u'annex', 1)
# 2087 (u'walk.', 1)
# 2088 (u'CrownedWith', 1)
# 2089 (u'form.\'"To', 1)
# 2090 (u'Hardware', 1)
# 2091 (u'fraudulent', 1)
# 2092 (u'Street', 1)
# 2093 (u'Cove.Around', 1)
# 2094 (u'"Bro"', 1)
# 2095 (u'9/11', 1)
# 2096 (u'consider', 1)
# 2097 (u'caused', 1)
# 2098 (u'robots,', 1)
# 2099 (u'PAC,', 1)
# 2100 (u'causes', 1)
# 2101 (u'it.5.', 1)
# 2102 (u'hunting', 1)
# 2103 (u'Crimes,', 1)
# 2104 (u'Hedlund', 1)
# 2105 (u'+Steven', 1)
# 2106 (u'debit', 1)
# 2107 (u'surprise', 1)
# 2108 (u'corporations,', 1)
# 2109 (u'illustrated', 1)
# ...
# 5054 (u'Using', 1)
# 5055 (u'hypothesis,', 1)
# 5056 (u'happened', 1)
# 5057 (u'writes:"Paying', 1)
# 5058 (u'\u201cbacktrack', 1)
# 5059 (u'Rome', 1)
# 5060 (u')So', 1)
# 5061 (u':-)\ufeff', 1)
# 5062 (u'ridiculous!', 1)
# 5063 (u'corners', 1)
# 5064 (u'#opendata', 1)
# 5065 (u'realistic', 1)
# 5066 (u'dirty!', 1)
# 5067 (u'offer:', 1)
# 5068 (u'rethinking', 1)
# 5069 (u'mountain.\ufeff', 1)
# 5070 (u'Save', 1)
# 5071 (u'(At', 1)
# 5072 (u"(O'Reilly", 1)
# 5073 (u'factors', 1)
# 5074 (u'collusion...could', 1)
# 5075 (u'working-age', 1)
# 5076 (u'bolts', 1)
# 5077 (u"Kohn's", 1)
# 5078 (u'motion', 1)
# 5079 (u"O'Connor's", 1)
# 5080 (u'revenue', 1)
# 5081 (u'most.\ufeff', 1)
# 5082 (u'world\u2019s', 1)
# 5083 (u'policy."', 1)
# 5084 (u'Torc,', 1)
# 5085 (u'necessarily', 1)
# 5086 (u'card.', 1)
# 5087 (u'W.H.', 1)
# 5088 (u'card"', 1)
# 5089 (u'trillion', 1)
# 5090 (u'pile.Then', 1)
# 5091 (u'SEC', 1)
# 5092 (u'prefers:', 1)
# 5093 (u'circa', 1)
# 5094 (u'Keeping', 1)
# 5095 (u'wrongdoing', 1)
# 5096 (u'work)?', 1)
# 5097 (u'innovators', 1)
# 5098 (u'accused', 1)
# 5099 (u'witty,', 1)
# 5100 (u'outcome', 1)
# 5101 (u'survey.', 1)
# 5102 (u'Fails', 1)
# 5103 (u'year."via', 1)
# 5104 (u'fall,', 1)
# 5105 (u'prosperity', 1)
# 5106 (u'astonishingly', 1)
# 5107 (u'Warmiwanuska', 1)
# 5108 (u'programs.', 1)
# 5109 (u'"poo', 1)
# 5110 (u'ideal', 1)
# 5111 (u'multiple', 1)
# 5112 (u'cleared', 1)
# 5113 (u'science!', 1)
# 5114 (u'sources,', 1)
# 5115 (u'NRA', 1)
# 5116 (u'later', 1)
# 5117 (u'science.', 1)
# 5118 (u'hungry', 1)
# 5119 (u'science,', 1)
# 5120 (u'need,', 1)
# 5121 (u'idea,', 1)
# 5122 (u'entrepreneurs.\ufeff', 1)
# 5123 (u'senior', 1)
# 5124 (u'slope', 1)
# 5125 (u'hustled', 1)
# 5126 (u'Research', 1)
# 5127 (u'Fellowship', 1)
# 5128 (u'Brightest,', 1)
# 5129 (u'media\u201d', 1)
# 5130 (u'Siri,', 1)
# 5131 (u'humans.', 1)
# 5132 (u'(Just', 1)
# 5133 (u'(still', 1)
# 5134 (u'profitability.\u201d\ufeff', 1)
# 5135 (u'space,', 1)
# 5136 (u'space.', 1)
# 5137 (u'hoped,', 1)
# 5138 (u'"how', 1)
# 5139 (u'ignored', 1)
# 5140 (u'"Church', 1)
# 5141 (u'college', 1)
# 5142 (u'apologies', 1)
# 5143 (u'collects', 1)
# 5144 (u'enforcers!', 1)
# 5145 (u'encouraged', 1)
# 5146 (u'surfaces', 1)
# 5147 (u'detect', 1)
# 5148 (u'review', 1)
# 5149 (u'circulating', 1)
# 5150 (u'relief,', 1)
# 5151 (u'Brilliant:', 1)
# 5152 (u'Neocons', 1)
# 5153 (u'collect"', 1)
# 5154 (u'U.S.', 1)
# 5155 (u'@SenatorPhD,', 1)
# 5156 (u'cities', 1)
# 5157 (u'Salih,', 1)
# 5158 (u"@jgrahamc's", 1)
# 5159 (u'activated.That', 1)
# 5160 (u'way,', 1)
# 5161 (u'champion.', 1)
# 5254 (u'culture.', 1)
# 5255 (u'Anything', 1)
# 5256 (u'strongly', 1)
# 5257 (u'bullet"', 1)
# 5258 (u'research:', 1)
# 5259 (u'totaling', 1)
# 5260 (u'words,', 1)
# 5261 (u'climate-risk', 1)
# 5262 (u'recruiters.', 1)
# 5263 (u'odd,', 1)
# 5264 (u'call,', 1)
# 5265 (u'Ross', 1)
# 5266 (u'serious', 1)
# 5267 (u'finals', 1)
# 5268 (u'environment,', 1)
# 5269 (u'invest', 1)
# 5270 (u'wifi', 1)
# 5271 (u'Republican-controlled', 1)
# 5272 (u'Clem', 1)
# 5273 (u'bubble.', 1)
# 5274 (u'meditation', 1)
# 5275 (u'aviators."', 1)
# 5276 (u'everyone,', 1)
# 5277 (u'worse', 1)
# 5278 (u'everyone.', 1)
# 5279 (u'Still,', 1)
# 5280 (u'ten', 1)
# 5281 (u'direction,', 1)
# 5282 (u'design', 1)
# 5283 (u'Next:Money', 1)
# 5284 (u'Worker', 1)
# 5285 (u'anniversary', 1)
# 5286 (u'faltered', 1)
# 5287 (u'version', 1)
# 5288 (u'Spectacular!\ufeff', 1)
# 5289 (u'Short', 1)
# 5290 (u'1:25)\ufeff', 1)
# 5291 (u'combating', 1)
# 5292 (u'Russ', 1)
# 5293 (u'loosely,', 1)
# 5294 (u'allows', 1)
# 5295 (u'horrified', 1)
# 5296 (u'off."', 1)
# 5297 (u'http://www.codeforamerica.org/blog/2015/11/30/a-new-approach-to-procuring-government-technology-in-california/', 1)
# 5298 (u'Stamp', 1)
# 5299 (u'Top', 1)
# 5300 (u'know,', 1)
# 5301 (u'underfunded,', 1)
# 5302 (u'forcefully', 1)
# 5303 (u"Christ's", 1)
# 5304 (u'markets', 1)
# 5305 (u'minor', 1)
# 5306 (u'knows', 1)
# 5307 (u'begin:1.', 1)
# 5308 (u'known', 1)
# 5309 (u'Senate,', 1)
# 5310 (u"shit'", 1)
# 5311 (u'slowly,', 1)
# 5312 (u'Japan\u2019s', 1)
# 5313 (u'co-host', 1)
# 5314 (u'Conference!\ufeff', 1)
# 5315 (u'protective', 1)
# 5316 (u'Next,', 1)
# 5317 (u'influences', 1)
# 5318 (u'event.\ufeff', 1)
# 5319 (u'reflect', 1)
# 5320 (u"pundits'", 1)
# 5321 (u'#OSCON.', 1)
# 5322 (u'explain.', 1)
# 5323 (u'music,', 1)
# 5324 (u'H\xf6lzle,', 1)
# 5325 (u'essence', 1)
# 5326 (u'prisons.\ufeff', 1)
# 5327 (u'March', 1)
# 5328 (u'already,', 1)
# 5329 (u'papacy,', 1)
# 5330 (u'fiasco,', 1)
# 5331 (u'Makers/Exhibitors/Performers,', 1)
# 5332 (u'framework', 1)
# 5333 (u'botnet', 1)
# 5334 (u"Sunday's", 1)
# 5335 (u'inequality', 1)
# 5336 (u'works."The', 1)
# 5337 (u'aligns', 1)
# 5338 (u'everyone"Adjustments', 1)
# 5339 (u'Complex', 1)
# 5340 (u'expect', 1)
# 5341 (u'Passport', 1)
# 5342 (u'More', 1)
# 5343 (u'Boston,', 1)
# 5344 (u'providing,', 1)
# 5345 (u'Lake,', 1)
# 5346 (u'properly,', 1)
# 5347 (u'properly.', 1)
# 5348 (u'Elon', 1)
# 5349 (u'feed', 1)
# 5350 (u'Huge', 1)
# 5351 (u'6.', 1)
# 5352 (u'Indian', 1)
# 5353 (u'recreation,', 1)
# 5354 (u'"', 1)
# 5355 (u'Larry', 1)
# 5356 (u'prescient', 1)
# 5357 (u'passed', 1)
# 5358 (u'store', 1)
# 5359 (u'Companies', 1)
# 5360 (u'"When', 1)
# 5361 (u'from?', 1)
# 5362 (u'$5', 1)
# 5363 (u'nagging', 1)
# 5364 (u'vial', 1)
# 5365 (u'views.', 1)
# 5366 (u'it.\ufeff', 1)
# 5367 (u'risks', 1)
# 5368 (u'interview.', 1)
# 5369 (u'risky', 1)
# 5370 (u'infrastructure,', 1)
# 5371 (u'infrastructure.', 1)
# 5372 (u'hour-long', 1)
# 5373 (u'generals;', 1)
# 5374 (u'me.)', 1)
# 5375 (u'finding', 1)
# 5376 (u'added', 1)
# 5377 (u'vote."', 1)
# 5378 (u'interviewed', 1)
# 5379 (u'wasn\u2019t', 1)
# 5380 (u'shareholder', 1)
# 5381 (u'toldthe', 1)
# 5382 (u'bugaboo', 1)
# 5383 (u'paintings,', 1)
# 5384 (u'coincided', 1)
# 5385 (u'Gilead', 1)
# 5386 (u'meditation,', 1)
# 5387 (u'grotesque', 1)
# 5388 (u'unilaterally', 1)
# 5389 (u'"People', 1)
# 5390 (u'hit', 1)
# 5391 (u'right.\ufeff', 1)
# 5392 (u'Slack.)', 1)
# 5393 (u'school.\ufeff', 1)
# 5394 (u'investigate', 1)
# 5395 (u'sustainable', 1)
# 5396 (u'needle."Very', 1)
# 5397 (u'Networks', 1)
# 5398 (u'art', 1)
# 5399 (u'city,', 1)
# 5400 (u'city!', 1)
# 5401 (u'arm', 1)
# 5402 (u'implementation."', 1)
# 5403 (u'nailed', 1)
# 5404 (u'Music:"I', 1)
# 5405 (u'libraries', 1)
# 5406 (u'unions', 1)
# 5407 (u'Gonzalez!\ufeff', 1)
# 5408 (u'after.', 1)
# 5409 (u'achieve,', 1)
# 5410 (u'days,', 1)
# 5411 (u'AND', 1)
# 5412 (u'became', 1)
# 5413 (u'learn)', 1)
# 5414 (u'learn,', 1)
# 5415 (u'finds', 1)
# 5416 (u'learn.', 1)
# 5417 (u'computers.', 1)
# 5418 (u'regulates', 1)
# 5419 (u'time.\ufeff', 1)
# 5420 (u'CityLab', 1)
# 5421 (u'there,', 1)
# 5422 (u'due', 1)
# 5423 (u'appears', 1)
# 5424 (u'(charisma,', 1)
# 5425 (u'gushes:', 1)
# 5426 (u'Winston', 1)
# 5427 (u'tweaking', 1)
# 5428 (u'kick', 1)
# 5429 (u'parents,', 1)
# 5430 (u'City', 1)
# 5431 (u'flow,', 1)
# 5432 (u'holiday.', 1)
# 5433 (u'obstacle', 1)
# 5434 (u'\u201cBut', 1)
# 5435 (u'provide.\ufeff', 1)
# 5436 (u'future.\ufeff', 1)
# 5527 (u'windy', 1)
# 5528 (u'Bureau', 1)
# 5529 (u'crashing.', 1)
# 5530 (u'super-excited', 1)
# 5531 (u'deal.', 1)
# 5532 (u'crisis,', 1)
# 5533 (u'include', 1)
# 5534 (u'better!\ufeff', 1)
# 5535 (u'Takahashi', 1)
# 5536 (u'issue,', 1)
# 5537 (u'issue.', 1)
# 5538 (u'wishes', 1)
# 5539 (u'bryant', 1)
# 5540 (u'soon.\ufeff', 1)
# 5541 (u'Fundraiser', 1)
# 5542 (u'noted', 1)
# 5543 (u'Revolutions', 1)
# 5544 (u'wrestling', 1)
# 5545 (u'Councilor', 1)
# 5546 (u'traveling', 1)
# 5547 (u'policy.The', 1)
# 5548 (u'Python\u2026', 1)
# 5549 (u'UK.\ufeff', 1)
# 5550 (u'modded', 1)
# 5551 (u'true..."\u201c...and', 1)
# 5552 (u'chose', 1)
# 5553 (u'pushing', 1)
# 5554 (u'entry,', 1)
# 5555 (u'post-truth', 1)
# 5556 (u"'exit", 1)
# 5557 (u'larger', 1)
# 5558 (u'catalyzing', 1)
# 5559 (u'Regulation.', 1)
# 5560 (u'ones.', 1)
# 5561 (u'CBW', 1)
# 5562 (u'Regulation:', 1)
# 5563 (u'humansofnewyork.com', 1)
# 5564 (u'scales', 1)
# 5565 (u'app', 1)
# 5566 (u'apt', 1)
# 5567 (u'consumption', 1)
# 5568 (u'&', 1)
# 5569 (u'"improved"', 1)
# 5570 (u'KQED', 1)
# 5571 (u'hard,', 1)
# 5572 (u'hard!', 1)
# 5573 (u'integration,', 1)
# 5574 (u'1980s', 1)
# 5575 (u'Smart,', 1)
# 5576 (u'us!', 1)
# 5577 (u'proof', 1)
# 5578 (u'Buchheit.\ufeff', 1)
# 5579 (u'tax', 1)
# 5580 (u'assumptions', 1)
# 5581 (u'Blaise', 1)
# 5582 (u'(think', 1)
# 5583 (u'instead', 1)
# 5584 (u'Walter', 1)
# 5585 (u'(ISEA)', 1)
# 5586 (u'tomorrow.\ufeff', 1)
# 5587 (u'light', 1)
# 5588 (u'#making,', 1)
# 5589 (u'this.7.', 1)
# 5590 (u'matter."\ufeff', 1)
# 5591 (u'https://www.producthunt.com/live/tim-o-reilly\ufeff', 1)
# 5592 (u"'science", 1)
# 5593 (u'13,', 1)
# 5594 (u'coworking"', 1)
# 5595 (u'Shell', 1)
# 5596 (u'article:', 1)
# 5597 (u'Thanks,', 1)
# 5598 (u'choose', 1)
# 5599 (u'holiday', 1)
# 5600 (u'powerful:', 1)
# 5601 (u'Tickets', 1)
# 5602 (u'richness', 1)
# 5603 (u'look,', 1)
# 5604 (u'that.P.S.', 1)
# 5605 (u'flee', 1)
# 5606 (u'worlds', 1)
# 5607 (u"night's", 1)
# 5608 (u'edit', 1)
# 5609 (u'ship.', 1)
# 5610 (u'@TPPodcast_', 1)
# 5611 (u'early.\ufeff', 1)
# 5612 (u'related', 1)
# 5613 (u'interplay', 1)
# 5614 (u'integrates', 1)
# 5615 (u'cross-agency', 1)
# 5616 (u'dive', 1)
# 5617 (u'too.\ufeff', 1)
# 5618 (u'support.', 1)
# 5619 (u'country.\ufeff', 1)
# 5620 (u'feasible', 1)
# 5621 (u'conversation', 1)
# 5622 (u'software...."Get', 1)
# 5623 (u'slide,', 1)
# 5624 (u'co-founder', 1)
# 5625 (u'quotes:\u201cA', 1)
# 5626 (u'Vegas', 1)
# 5627 (u'chemotherapy', 1)
# 5628 (u'grades.\ufeff', 1)
# 5629 (u'tidbit', 1)
# 5630 (u'in-progress', 1)
# 5631 (u'Probably', 1)
# 5632 (u'entrepreneurs?"', 1)
# 5633 (u'liberating."\ufeff', 1)
# 5634 (u'Siri', 1)
# 5635 (u'individual', 1)
# 5636 (u'Peter', 1)
# 5637 (u"well.I've", 1)
# 5638 (u'linked', 1)
# 5639 (u'afraid', 1)
# 5640 (u'"collect', 1)
# 5641 (u'McGuire', 1)
# 5642 (u'combat', 1)
# 5643 (u'Loch', 1)
# 5644 (u'Poo', 1)
# 5645 (u'consistency).', 1)
# 5646 (u'healthy.', 1)
# 5647 (u'planning', 1)
# 5648 (u'begun..."Quoted', 1)
# 5649 (u'playbook', 1)
# 5650 (u'chicken', 1)
# 5651 (u'debate', 1)
# 5652 (u'repertoire!\ufeff', 1)
# 5653 (u'candidates', 1)
# 5654 (u'watching', 1)
# 5655 (u'colorful,', 1)
# 5656 (u'ones', 1)
# 5657 (u'interoperability', 1)
# 5658 (u'chance.', 1)
# 5659 (u'words', 1)
# 5660 (u'Gilead:', 1)
# 5661 (u'Area,', 1)
# 5662 (u'brain', 1)
# 5663 (u'Sullivan', 1)
# 5664 (u'modulo', 1)
# 5665 (u'acquired', 1)
# 5666 (u'laundering,', 1)
# 5667 (u'mom,', 1)
# 5668 (u'publisher.', 1)
# 5669 (u'ground,', 1)
# 5670 (u'ground.', 1)
# 5671 (u'focuses', 1)
# 5672 (u'superb', 1)
# 5673 (u'command,', 1)
# 5674 (u'opening', 1)
# 5675 (u'joy', 1)
# 5676 (u'agencies', 1)
# 5677 (u'ideas,', 1)
# 5678 (u'Unfortunately,', 1)
# 5679 (u'Jascha', 1)
# 5680 (u'wall', 1)
# 5681 (u'respect', 1)
# 5682 (u'connection.\ufeff', 1)
# 5683 (u'rich.', 1)
# 5684 (u'Guild', 1)
# 5685 (u'choices', 1)
# 5686 (u'chart,', 1)
# 5687 (u'wild', 1)
# 5688 (u'rename', 1)
# 5689 (u'"What', 1)
# 5690 (u'Hope', 1)
# 5691 (u'State,', 1)
# 5692 (u'unity', 1)
# 5693 (u'largest', 1)
# 5694 (u'units', 1)
# 5695 (u'difficult', 1)
# 5696 (u'this.BTW,', 1)
# 5697 (u'succulent', 1)
# 5698 (u'Todd', 1)
# 5699 (u'disagree', 1)
# 5700 (u'Reid', 1)
# 5701 (u'get.', 1)
# 5702 (u'Muir', 1)
# 5703 (u'(although', 1)
# 5704 (u'Yorkshire', 1)
# 5705 (u'happiness', 1)
# 5706 (u'Matt', 1)
# 5707 (u'fund!\ufeff', 1)
# 5708 (u'arresting', 1)
# 5709 (u'surprised)', 1)
# 5710 (u"who's", 1)
# 5711 (u'#WTFeconomy.', 1)
# 5712 (u'press', 1)
# 5713 (u'redesign', 1)
# 5714 (u'chutzpah', 1)
# 5715 (u"who'd", 1)
# 5716 (u'overwatering', 1)
# 5717 (u'handicapping', 1)
# 5718 (u'taxpayers', 1)
# 5719 (u"Konnikova's", 1)
# 5720 (u'yours.', 1)
# 5721 (u'sequence', 1)
# 5722 (u'searching', 1)
# 5723 (u'growth', 1)
# 5724 (u'110', 1)
# 5725 (u'Jonathan', 1)
# 5726 (u'sake,', 1)
# 5727 (u'backups.', 1)
# 5728 (u'Regulations?Evgeny', 1)
# 5729 (u'leader', 1)
# 5730 (u'platform,', 1)
# 5731 (u"step.\u201c'If", 1)
# 5732 (u'capture",', 1)
# 5733 (u'wouldn\u2019t', 1)
# 5734 (u'awards.', 1)
# 5735 (u'surge', 1)
# 5736 (u'lives.\ufeff', 1)
# 5737 (u'Americans', 1)
# 5738 (u'mine)', 1)
# 5739 (u'publishers.', 1)
# 5740 (u'models.The', 1)
# 5741 (u'registration', 1)
# 5742 (u'Bruner', 1)
# 5743 (u'funds', 1)
# 5744 (u'Detroit', 1)
# 5745 (u'(Part', 1)
# 5746 (u'this!', 1)
# 5747 (u'Michener)quoteinvestigator.com/2010/08/27/master/Thanks', 1)
# 5748 (u'distract', 1)
# 5749 (u'this.', 1)
# 5750 (u'record', 1)
# 5751 (u'demonstrate', 1)
# 5752 (u'inadequate', 1)
# 5753 (u'Vancouver', 1)
# 5754 (u'Geometric', 1)
# 5755 (u'kind,', 1)
# 5756 (u'basketball.A', 1)
# 5757 (u'branch', 1)
# 5758 (u'toured', 1)
# 5759 (u'death."And', 1)
# 5760 (u'conclusion', 1)
# 5761 (u'junk', 1)
# 5762 (u"HONY's", 1)
# 5763 (u'insights,', 1)
# 5764 (u'pacific.', 1)
# 5765 (u'profit', 1)
# 5766 (u'percent?', 1)
# 5767 (u'"Government', 1)
# 5768 (u'representative', 1)

# %% [markdown]
# ## Example 9. Querying Google+ data with TF-IDF

# %%
import json
import nltk

# Load in human language data from wherever you've saved it

DATA = 'resources/ch04-googleplus/107033731246200681024.json'
data = json.loads(open(DATA).read())

# XXX: Provide your own query terms here

QUERY_TERMS = ['OPEN', 'SOURCE']

activities = [activity['object']['content'].lower().split() \
              for activity in data \
                if activity['object']['content'] != ""]

# TextCollection provides tf, idf, and tf_idf abstractions so 
# that we don't have to maintain/compute them ourselves

tc = nltk.TextCollection(activities)

relevant_activities = []

for idx in range(len(activities)):
    score = 0
    for term in [t.lower() for t in QUERY_TERMS]:
        score += tc.tf_idf(term, activities[idx])
    if score > 0:
        relevant_activities.append({'score': score, 'title': data[idx]['title'],
                              'url': data[idx]['url']})

# Sort by score and display results

relevant_activities = sorted(relevant_activities, 
                             key=lambda p: p['score'], reverse=True)
for activity in relevant_activities:
    print activity['title']
    print '\tLink: %s' % (activity['url'], )
    print '\tScore: %s' % (activity['score'], )
    print
# Out:
# This is a really important piece about open data and platforms.
# 	Link: https://plus.google.com/+TimOReilly/posts/fo9uxWTctHb
# 	Score: 0.283046846292
#
# My latest @radar post: #SocialCivics and the architecture of participation. Inspired by @goldman joining...
# 	Link: https://plus.google.com/+TimOReilly/posts/BipFsL8tjmP
# 	Score: 0.135660053835
#
# An excellent demonstration of why Open Access lowers the barriers to knowledge-sharing in science. This...
# 	Link: https://plus.google.com/+TimOReilly/posts/iQ4RdspWxbY
# 	Score: 0.12972980455
#
# Predictive policing has enormous risks of introducing algorithmic bias. As a way of countering that,...
# 	Link: https://plus.google.com/+TimOReilly/posts/TFwW3wgKm2F
# 	Score: 0.0738969754014
#
# I'm doing a ProductHunt AMA at 9 am PT this morning.  I love getting people thinking harder about how...
# 	Link: https://plus.google.com/+TimOReilly/posts/KFxXr6qTEHS
# 	Score: 0.0718200285009
#
# As you may know, I'm a big fan of the idea that government should act as a platform, not always as an...
# 	Link: https://plus.google.com/+TimOReilly/posts/55MBeEgma4C
# 	Score: 0.0715750645795
#
# I'm totally stoked to hear that computational biologist and open science advocate (UC Berkeley professor...
# 	Link: https://plus.google.com/+TimOReilly/posts/WVHsuWw3KfX
# 	Score: 0.0662450065789
#
# Amazon's War on Publishers
#
# While I love Amazon, I've always been wary about how they would act when...
# 	Link: https://plus.google.com/+TimOReilly/posts/WhyyNx7PYnt
# 	Score: 0.0628675760877
#
# This is ridiculous! Companies submit inaccurate data, so the SEC wants to let them just hide it by going...
# 	Link: https://plus.google.com/+TimOReilly/posts/T1FjemHHSnc
# 	Score: 0.0587455718719
#
# This is truly shameful. The DRM world has truly gone wild when a farmer is unable to fix his own equipment...
# 	Link: https://plus.google.com/+TimOReilly/posts/6LJyF18ALEf
# 	Score: 0.0576576909113
#
# Portable benefits tied to the worker, not the company, are key to rethinking the social safety net for...
# 	Link: https://plus.google.com/+TimOReilly/posts/TJMVfMWgeX4
# 	Score: 0.0486486767064
#
# The 10-year contract for the US recreation.gov site  is up for renewal, and the Department of the Interior...
# 	Link: https://plus.google.com/+TimOReilly/posts/cmjFvKC5S9v
# 	Score: 0.0457869898413
#
# If  told you that any K-12 student in the US can get full access to all O'Reilly books and videos via...
# 	Link: https://plus.google.com/+TimOReilly/posts/AZf2Sr8CWah
# 	Score: 0.0210372656028
#
# "Surely Democrats and Republicans could agree to cut billions from a failed program like this!" you ...
# 	Link: https://plus.google.com/+TimOReilly/posts/1Lcxb3b8VPH
# 	Score: 0.00929407554988

# %% [markdown]
# ## Example 10. Finding similar documents using cosine similarity

# %%
import json
import nltk

# Load in human language data from wherever you've saved it

DATA = 'resources/ch04-googleplus/107033731246200681024.json'
data = json.loads(open(DATA).read())

# Only consider content that's ~1000+ words.
data = [ post for post in json.loads(open(DATA).read())
         if len(post['object']['content']) > 1000 ]

all_posts = [post['object']['content'].lower().split() 
             for post in data ]


# Provides tf, idf, and tf_idf abstractions for scoring

tc = nltk.TextCollection(all_posts)

# Compute a term-document matrix such that td_matrix[doc_title][term]
# returns a tf-idf score for the term in the document

td_matrix = {}
for idx in range(len(all_posts)):
    post = all_posts[idx]
    fdist = nltk.FreqDist(post)

    doc_title = data[idx]['title']
    url = data[idx]['url']
    td_matrix[(doc_title, url)] = {}

    for term in fdist.iterkeys():
        td_matrix[(doc_title, url)][term] = tc.tf_idf(term, post)
        
# Build vectors such that term scores are in the same positions...

distances = {}
for (title1, url1) in td_matrix.keys():

    distances[(title1, url1)] = {}
    (min_dist, most_similar) = (1.0, ('', ''))

    for (title2, url2) in td_matrix.keys():

        # Take care not to mutate the original data structures
        # since we're in a loop and need the originals multiple times

        terms1 = td_matrix[(title1, url1)].copy()
        terms2 = td_matrix[(title2, url2)].copy()

        # Fill in "gaps" in each map so vectors of the same length can be computed

        for term1 in terms1:
            if term1 not in terms2:
                terms2[term1] = 0

        for term2 in terms2:
            if term2 not in terms1:
                terms1[term2] = 0

        # Create vectors from term maps

        v1 = [score for (term, score) in sorted(terms1.items())]
        v2 = [score for (term, score) in sorted(terms2.items())]

        # Compute similarity amongst documents

        distances[(title1, url1)][(title2, url2)] = \
            nltk.cluster.util.cosine_distance(v1, v2)

        if url1 == url2:
            #print distances[(title1, url1)][(title2, url2)]
            continue

        if distances[(title1, url1)][(title2, url2)] < min_dist:
            (min_dist, most_similar) = (distances[(title1, url1)][(title2,
                                         url2)], (title2, url2))
    
    print '''Most similar to %s (%s)
\t%s (%s)
\tscore %f
''' % (title1, url1,
            most_similar[0], most_similar[1], 1-min_dist)
# Out:
# Most similar to How fragile life is, even for the best of us. We heard this morning that our friend Jake Brewer was ... (https://plus.google.com/+TimOReilly/posts/jV8jeKeWWyf)
# 	How to Raise Moral Children
#
# I thought this article on child-raising had a lot of good ideas in it. ... (https://plus.google.com/+TimOReilly/posts/NVZVmG1ct6C)
# 	score 0.058431
#
# Most similar to Work on sh-t that matters, aka Poo Camp
#
# Today was the annual chicken coop poo cleanup. (The chickens... (https://plus.google.com/+TimOReilly/posts/3vTSVs6CcdY)
# 	How to Raise Moral Children
#
# I thought this article on child-raising had a lot of good ideas in it. ... (https://plus.google.com/+TimOReilly/posts/NVZVmG1ct6C)
# 	score 0.036505
#
# Most similar to From an article about Walmart, their move to pay more, and the lessons for the broader economy: http... (https://plus.google.com/+TimOReilly/posts/bqErtyYp6co)
# 	 +Maria Konnikova's NY Times article about the role of time and attention scarcity in the cycle of poverty... (https://plus.google.com/+TimOReilly/posts/4qHJZJU6Dtb)
# 	score 0.043916
#
# Most similar to Absolutely fascinating exploration of the microbiome of a city.
#
# For those who don't know what the microbiome... (https://plus.google.com/+TimOReilly/posts/7EaHeYc1BiB)
# 	How to Raise Moral Children
#
# I thought this article on child-raising had a lot of good ideas in it. ... (https://plus.google.com/+TimOReilly/posts/NVZVmG1ct6C)
# 	score 0.040210
#
# Most similar to If we are going to transform government, we need both an inside game and an outside game.
#
# The inside... (https://plus.google.com/+TimOReilly/posts/WySK63oPskZ)
# 	This was my favorite piece in this Sunday's New York Times. It's a fascinating article about CBW, a ... (https://plus.google.com/+TimOReilly/posts/VsvsS9nagtU)
# 	score 0.059386
#
# Most similar to My dear friend Carolyn Shapiro does amazing projects that help communities understand their history,... (https://plus.google.com/+TimOReilly/posts/F1E8rsm3URP)
# 	"We don't need new policies. We need better implementation."
#
# Last night, I hosted Oakland City Councilor... (https://plus.google.com/+TimOReilly/posts/M1kH7bErNDm)
# 	score 0.052532
#
# Most similar to The Myth of the Spoiled Child
#
# There is an interesting op-ed in the NY Times by Alfie Cohn, who has ... (https://plus.google.com/+TimOReilly/posts/c1f9KVXsivD)
# 	How to Raise Moral Children
#
# I thought this article on child-raising had a lot of good ideas in it. ... (https://plus.google.com/+TimOReilly/posts/NVZVmG1ct6C)
# 	score 0.109587
#
# Most similar to Amazing story about digital transformation http://www.codeforamerica.org/blog/2015/11/30/a-new-approach... (https://plus.google.com/+TimOReilly/posts/BRmKh2ycaPe)
# 	How to Raise Moral Children
#
# I thought this article on child-raising had a lot of good ideas in it. ... (https://plus.google.com/+TimOReilly/posts/NVZVmG1ct6C)
# 	score 0.084205
#
# Most similar to This was my favorite piece in this Sunday's New York Times. It's a fascinating article about CBW, a ... (https://plus.google.com/+TimOReilly/posts/VsvsS9nagtU)
# 	If we are going to transform government, we need both an inside game and an outside game.
#
# The inside... (https://plus.google.com/+TimOReilly/posts/WySK63oPskZ)
# 	score 0.059386
#
# Most similar to  +Maria Konnikova's NY Times article about the role of time and attention scarcity in the cycle of poverty... (https://plus.google.com/+TimOReilly/posts/4qHJZJU6Dtb)
# 	The Myth of the Spoiled Child
#
# There is an interesting op-ed in the NY Times by Alfie Cohn, who has ... (https://plus.google.com/+TimOReilly/posts/c1f9KVXsivD)
# 	score 0.070510
#
# Most similar to How to Raise Moral Children
#
# I thought this article on child-raising had a lot of good ideas in it. ... (https://plus.google.com/+TimOReilly/posts/NVZVmG1ct6C)
# 	The Myth of the Spoiled Child
#
# There is an interesting op-ed in the NY Times by Alfie Cohn, who has ... (https://plus.google.com/+TimOReilly/posts/c1f9KVXsivD)
# 	score 0.109587
#
# Most similar to Nassau, The Bahamas Airport Travel Advice
#
# If anyone happens to travel to Nassau, the Bahamas, I thought... (https://plus.google.com/+TimOReilly/posts/dpQDew7sPbu)
# 	"We don't need new policies. We need better implementation."
#
# Last night, I hosted Oakland City Councilor... (https://plus.google.com/+TimOReilly/posts/M1kH7bErNDm)
# 	score 0.047668
#
# Most similar to Great talk by Maciej Ceglowski.  Funny, smart, and with an important message.  Just like Maciej all ... (https://plus.google.com/+TimOReilly/posts/b17bWhGfkH3)
# 	Can We Use Data to Make Better Regulations?
#
# Evgeny Morozov either misunderstands or misrepresents the... (https://plus.google.com/+TimOReilly/posts/gboAUahQwuZ)
# 	score 0.084840
#
# Most similar to Who will build the “god platform” for the Internet of Things?
#
# The idea that everyone will have a separate... (https://plus.google.com/+TimOReilly/posts/fTnKQCQdikp)
# 	"We don't need new policies. We need better implementation."
#
# Last night, I hosted Oakland City Councilor... (https://plus.google.com/+TimOReilly/posts/M1kH7bErNDm)
# 	score 0.045970
#
# Most similar to The 10-year contract for the US recreation.gov site  is up for renewal, and the Department of the Interior... (https://plus.google.com/+TimOReilly/posts/cmjFvKC5S9v)
# 	Great talk by Maciej Ceglowski.  Funny, smart, and with an important message.  Just like Maciej all ... (https://plus.google.com/+TimOReilly/posts/b17bWhGfkH3)
# 	score 0.060645
#
# Most similar to "We don't need new policies. We need better implementation."
#
# Last night, I hosted Oakland City Councilor... (https://plus.google.com/+TimOReilly/posts/M1kH7bErNDm)
# 	Why Common Core is Like Healthcare.gov
#
# Draw a bold line between this piece on the failure of the Common... (https://plus.google.com/+TimOReilly/posts/XebEgwjhV35)
# 	score 0.095470
#
# Most similar to "Surely Democrats and Republicans could agree to cut billions from a failed program like this!" you ... (https://plus.google.com/+TimOReilly/posts/1Lcxb3b8VPH)
# 	Can We Use Data to Make Better Regulations?
#
# Evgeny Morozov either misunderstands or misrepresents the... (https://plus.google.com/+TimOReilly/posts/gboAUahQwuZ)
# 	score 0.093030
#
# Most similar to Can We Use Data to Make Better Regulations?
#
# Evgeny Morozov either misunderstands or misrepresents the... (https://plus.google.com/+TimOReilly/posts/gboAUahQwuZ)
# 	"Surely Democrats and Republicans could agree to cut billions from a failed program like this!" you ... (https://plus.google.com/+TimOReilly/posts/1Lcxb3b8VPH)
# 	score 0.093030
#
# Most similar to Why Common Core is Like Healthcare.gov
#
# Draw a bold line between this piece on the failure of the Common... (https://plus.google.com/+TimOReilly/posts/XebEgwjhV35)
# 	"We don't need new policies. We need better implementation."
#
# Last night, I hosted Oakland City Councilor... (https://plus.google.com/+TimOReilly/posts/M1kH7bErNDm)
# 	score 0.095470

# %% [markdown]
# **Code to create a matrix diagram displaying linkages between Google+ activities as illustrated in Figure 6.**

# %%
import json
from operator import itemgetter
import nltk
from IPython.display import IFrame
from IPython.core.display import display

# Load in human language data from wherever you've saved it

DATA = 'resources/ch04-googleplus/107033731246200681024.json'

# Only consider content that's ~100+ words.
data = [post for post in json.loads(open(DATA).read())
        if len(post['object']['content']) > 1000]


all_posts = [post['object']['content'].lower().split() 
             for post in data]

# Provides tf, idf, tf_idf abstractions for scoring

tc = nltk.TextCollection(all_posts)

# Compute a term-document matrix such that td_matrix[doc_title][term]
# returns a tf-idf score for the term in the document

td_matrix = {}
for idx in range(len(all_posts)):
    post = all_posts[idx]
    fdist = nltk.FreqDist(post)

    doc_title = data[idx]['title']
    url = data[idx]['url']
    td_matrix[(doc_title, url)] = {}

    for term in fdist.iterkeys():
        td_matrix[(doc_title, url)][term] = tc.tf_idf(term, post)

# Build vectors such that term scores are in the same positions...

distances = {}

# Visualization output requires a list of nodes with values and a list of links that have
# source and destination targets. We'll pre-build the list of nodes here and create an index
# so that we can easily create links from titles after we compute the most similar items
# on each iteration of the outer loop

viz_links = []
viz_nodes = [ {'title' : title, 'url' : url} for (title, url) in td_matrix.keys() ]

foo = 0
for vn in viz_nodes:
    vn.update({'idx' : foo})
    foo += 1

idx = dict(zip([ vn['title'] for vn in viz_nodes ], range(len(viz_nodes))))


for (title1, url1) in td_matrix.keys():

    distances[(title1, url1)] = {}
    (min_dist, most_similar) = (1.0, ('', ''))

    for (title2, url2) in td_matrix.keys():

        # Take care not to mutate the original data structures
        # since we're in a loop and need the originals multiple times

        terms1 = td_matrix[(title1, url1)].copy()
        terms2 = td_matrix[(title2, url2)].copy()

        # Fill in "gaps" in each map so vectors of the same length can be computed

        for term1 in terms1:
            if term1 not in terms2:
                terms2[term1] = 0

        for term2 in terms2:
            if term2 not in terms1:
                terms1[term2] = 0

        # Create vectors from term maps

        v1 = [score for (term, score) in sorted(terms1.items())]
        v2 = [score for (term, score) in sorted(terms2.items())]

        # Compute similarity amongst documents

        distances[(title1, url1)][(title2, url2)] = \
            nltk.cluster.util.cosine_distance(v1, v2)

        if url1 == url2:
            #print distances[(title1, url1)][(title2, url2)]
            continue

        if distances[(title1, url1)][(title2, url2)] < min_dist:
            (min_dist, most_similar) = (distances[(title1, url1)][(title2,
                                         url2)], (title2, url2))
    
    viz_links.append({'source' : idx[title1], 'target' : idx[most_similar[0]], 'score' : 1 - min_dist})
    

f = open('resources/ch04-googleplus/viz/matrix.json', 'w')
f.write(json.dumps({'nodes' : viz_nodes, 'links' : viz_links}, indent=1))
f.close()

# Display the visualization below with an inline frame
display(IFrame('files/resources/ch04-googleplus/viz/matrix.html', '100%', '600px'))

# You could also serve it by running SimpleHTTPServer in the viz directory as follows:
# $ python -m SimpleHTTPServer 9000
# Now, open http://localhost:9000/matrix.html in your web browser
# Out:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch04-googleplus/viz/matrix.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Example 11. Using NLTK to compute bigrams and collocations for a sentence

# %%
import nltk

sentence = "Mr. Green killed Colonel Mustard in the study with the " + \
           "candlestick. Mr. Green is not a very nice fellow."

rs = nltk.ngrams(sentence.split(), 2)
print rs.next()
txt = nltk.Text(sentence.split())

txt.collocations()
# Out:
# ('Mr.', 'Green')
# Mr. Green

# %% [markdown]
# ## Example 12. Using NLTK to compute collocations in a similar manner to the nltk.Text.collocations demo functionality

# %%
import json
import nltk

# Load in human language data from wherever you've saved it

DATA = 'resources/ch04-googleplus/107033731246200681024.json'
data = json.loads(open(DATA).read())

# Number of collocations to find

N = 25

all_tokens = [token for activity in data for token in activity['object']['content'
              ].lower().split()]

finder = nltk.BigramCollocationFinder.from_words(all_tokens)
finder.apply_freq_filter(2)
finder.apply_word_filter(lambda w: w in nltk.corpus.stopwords.words('english'))
scorer = nltk.association.BigramAssocMeasures.jaccard
collocations = finder.nbest(scorer, N)

i = 1
for collocation in collocations:
    c = ' '.join(collocation)
    print '%d: %s' % (i, c)
    i += 1
# Out:
# 1: bottom, “copyright
# 2: cabo pulmo
# 3: expressing disappointment
# 4: nbc press:here
# 5: negative judgment
# 6: press:here tv
# 7: wood fired
# 8: yuval noah
# 9: silicon valley
# 10: on-demand economy,
# 11: +jennifer pahlka
# 12: acted generously,
# 13: barre historical
# 14: computational biologist
# 15: private sector
# 16: pulmo sunrise﻿
# 17: saul griffith
# 18: bay mini
# 19: credit card
# 20: east bay
# 21: +bryce roberts
# 22: inca trail
# 23: italian granite
# 24: models say,
# 25: child welfare
